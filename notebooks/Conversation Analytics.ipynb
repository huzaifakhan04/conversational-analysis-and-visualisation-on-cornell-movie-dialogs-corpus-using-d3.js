# %% [markdown]
# **<h1><center>Conservational Analytics</center></h1>**

# %% [markdown]
# Conversational analytics is a technology-driven process that involves analysing data from human conversations to extract meaningful insights. These conversations can occur across various channels such as phone calls, chatbots, social media, customer service interactions, and more. The primary goal of conversational analytics is to understand the content, context, and sentiment of conversations to improve customer experiences, streamline operations, and inform strategic decision-making.

# %% [markdown]
# ## **What Is Our Approach?**

# %% [markdown]
# For our analysis of the Cornell Movie-Dialogs Corpus, we employ natural language processing (NLP) techniques, including topic modelling, to uncover hidden thematic structures within the dialogues. Additionally, we create a conversation network to organise and summarise the extensive textual information, allowing us to understand the connections between entities in the dataset.

# %%
#   Importing the necessary libraries/modules.

from convokit import Corpus, download
import pandas as pd
from tqdm import tqdm
import json
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
#   Downloading the necessary packages.

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/huzaifa/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/huzaifa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/huzaifa/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/huzaifa/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
corpus=Corpus(filename=download("movie-corpus"))    #   Loading the corpus.
# Out:
# Downloading movie-corpus to /Users/huzaifa/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done

# %%
corpus.print_summary_stats()
# Out:
# Number of Speakers: 9035
# Number of Utterances: 304713
# Number of Conversations: 83097

# %%
speaker_dataframe=corpus.get_speakers_dataframe()   #   Retrieving the speakers pandas.DataFrame.
speaker_dataframe
# Out:
#       vectors meta.character_name meta.movie_idx             meta.movie_name  \
# id
# u0         []              BIANCA             m0  10 things i hate about you
# u2         []             CAMERON             m0  10 things i hate about you
# u3         []            CHASTITY             m0  10 things i hate about you
# u4         []                JOEY             m0  10 things i hate about you
# u5         []                 KAT             m0  10 things i hate about you
# ...       ...                 ...            ...                         ...
# u9029      []            CREALOCK           m616                   zulu dawn
# u9033      []        STUART SMITH           m616                   zulu dawn
# u9028      []             COGHILL           m616                   zulu dawn
# u9031      []             MELVILL           m616                   zulu dawn
# u9034      []             VEREKER           m616                   zulu dawn
#
#       meta.gender meta.credit_pos
# id
# u0              f               4
# u2              m               3
# u3              ?               ?
# u4              m               6
# u5              f               2
# ...           ...             ...
# u9029           ?               ?
# u9033           ?               ?
# u9028           ?               ?
# u9031           ?               ?
# u9034           ?               ?
#
# [9035 rows x 6 columns]

# %%
conversation_dataframe=corpus.get_conversations_dataframe() #   Retrieving the conversations pandas.DataFrame.
conversation_dataframe
# Out:
#         vectors meta.movie_idx             meta.movie_name meta.release_year  \
# id
# L1044        []             m0  10 things i hate about you              1999
# L984         []             m0  10 things i hate about you              1999
# L924         []             m0  10 things i hate about you              1999
# L870         []             m0  10 things i hate about you              1999
# L866         []             m0  10 things i hate about you              1999
# ...         ...            ...                         ...               ...
# L666324      []           m616                   zulu dawn              1979
# L666262      []           m616                   zulu dawn              1979
# L666520      []           m616                   zulu dawn              1979
# L666369      []           m616                   zulu dawn              1979
# L666256      []           m616                   zulu dawn              1979
#
#         meta.rating meta.votes  \
# id
# L1044          6.90      62847
# L984           6.90      62847
# L924           6.90      62847
# L870           6.90      62847
# L866           6.90      62847
# ...             ...        ...
# L666324        6.40       1911
# L666262        6.40       1911
# L666520        6.40       1911
# L666369        6.40       1911
# L666256        6.40       1911
#
#                                                 meta.genre
# id
# L1044                                ['comedy', 'romance']
# L984                                 ['comedy', 'romance']
# L924                                 ['comedy', 'romance']
# L870                                 ['comedy', 'romance']
# L866                                 ['comedy', 'romance']
# ...                                                    ...
# L666324  ['action', 'adventure', 'drama', 'history', 'w...
# L666262  ['action', 'adventure', 'drama', 'history', 'w...
# L666520  ['action', 'adventure', 'drama', 'history', 'w...
# L666369  ['action', 'adventure', 'drama', 'history', 'w...
# L666256  ['action', 'adventure', 'drama', 'history', 'w...
#
# [83097 rows x 7 columns]

# %%
utterance_dataframe=corpus.get_utterances_dataframe()   #   Retrieving the utterances pandas.DataFrame.
utterance_dataframe
# Out:
#         timestamp                                               text speaker  \
# id
# L1045        None                                       They do not!      u0
# L1044        None                                        They do to!      u2
# L985         None                                         I hope so.      u0
# L984         None                                          She okay?      u2
# L925         None                                          Let's go.      u0
# ...           ...                                                ...     ...
# L666371      None  Lord Chelmsford seems to want me to stay back ...   u9030
# L666370      None  I'm to take the Sikali with the main column to...   u9034
# L666369      None                           Your orders, Mr Vereker?   u9030
# L666257      None  Good ones, yes, Mr Vereker. Gentlemen who can ...   u9030
# L666256      None  Colonel Durnford... William Vereker. I hear yo...   u9034
#
#         reply_to conversation_id meta.movie_id  \
# id
# L1045      L1044           L1044            m0
# L1044       None           L1044            m0
# L985        L984            L984            m0
# L984        None            L984            m0
# L925        L924            L924            m0
# ...          ...             ...           ...
# L666371  L666370         L666369          m616
# L666370  L666369         L666369          m616
# L666369     None         L666369          m616
# L666257  L666256         L666256          m616
# L666256     None         L666256          m616
#
#                                                meta.parsed vectors
# id
# L1045    [{'rt': 1, 'toks': [{'tok': 'They', 'tag': 'PR...      []
# L1044    [{'rt': 1, 'toks': [{'tok': 'They', 'tag': 'PR...      []
# L985     [{'rt': 1, 'toks': [{'tok': 'I', 'tag': 'PRP',...      []
# L984     [{'rt': 1, 'toks': [{'tok': 'She', 'tag': 'PRP...      []
# L925     [{'rt': 0, 'toks': [{'tok': 'Let', 'tag': 'VB'...      []
# ...                                                    ...     ...
# L666371  [{'rt': 2, 'toks': [{'tok': 'Lord', 'tag': 'NN...      []
# L666370  [{'rt': 1, 'toks': [{'tok': 'I', 'tag': 'PRP',...      []
# L666369  [{'rt': 1, 'toks': [{'tok': 'Your', 'tag': 'PR...      []
# L666257  [{'rt': 1, 'toks': [{'tok': 'Good', 'tag': 'JJ...      []
# L666256  [{'rt': 1, 'toks': [{'tok': 'Colonel', 'tag': ...      []
#
# [304713 rows x 8 columns]

# %%
speaker_utterance_dataframe=pd.merge(speaker_dataframe, utterance_dataframe, left_on="id", right_on="speaker")  #   Joining the speakers and utterances pandas.DataFrames.
speaker_utterance_dataframe.head()
# Out:
#   vectors_x meta.character_name meta.movie_idx             meta.movie_name  \
# 0        []              BIANCA             m0  10 things i hate about you
# 1        []              BIANCA             m0  10 things i hate about you
# 2        []              BIANCA             m0  10 things i hate about you
# 3        []              BIANCA             m0  10 things i hate about you
# 4        []              BIANCA             m0  10 things i hate about you
#
#   meta.gender meta.credit_pos timestamp  \
# 0           f               4      None
# 1           f               4      None
# 2           f               4      None
# 3           f               4      None
# 4           f               4      None
#
#                                                 text speaker reply_to  \
# 0                                       They do not!      u0    L1044
# 1                                         I hope so.      u0     L984
# 2                                          Let's go.      u0     L924
# 3     Okay -- you're gonna need to learn how to lie.      u0     L871
# 4  I'm kidding.  You know how sometimes you just ...      u0     None
#
#   conversation_id meta.movie_id  \
# 0           L1044            m0
# 1            L984            m0
# 2            L924            m0
# 3            L870            m0
# 4            L870            m0
#
#                                          meta.parsed vectors_y
# 0  [{'rt': 1, 'toks': [{'tok': 'They', 'tag': 'PR...        []
# 1  [{'rt': 1, 'toks': [{'tok': 'I', 'tag': 'PRP',...        []
# 2  [{'rt': 0, 'toks': [{'tok': 'Let', 'tag': 'VB'...        []
# 3  [{'rt': 4, 'toks': [{'tok': 'Okay', 'tag': 'UH...        []
# 4  [{'rt': 2, 'toks': [{'tok': 'I', 'tag': 'PRP',...        []

# %%
corpus_dataframe=pd.merge(conversation_dataframe, speaker_utterance_dataframe, left_on="id", right_on="conversation_id")    #   Joining the conversations and speakers and utterances pandas.DataFrames.
corpus_dataframe.head()
# Out:
#   vectors meta.movie_idx_x           meta.movie_name_x meta.release_year  \
# 0      []               m0  10 things i hate about you              1999
# 1      []               m0  10 things i hate about you              1999
# 2      []               m0  10 things i hate about you              1999
# 3      []               m0  10 things i hate about you              1999
# 4      []               m0  10 things i hate about you              1999
#
#   meta.rating meta.votes             meta.genre vectors_x meta.character_name  \
# 0        6.90      62847  ['comedy', 'romance']        []              BIANCA
# 1        6.90      62847  ['comedy', 'romance']        []             CAMERON
# 2        6.90      62847  ['comedy', 'romance']        []              BIANCA
# 3        6.90      62847  ['comedy', 'romance']        []             CAMERON
# 4        6.90      62847  ['comedy', 'romance']        []              BIANCA
#
#   meta.movie_idx_y  ... meta.gender meta.credit_pos timestamp          text  \
# 0               m0  ...           f               4      None  They do not!
# 1               m0  ...           m               3      None   They do to!
# 2               m0  ...           f               4      None    I hope so.
# 3               m0  ...           m               3      None     She okay?
# 4               m0  ...           f               4      None     Let's go.
#
#   speaker reply_to conversation_id meta.movie_id  \
# 0      u0    L1044           L1044            m0
# 1      u2     None           L1044            m0
# 2      u0     L984            L984            m0
# 3      u2     None            L984            m0
# 4      u0     L924            L924            m0
#
#                                          meta.parsed vectors_y
# 0  [{'rt': 1, 'toks': [{'tok': 'They', 'tag': 'PR...        []
# 1  [{'rt': 1, 'toks': [{'tok': 'They', 'tag': 'PR...        []
# 2  [{'rt': 1, 'toks': [{'tok': 'I', 'tag': 'PRP',...        []
# 3  [{'rt': 1, 'toks': [{'tok': 'She', 'tag': 'PRP...        []
# 4  [{'rt': 0, 'toks': [{'tok': 'Let', 'tag': 'VB'...        []
#
# [5 rows x 21 columns]

# %%
print(list(corpus_dataframe.columns))
# Out:
# ['vectors', 'meta.movie_idx_x', 'meta.movie_name_x', 'meta.release_year', 'meta.rating', 'meta.votes', 'meta.genre', 'vectors_x', 'meta.character_name', 'meta.movie_idx_y', 'meta.movie_name_y', 'meta.gender', 'meta.credit_pos', 'timestamp', 'text', 'speaker', 'reply_to', 'conversation_id', 'meta.movie_id', 'meta.parsed', 'vectors_y']

# %%
corpus_dataframe=corpus_dataframe.drop(columns=["vectors", "meta.movie_idx_x", "vectors_x", "meta.movie_idx_y", "meta.movie_name_y", "meta.gender", "meta.credit_pos", "timestamp", "conversation_id", "meta.movie_id", "meta.parsed", "vectors_y"])
corpus_dataframe
# Out:
#                  meta.movie_name_x meta.release_year meta.rating meta.votes  \
# 0       10 things i hate about you              1999        6.90      62847
# 1       10 things i hate about you              1999        6.90      62847
# 2       10 things i hate about you              1999        6.90      62847
# 3       10 things i hate about you              1999        6.90      62847
# 4       10 things i hate about you              1999        6.90      62847
# ...                            ...               ...         ...        ...
# 304708                   zulu dawn              1979        6.40       1911
# 304709                   zulu dawn              1979        6.40       1911
# 304710                   zulu dawn              1979        6.40       1911
# 304711                   zulu dawn              1979        6.40       1911
# 304712                   zulu dawn              1979        6.40       1911
#
#                                                meta.genre meta.character_name  \
# 0                                   ['comedy', 'romance']              BIANCA
# 1                                   ['comedy', 'romance']             CAMERON
# 2                                   ['comedy', 'romance']              BIANCA
# 3                                   ['comedy', 'romance']             CAMERON
# 4                                   ['comedy', 'romance']              BIANCA
# ...                                                   ...                 ...
# 304708  ['action', 'adventure', 'drama', 'history', 'w...            DURNFORD
# 304709  ['action', 'adventure', 'drama', 'history', 'w...             VEREKER
# 304710  ['action', 'adventure', 'drama', 'history', 'w...             VEREKER
# 304711  ['action', 'adventure', 'drama', 'history', 'w...            DURNFORD
# 304712  ['action', 'adventure', 'drama', 'history', 'w...             VEREKER
#
#                                                      text speaker reply_to
# 0                                            They do not!      u0    L1044
# 1                                             They do to!      u2     None
# 2                                              I hope so.      u0     L984
# 3                                               She okay?      u2     None
# 4                                               Let's go.      u0     L924
# ...                                                   ...     ...      ...
# 304708                           Your orders, Mr Vereker?   u9030     None
# 304709  I think Chelmsford wants a good man on the bor...   u9034  L666371
# 304710  I'm to take the Sikali with the main column to...   u9034  L666369
# 304711  Good ones, yes, Mr Vereker. Gentlemen who can ...   u9030  L666256
# 304712  Colonel Durnford... William Vereker. I hear yo...   u9034     None
#
# [304713 rows x 9 columns]

# %% [markdown]
# ### **• Conversation Network:**

# %% [markdown]
# A conversation network is a graphical representation of interactions between entities within a dataset, particularly focusing on dialogues and conversations. In the context of the Cornell Movie-Dialogs Corpus, a conversation network can help visualise and analyse the relationships and communication patterns between characters.
#
# - **Nodes:** Each node represents an entity in the dataset; in this case, the nodes represent movie characters.
# - **Edges:** Each edge represents a conversation or interaction between two nodes (characters).
#
# Facilitates various types of analysis, such as:
#
# - **Centrality Analysis:** Identifying key characters who are central to the story or have the most interactions.
# - **Community Detection:** Finding groups of characters who interact more frequently with each other than with others.
# - **Interaction Patterns:** Understanding how conversations flow, who initiates them, and how they propagate through the network.

# %%
edges=list(zip(corpus_dataframe["meta.character_name"], corpus_dataframe["reply_to"], corpus_dataframe["text"]))    #   Creating a list of tuples containing the source, target, and text of each edge.
edges=[(source, target, text) for source, target, text in edges if target is not None]  #   Removing the edges with a target of None.
edges
# Out:
# [('BIANCA', 'L1044', 'They do not!'),
#  ('BIANCA', 'L984', 'I hope so.'),
#  ('BIANCA', 'L924', "Let's go."),
#  ('BIANCA', 'L871', "Okay -- you're gonna need to learn how to lie."),
#  ('CAMERON', 'L870', 'No'),
#  ('BIANCA', 'L868', 'Like my fear of wearing pastels?'),
#  ('BIANCA', 'L866', 'What good stuff?'),
#  ('CAMERON', 'L867', 'The "real you".'),
#  ('BIANCA',
#   'L863',
#   "Me.  This endless ...blonde babble. I'm like, boring myself."),
#  ('CAMERON',
#   'L864',
#   'Thank God!  If I had to hear one more story about your coiffure...'),
#  ('CAMERON', 'L862', 'What crap?'),
#  ('CAMERON', 'L860', 'No...'),
#  ('BIANCA', 'L697', 'But'),
#  ('CAMERON', 'L698', 'You always been this selfish?'),
#  ('CAMERON', 'L696', "Then that's all you had to say."),
#  ('BIANCA', 'L693', 'I was?'),
#  ('CAMERON', 'L694', "You never wanted to go out with 'me, did you?"),
#  ('BIANCA', 'L662', 'Tons'),
#  ('CAMERON', 'L577', 'I believe we share an art instructor'),
#  ('CAMERON', 'L575', 'Looks like things worked out tonight, huh?'),
#  ('BIANCA',
#   'L406',
#   "Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes."),
#  ('BIANCA',
#   'L404',
#   "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies."),
#  ('CAMERON', 'L405', "So that's the kind of guy she likes? Pretty ones?"),
#  ('BIANCA',
#   'L401',
#   "I really, really, really wanna go, but I can't.  Not unless my sister goes."),
#  ('CAMERON',
#   'L402',
#   "I'm workin' on it. But she doesn't seem to be goin' for him."),
#  ('BIANCA',
#   'L367',
#   "Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment."),
#  ('BIANCA', 'L365', "You're sweet."),
#  ('BIANCA',
#   'L363',
#   "I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?"),
#  ('BIANCA', 'L280', 'Where?'),
#  ('CAMERON', 'L276', "Well, there's someone I think might be --"),
#  ('BIANCA', 'L274', 'Forget French.'),
#  ('BIANCA',
#   'L272',
#   "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone."),
#  ('CAMERON', 'L273', "That's because it's such a nice one."),
#  ('CAMERON', 'L271', "Right.  See?  You're ready for the quiz."),
#  ('CAMERON', 'L207', 'Let me see what I can do.'),
#  ('BIANCA',
#   'L204',
#   'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.'),
#  ('CAMERON', 'L205', "That's a shame."),
#  ('BIANCA',
#   'L201',
#   "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does."),
#  ('CAMERON', 'L202', 'Seems like she could get a date easy enough...'),
#  ('CAMERON', 'L200', 'Cameron.'),
#  ('CAMERON', 'L198', 'Forget it.'),
#  ('BIANCA', 'L195', 'Not the hacking and gagging and spitting part.  Please.'),
#  ('CAMERON',
#   'L196',
#   "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?"),
#  ('CAMERON',
#   'L194',
#   "Well, I thought we'd start with pronunciation, if that's okay with you."),
#  ('BIANCA', 'L952', 'I did.'),
#  ('CHASTITY', 'L659', "I don't have to be home 'til two."),
#  ('BIANCA',
#   'L598',
#   "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?"),
#  ('CHASTITY',
#   'L599',
#   "All I know is -- I'd give up my private line to go out with a guy like Joey."),
#  ('BIANCA',
#   'L596',
#   "Combination.  I don't know -- I thought he'd be different.  More of a gentleman..."),
#  ('CHASTITY', 'L595', 'Is he oily or dry?'),
#  ('BIANCA', 'L579', 'Would you mind getting me a drink, Cameron?'),
#  ('BIANCA', 'L572', 'Joey.'),
#  ('CHASTITY', 'L571', 'Who?'),
#  ('BIANCA', 'L50', 'You might wanna think about it'),
#  ('CHASTITY', 'L49', 'No.'),
#  ('BIANCA', 'L759', "You know the deal.  I can ' t go if Kat doesn't go --"),
#  ('BIANCA', 'L756', 'Hi, Joey.'),
#  ('JOEY',
#   'L757',
#   "You're concentrating awfully hard considering it's gym class."),
#  ('JOEY',
#   'L592',
#   "My agent says I've got a good shot at being the Prada guy next year."),
#  ('BIANCA', 'L589', 'Queen Harry?'),
#  ('JOEY',
#   'L590',
#   "It's a gay cruise line, but I'll be, like, wearing a uniform and stuff."),
#  ('BIANCA', 'L396', 'Hopefully.'),
#  ('BIANCA', 'L394', 'Expensive?'),
#  ('KAT', 'L1051', 'Perm?'),
#  ('KAT', 'L1021', "It's just you."),
#  ('BIANCA', 'L1010', 'No! I just wanted'),
#  ('BIANCA', 'L1008', 'I just wanted --'),
#  ('KAT',
#   'L1009',
#   'What? To completely damage me?  To send me to therapy forever? What?'),
#  ('KAT', 'L1007', 'You set me up.'),
#  ('KAT', 'L982', 'So did you'),
#  ('BIANCA', 'L913', "I guess I'll never know, will I?"),
#  ('BIANCA',
#   'L911',
#   "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself"),
#  ('BIANCA', 'L909', "I'm not stupid enough to repeat your mistakes."),
#  ('KAT',
#   'L912',
#   "Not all experiences are good, Bianca. You can't always trust the people you want to."),
#  ('KAT', 'L910', 'I guess I thought I was protecting you.'),
#  ('BIANCA',
#   'L907',
#   "No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage."),
#  ('BIANCA', 'L905', "Why didn't you tell me?"),
#  ('KAT', 'L906', 'I wanted to let you make up your own mind about him.'),
#  ('KAT',
#   'L904',
#   'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --'),
#  ('BIANCA', 'L901', 'You did what?'),
#  ('KAT',
#   'L902',
#   "Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me."),
#  ('BIANCA', 'L899', 'As in...'),
#  ('BIANCA', 'L897', 'But you hate Joey'),
#  ('BIANCA', 'L895', 'Why?'),
#  ('BIANCA', 'L893', 'What?'),
#  ('KAT', 'L898', 'Now I do.  Back then, was a different story.'),
#  ('KAT', 'L896', 'He was, like, a total babe'),
#  ('KAT', 'L894', 'In 9th.  For a month'),
#  ('BIANCA',
#   'L891',
#   "I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t."),
#  ('BIANCA', 'L889', 'Like you care.'),
#  ('KAT',
#   'L890',
#   "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s ."),
#  ('KAT', 'L655', "You're welcome."),
#  ('BIANCA',
#   'L601',
#   "I really don't think I need any social advice from you right now."),
#  ('KAT', 'L542', 'Can we go now?'),
#  ('BIANCA',
#   'L532',
#   "Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too."),
#  ('KAT', 'L531', "It's Shakespeare.  Maybe you've heard of him?"),
#  ('KAT', 'L529', "At least I'm not a clouted fen- sucked hedge-pig."),
#  ('BIANCA',
#   'L526',
#   "Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that."),
#  ('KAT', 'L525', "What's normal?"),
#  ('BIANCA',
#   'L444',
#   "I think you're a freak.  I think you do this to torture me.  And I think you suck."),
#  ('BIANCA',
#   'L442',
#   "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?"),
#  ('KAT', 'L443', 'What do you think?'),
#  ('KAT',
#   'L441',
#   "It means that Gigglepuss is playing at Club Skunk and we're going."),
#  ('BIANCA', 'L319', 'Can you at least start wearing a bra?'),
#  ('BIANCA', 'L164', 'Nowhere... Hi, Daddy.'),
#  ('BIANCA',
#   'L922',
#   "I have a date, Daddy.  And he ' s not a captain of oppression like some men we know."),
#  ('BIANCA',
#   'L883',
#   "Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!"),
#  ('BIANCA', 'L881', 'He\'s not a "hot rod".  Whatever that is.'),
#  ('BIANCA', 'L879', 'No, but'),
#  ('WALTER',
#   'L882',
#   "You're not going unless your sister goes.  End of story."),
#  ('WALTER',
#   'L880',
#   "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?"),
#  ('WALTER', 'L878', 'The prom?  Kat has a date?'),
#  ('BIANCA', 'L544', 'Why?'),
#  ('WALTER', 'L545', "Because she'll scare them away."),
#  ('BIANCA', 'L538', 'Daddy, no!'),
#  ('WALTER', 'L539', 'Just for a minute'),
#  ('BIANCA', 'L536', "It's just a party. Daddy."),
#  ('WALTER', 'L523', "If Kat's not going, you're not going."),
#  ('BIANCA',
#   'L520',
#   'It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --'),
#  ('BIANCA',
#   'L518',
#   'If you must know, we were attempting to go to a small study group of friends.'),
#  ('WALTER', 'L519', 'Otherwise known as an orgy?'),
#  ('WALTER', 'L517', "And where're you going?"),
#  ('WALTER', 'L189', 'Exactly my point'),
#  ('BIANCA', 'L182', "But it's not fair -- she's a mutant, Daddy!"),
#  ('BIANCA', 'L180', 'What if she never starts dating?'),
#  ('WALTER', 'L181', "Then neither will you.  And I'll get to sleep at night."),
#  ('WALTER',
#   'L179',
#   "No! You're not dating until your sister starts dating.  End of discussion."),
#  ('BRUCE', 'L462', "Just sent 'em through."),
#  ('BRUCE', 'L460', 'Never'),
#  ('BRUCE',
#   'L458',
#   "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?"),
#  ('PATRICK',
#   'L461',
#   'Padua girls.  One tall, decent body. The other one kinda short and undersexed?'),
#  ('PATRICK', 'L459', 'Fan of a fan.  You see a couple of minors come in?'),
#  ('MICHAEL',
#   'L778',
#   "Best case scenario, you're back on the payroll for awhile."),
#  ('CAMERON', 'L585', "No, I ' m not."),
#  ('CAMERON',
#   'L583',
#   "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?"),
#  ('MICHAEL', 'L584', "Buttholus extremus.  But hey, you're making progress."),
#  ('CAMERON',
#   'L499',
#   "Hell, I've just been going over the whole thing in my head and -"),
#  ('CAMERON', 'L432', "It's her favorite band."),
#  ('CAMERON', 'L424', "Okay!  I wasn't sure"),
#  ('CAMERON', 'L417', 'Her favorite uncle'),
#  ('MICHAEL', 'L418', 'Dead at forty-one.'),
#  ('MICHAEL', 'L416', "It's a lung cancer issue"),
#  ('CAMERON', 'L389', 'Will Bogey get bent?'),
#  ('MICHAEL',
#   'L390',
#   "Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass."),
#  ('MICHAEL',
#   'L388',
#   "In that case, we'll need to make it a school-wide blow out."),
#  ('MICHAEL',
#   'L244',
#   "Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca."),
#  ('CAMERON', 'L223', 'I thought you hated those people.'),
#  ('MICHAEL',
#   'L224',
#   "Hey -- I've gotta have a few clients when I get to Wall Street."),
#  ('CAMERON', 'L221', "That's what I just said"),
#  ('CAMERON',
#   'L219',
#   "Forget his reputation.  Do you think we've got a plan or not?"),
#  ('CAMERON', 'L217', 'They always let felons sit in on Honors Biology?'),
#  ('CAMERON', 'L215', 'He seems like he thrives on danger'),
#  ('MICHAEL', 'L220', "Did she actually say she'd go out with you?"),
#  ('MICHAEL',
#   'L218',
#   "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers."),
#  ('MICHAEL',
#   'L216',
#   "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz..."),
#  ('MICHAEL', 'L212', 'You wanna go out with him?'),
#  ('MICHAEL',
#   'L210',
#   "Unlikely, but even so, she still can't go out with you.  So what's the point?"),
#  ('CAMERON', 'L157', "That's her?  Bianca's sister?"),
#  ('MICHAEL', 'L158', 'The mewling, rampalian wretch herself.'),
#  ('CAMERON', 'L145', "You mean I'd get a chance to talk to her?"),
#  ('CAMERON', 'L143', "Sure do ... my Mom's from Canada"),
#  ('MICHAEL', 'L146', 'You could consecrate with her, my friend.'),
#  ('MICHAEL', 'L144', 'Guess who just signed up for a tutor?'),
#  ('CAMERON', 'L140', 'He always have that shit-eating grin?'),
#  ('MICHAEL',
#   'L141',
#   "Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out."),
#  ('MICHAEL',
#   'L139',
#   "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted."),
#  ('CAMERON', 'L90', 'Why not?'),
#  ('CAMERON', 'L88', 'Who is she?'),
#  ('MICHAEL',
#   'L91',
#   "I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility."),
#  ('MICHAEL', 'L89', "Bianca Stratford.  Sophomore. Don't even think about it"),
#  ('MICHAEL', 'L87', 'You burn, you pine, you perish?'),
#  ('MICHAEL',
#   'L77',
#   'Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.'),
#  ('CAMERON', 'L72', 'How many people go here?'),
#  ('CAMERON', 'L70', 'Thirty-two.'),
#  ('CAMERON',
#   'L68',
#   "Yeah.  A couple.  We're outnumbered by the cows, though."),
#  ('CAMERON', 'L66', "North, actually.  How'd you   ?"),
#  ('MICHAEL', 'L73', 'Couple thousand. Most of them evil'),
#  ('MICHAEL', 'L71', 'Get out!'),
#  ('MICHAEL', 'L69', 'How many people were in your old school?'),
#  ('MICHAEL', 'L67', 'I was kidding. People actually live there?'),
#  ('CAMERON', 'L63', 'So they tell me...'),
#  ('MICHAEL', 'L64', "C'mon.  I'm supposed to give you the tour."),
#  ('CAMERON', 'L780', 'You get the girl.'),
#  ('CAMERON', 'L743', 'She kissed me.'),
#  ('PATRICK', 'L744', 'Where?'),
#  ('PATRICK', 'L740', "She just needs time to cool off I'll give it a day."),
#  ('PATRICK',
#   'L725',
#   "I don ' t know.  I decided not to nail her when she was too drunk to remember it."),
#  ('CAMERON', 'L623', 'Sure'),
#  ('PATRICK', 'L624', 'Then, go get her'),
#  ('CAMERON', 'L621', "She's partial to Joey, not me"),
#  ('CAMERON', 'L619', "It's off. The whole thing."),
#  ('PATRICK', 'L430', "Don't make me do it, man"),
#  ('PATRICK',
#   'L426',
#   "So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?"),
#  ('CAMERON',
#   'L411',
#   "I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful."),
#  ('PATRICK', 'L385', "Yeah -- we'll see."),
#  ('JOEY', 'L557', 'And why would I do that?'),
#  ('JOEY', 'L555', 'Your sister here?'),
#  ('KAT', 'L554', 'Away.'),
#  ('JOEY', 'L335', 'Not at all'),
#  ('JOEY', 'L149', "They're running the rest of me next month."),
#  ('KAT',
#   'L148',
#   'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.'),
#  ('JOEY', 'L747', "Enough with the Barbie n' Ken shit. I know."),
#  ('JOEY', 'L608', 'Get her to act like a human'),
#  ('PATRICK', 'L607', 'Do what?'),
#  ('JOEY', 'L605', "A deal's a deal."),
#  ('JOEY', 'L356', 'Forget it.'),
#  ('JOEY', 'L354', 'What?'),
#  ('PATRICK', 'L357', 'Forget her sister, then.'),
#  ('PATRICK', 'L355', 'A hundred bucks a date.'),
#  ('JOEY', 'L350', "Watching the bitch trash my car doesn't count as a date."),
#  ('PATRICK',
#   'L351',
#   'I got her under control. She just acts crazed in public to keep up the image.'),
#  ('PATRICK', 'L349', "I'm on it"),
#  ('PATRICK', 'L300', "Fifty, and you've got your man."),
#  ('JOEY', 'L298', 'Fine, thirty.'),
#  ('JOEY',
#   'L295',
#   "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend."),
#  ('PATRICK', 'L296', 'How much?'),
#  ('PATRICK', 'L294', "You're gonna pay me to take out some girl?"),
#  ('JOEY', 'L291', "But you'd go out with her if you had the cake?"),
#  ('JOEY', 'L289', 'You just said'),
#  ('JOEY', 'L287', 'Yeah, whatever.  I want you to go out with her.'),
#  ('PATRICK', 'L290', 'You need money to take a girl out'),
#  ('PATRICK', 'L288', "Sure, Sparky.  I'll get right on it."),
#  ('JOEY', 'L285', 'What do you think?'),
#  ('MICHAEL', 'L508', "Hey -- it's all for the higher good right?"),
#  ('JOEY', 'L503', 'You and Verona?'),
#  ('MICHAEL', 'L504', 'What?  We took bathes together when we were kids.'),
#  ('MICHAEL', 'L502', "Uh,  yeah.  We're old friend*"),
#  ('JOEY', 'L238', 'Does this conversation have a purpose?'),
#  ('MICHAEL',
#   'L239',
#   "So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job."),
#  ('JOEY', 'L235', "We're not."),
#  ('JOEY', 'L233', "We don't chat."),
#  ('JOEY', 'L231', 'Are you lost?'),
#  ('MICHAEL',
#   'L234',
#   "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested."),
#  ('MICHAEL', 'L232', 'Nope - just came by to chat'),
#  ('KAT',
#   'L948',
#   "Oh, honey -- tell me we haven't' progressed to full-on hallucinations."),
#  ('KAT', 'L946', 'Who?'),
#  ('MANDELLA', 'L947', 'William - he asked me to meet him here.'),
#  ('KAT',
#   'L753',
#   "You ' re looking at this from the wrong perspective.  We're making a statement."),
#  ('KAT',
#   'L751',
#   'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.'),
#  ('MANDELLA', 'L754', 'Oh, good.  Something new and different for us.'),
#  ('MANDELLA',
#   'L752',
#   "Okay, okay, we won't go.  It's not like I have a dress anyway"),
#  ('MANDELLA', 'L750', "Well, I guess we're not, since we don't have dates ."),
#  ('KAT', 'L720', 'I got drunk.  I puked.  I got rejected. It was big fun.'),
#  ('KAT', 'L718', 'I did Bianca a favor and it backfired.'),
#  ('KAT', 'L716', "I didn't have a choice."),
#  ('MANDELLA', 'L719', "You didn't"),
#  ('MANDELLA',
#   'L717',
#   "You didn't have a choice?  Where's Kat and what have you done with her?"),
#  ('KAT', 'L490', 'Who cares?'),
#  ('KAT', 'L447', 'No fear.'),
#  ('KAT',
#   'L253',
#   'If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."'),
#  ('MANDELLA', 'L252', 'Does it matter?'),
#  ('KAT', 'L250', 'Neither has his heterosexuality.'),
#  ('KAT', 'L248', "William didn't even go to high school"),
#  ('MANDELLA', 'L249', "That's never been proven"),
#  ('MANDELLA', 'L247', 'William would never have gone to a state school.'),
#  ('MANDELLA',
#   'L151',
#   "You could always go with me.  I'm sure William has some friends."),
#  ('MANDELLA', 'L133', "But imagine the things he'd say during sex."),
#  ('MANDELLA', 'L131', 'An attempted slit.'),
#  ('MANDELLA', 'L129', 'Just a little.'),
#  ('KAT', 'L127', 'Block E?'),
#  ('KAT',
#   'L125',
#   "I'm sure he's completely incapable of doing anything that interesting."),
#  ('KAT', 'L123', 'Patrick Verona   Random skid.'),
#  ('MANDELLA', 'L126', 'He always look so'),
#  ('MANDELLA',
#   'L124',
#   "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies."),
#  ('KAT', 'L1041', 'Oh, Bianca?  Can you get me my freshman yearbook?'),
#  ('PATRICK', 'L1042', "Don ' t you even dare. . ."),
#  ('PATRICK', 'L1040', 'Because I like to torture you.'),
#  ('KAT', 'L1033', 'Is that right?'),
#  ('PATRICK', 'L1034', 'Yeah, but then I fucked up. I fell for her.'),
#  ('PATRICK', 'L1031', 'I thought you could use it. When you start your band.'),
#  ('KAT',
#   'L975',
#   'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?'),
#  ('KAT',
#   'L973',
#   'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!'),
#  ('PATRICK', 'L976', "I didn't care about the money."),
#  ('PATRICK', 'L974', "It wasn't like that."),
#  ('PATRICK',
#   'L960',
#   'It gets worse -- you still have your freshman yearbook?'),
#  ('KAT', 'L957', 'What?'),
#  ('PATRICK',
#   'L958',
#   "That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story."),
#  ('KAT',
#   'L939',
#   "Look, I'm  -- sorry -- that I questioned your motives.  I was wrong."),
#  ('KAT', 'L937', "It's just something I had.  You know"),
#  ('PATRICK', 'L938', 'Oh huh'),
#  ('PATRICK',
#   'L936',
#   "It's Scurvy's.  His date got convicted. Where'd you get the dress?"),
#  ('KAT', 'L855', 'Answer the question, Patrick'),
#  ('KAT', 'L853', 'You tell me.'),
#  ('PATRICK',
#   'L856',
#   "Nothing!  There's nothing in it for me. Just the pleasure of your company."),
#  ('PATRICK', 'L854', 'You need therapy.  Has anyone ever told you that?'),
#  ('PATRICK', 'L852', 'So I have to have a motive to be with you?'),
#  ('KAT', 'L847', "Because I don't want to. It's a stupid tradition."),
#  ('KAT', 'L845', "No, I won't go with you"),
#  ('KAT', 'L843', 'No.'),
#  ('PATRICK', 'L846', 'Why not?'),
#  ('PATRICK', 'L844', 'No what?'),
#  ('PATRICK', 'L842', 'You know what I mean'),
#  ('KAT',
#   'L839',
#   "You're amazingly self-assured. Has anyone ever told you that?"),
#  ('KAT', 'L837', 'What?'),
#  ('KAT', 'L835', 'No -- something real.  Something no one else knows.'),
#  ('PATRICK', 'L840', 'Go to the prom with me'),
#  ('PATRICK', 'L838', 'No one else knows'),
#  ('PATRICK', 'L836', "You're sweet.  And sexy.  And completely hot for me."),
#  ('PATRICK', 'L834', 'I hate peas.'),
#  ('KAT', 'L831', "I know the porn career's a lie."),
#  ('KAT', 'L829', 'The duck?'),
#  ('PATRICK', 'L830', 'Hearsay.'),
#  ('PATRICK', 'L828', 'Fallacy.'),
#  ('KAT', 'L824', 'For. . . ?'),
#  ('KAT', 'L821', 'How?'),
#  ('KAT', 'L819', 'Something like that'),
#  ('KAT',
#   'L817',
#   "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change."),
#  ('KAT', 'L815', 'Acting the way we do.'),
#  ('KAT', 'L813', "Yeah, well, don't let it get out"),
#  ('PATRICK', 'L822', 'You never disappointed me.'),
#  ('PATRICK', 'L820', 'Then you screwed up'),
#  ('PATRICK',
#   'L818',
#   "So if you disappoint them from the start, you're covered?"),
#  ('PATRICK', 'L816', 'Yes'),
#  ('PATRICK', 'L814', "So what's your excuse?"),
#  ('KAT', 'L811', 'I dazzled him with my wit'),
#  ('KAT', 'L809', 'Good call.'),
#  ('PATRICK', 'L810', "So how'd you get Chapin to look the other way?"),
#  ('PATRICK',
#   'L808',
#   'I figured it had to be something ridiculous to win your respect.  And piss you off.'),
#  ('KAT', 'L804', 'You want me to climb up and show you how to get down?'),
#  ('PATRICK', 'L805', 'Maybe.'),
#  ('PATRICK', 'L803', "Forget it.  I'm stayin'."),
#  ('KAT', 'L800', "C'mon.  It's not that bad"),
#  ('PATRICK', 'L801', "Try lookin' at it from this angle"),
#  ('PATRICK', 'L798', 'Look up, sunshine'),
#  ('KAT', 'L773', 'Other than my upchuck reflex? Nothing.'),
#  ('KAT',
#   'L771',
#   "Don't for one minute think that you had any effect whatsoever on my panties."),
#  ('KAT', 'L769', 'Unwelcome.'),
#  ('PATRICK', 'L772', 'So what did I have an effect on ?'),
#  ('PATRICK',
#   'L770',
#   'Unwelcome?  I guess someone still has her panties in a twist.'),
#  ('KAT', 'L766', "You 're so --"),
#  ('KAT', 'L764', 'What are you doing here?'),
#  ('PATRICK', 'L767', 'Pleasant?'),
#  ('PATRICK', 'L765', 'I heard there was a poetry reading.'),
#  ('KAT', 'L688', 'BIANCA'),
#  ('KAT', 'L686', "He just wants me to be someone I'm not."),
#  ('PATRICK',
#   'L689',
#   "No offense, but you're sister is without.  I know everyone likes her and all, but ..."),
#  ('PATRICK', 'L687', 'Who?'),
#  ('PATRICK', 'L683', "I'm gettin' there"),
#  ('KAT', 'L680', "My father wouldn't approve of that that"),
#  ('PATRICK',
#   'L681',
#   "You don't strike me as the type that would ask permission."),
#  ('KAT', 'L678', 'This.'),
#  ('PATRICK', 'L677', 'Do what?'),
#  ('KAT', 'L675', "Why'd you lie?"),
#  ('KAT', 'L673', "No, you weren't"),
#  ('KAT', 'L671', 'Were you in jail?'),
#  ('PATRICK', 'L674', "Then why'd you ask?"),
#  ('PATRICK', 'L672', 'Maybe.'),
#  ('PATRICK', 'L670', 'Busy'),
#  ('KAT',
#   'L668',
#   "But it's Gigglepuss - I know you like them.  I saw you there."),
#  ('KAT', 'L650', 'What?'),
#  ('KAT', 'L645', 'You know what they say'),
#  ('KAT',
#   'L643',
#   'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?'),
#  ('KAT', 'L641', 'I hate him.'),
#  ('KAT', 'L639', 'Who?'),
#  ('PATRICK', 'L644', 'I thought you were above all that'),
#  ('PATRICK',
#   'L642',
#   "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type."),
#  ('PATRICK', 'L640', 'Dorsey.'),
#  ('KAT', 'L635', 'Just let me sit down.'),
#  ('KAT', 'L633', 'Like you could find one'),
#  ('KAT', 'L631', 'Why?'),
#  ('KAT', 'L629', "You don't care if I die"),
#  ('KAT', 'L627', "Why 're you doing this?"),
#  ('PATRICK',
#   'L634',
#   "See that?  Who needs affection when I've got blind hatred?"),
#  ('PATRICK',
#   'L632',
#   "Because then I'd have to start taking out girls who like me."),
#  ('PATRICK', 'L630', 'Sure, I do'),
#  ('PATRICK', 'L628', 'I told you'),
#  ('PATRICK',
#   'L626',
#   "Leave it to you to use big words when you're shitfaced."),
#  ('KAT', 'L614', 'I know, just let me sleep'),
#  ('KAT', 'L612', 'I just need to lie down for awhile'),
#  ('PATRICK',
#   'L615',
#   'What if you have a concussion? My dog went to sleep with a concussion and woke up a vegetable. Not that I could tell the difference...'),
#  ('PATRICK', 'L613', "Uh, uh. You lie down and you'll go to sleep"),
#  ('KAT', 'L610', "I'm fine. I'm"),
#  ('KAT', 'L566', "Funny, you're the only one"),
#  ('KAT',
#   'L564',
#   '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?'),
#  ('PATRICK', 'L565', 'I say, do what you wanna do.'),
#  ('KAT', 'L481', 'You know who The Raincoats are?'),
#  ('PATRICK', 'L482', "Why, don't you?"),
#  ('KAT', 'L475', "That's what you want, isn't it?"),
#  ('PATRICK', 'L476', "Do you mind?  You're sort of ruining it for me."),
#  ('KAT', 'L473', ''),
#  ('KAT',
#   'L333',
#   "Depends on the topic. My fenders don't really whip me into a verbal frenzy."),
#  ('KAT', 'L331', 'Hi'),
#  ('PATRICK',
#   'L330',
#   "I was in the laundromat. I saw your car. Thought I'd say hi."),
#  ('KAT', 'L326', 'You -- covered in my vomit.'),
#  ('KAT', 'L324', 'And why would I do that?'),
#  ('KAT', 'L322', "I don't really think you warrant that strong an emotion."),
#  ('PATRICK', 'L327', 'Seven-thirty?'),
#  ('PATRICK',
#   'L325',
#   'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...'),
#  ('PATRICK',
#   'L323',
#   "Then say you'll spend Dollar Night at the track with me."),
#  ('KAT',
#   'L311',
#   'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?'),
#  ('PATRICK', 'L312', 'I know a lot more than that'),
#  ('KAT', 'L309', 'Oh, right.  Friday.'),
#  ('KAT', 'L306', 'My mission in life.'),
#  ('KAT', 'L304', 'Sweating like a pig, actually.  And yourself?'),
#  ('PATRICK', 'L305', "There's a way to get a guy's attention."),
#  ('KAT', 'L998', 'When I go?'),
#  ('WALTER',
#   'L999',
#   "Oh, Christ.  Don't tell me you've changed your mind.  I already sent 'em a check."),
#  ('KAT', 'L995', "What's the matter?  Upset that I rubbed off on her?"),
#  ('KAT', 'L993', 'The part where Bianca beat the hell out of some guy.'),
#  ('KAT', 'L991', 'Parts of it.'),
#  ('KAT', 'L989', 'No, Daddy.'),
#  ('WALTER', 'L996', 'No -- impressed.'),
#  ('WALTER', 'L994', 'Bianca did what?'),
#  ('WALTER', 'L992', 'Which parts?'),
#  ('WALTER', 'L990', 'So tell me about this dance. Was it fun?'),
#  ('KAT', 'L986', 'Yeah.  She left with some bikers Big ones.  Full of sperm.'),
#  ('WALTER', 'L987', 'Funny.'),
#  ('KAT',
#   'L346',
#   'I want to go to an East Coast school! I want you to trust me to make my own choices.  I want --'),
#  ('KAT', 'L344', "So what I want doesn't matter?"),
#  ('KAT', 'L342', "Because you're making decisions for me."),
#  ('KAT', 'L340', 'I thought you were punishing me.'),
#  ('KAT', 'L338', 'Then tell them I had a seizure.'),
#  ('WALTER',
#   'L345',
#   "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it."),
#  ('WALTER', 'L343', "As a parent, that's my right"),
#  ('WALTER', 'L341', "Why can't we agree on this?"),
#  ('WALTER', 'L339', 'Is this about Sarah Lawrence? You punishing me?'),
#  ('WALTER', 'L184', 'Enough!'),
#  ('KAT', 'L173', 'You decided.'),
#  ('WALTER',
#   'L172',
#   'I thought we decided you were going to school here.  At U of 0.'),
#  ('MISS PERKY', 'L1017', 'Just smack her now.'),
#  ('MISS PERKY',
#   'L108',
#   'No ... I believe "heinous bitch" is the term used most often.'),
#  ('KAT',
#   'L105',
#   'I still maintain that he kicked himself in the balls.  I was merely a spectator.'),
#  ('KAT', 'L103', 'Expressing my opinion is not a terrorist action.'),
#  ('MISS PERKY',
#   'L106',
#   'The point is Kat -- people perceive you as somewhat ...'),
#  ('MISS PERKY',
#   'L104',
#   "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested."),
#  ('MICHAEL', 'L736', 'Kat a fan, too?'),
#  ('MANDELLA', 'L737', 'Yeah...'),
#  ('MANDELLA', 'L735', 'Right.'),
#  ('MICHAEL', 'L732', 'Oh yeah.'),
#  ('MICHAEL', 'L729', 'Cool pictures.  You a fan?'),
#  ('MANDELLA', 'L730', 'Yeah.  I guess.'),
#  ('MANDELLA', 'L728', 'Hi.'),
#  ('PATRICK',
#   'L776',
#   "Man -- don't say shit like that to  me. People can hear you."),
#  ('MICHAEL', 'L775', 'Sweet love, renew thy force!'),
#  ('PATRICK',
#   'L723',
#   "No - I've got a sweet-payin' job that I'm about to lose."),
#  ('PATRICK', 'L436', "I'm likin' you guys better"),
#  ('PATRICK', 'L428', 'Yeah.'),
#  ('MICHAEL', 'L420', 'Just for now.'),
#  ('MICHAEL', 'L414', 'Good enough.'),
#  ('MICHAEL', 'L383', "We're your guys."),
#  ('PATRICK', 'L380', 'So Dorsey can get the girl?'),
#  ('MICHAEL',
#   'L381',
#   "Patrick, Pat, you're not looking at the big picture.  Joey's just a pawn. We set this whole thing up so Cameron can get the girl."),
#  ('PATRICK',
#   'L378',
#   "Dorsey can plow whoever he wants. I'm just in this for the cash."),
#  ('PATRICK', 'L376', 'What is it with this chick?  She have three tits?'),
#  ('MICHAEL',
#   'L375',
#   'The situation is, my man Cameron here has a major jones for Bianca Stratford.'),
#  ('PATRICK',
#   'L372',
#   "Whatever the hell it is you're standin' there waitin' to say."),
#  ('MICHAEL', 'L371', 'What?'),
#  ('PATRICK', 'L511', 'See you next week!'),
#  ('PATRICK',
#   'L263',
#   "Well, you know -- there's the prestige of the job title... and the benefits package is pretty good..."),
#  ('PATRICK', 'L261', "What's to discuss?"),
#  ('MISS PERKY',
#   'L262',
#   "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?"),
#  ('PATRICK', 'L257', 'Touch of the flu.'),
#  ('MISS PERKY',
#   'L258',
#   "I'm at a loss, then.  What should we talk about? Your year of absence?"),
#  ('PATRICK', 'L60', 'It was a bratwurst.  I was eating lunch.'),
#  ('MISS PERKY', 'L61', 'With the teeth of your zipper?'),
#  ('MISS PERKY',
#   'L59',
#   'It says here you exposed yourself to a group of freshmen girls.'),
#  ('WALTER', 'L932', "That ' s what I thought"),
#  ('WALTER', 'L930', 'Did I have anything to say about it?'),
#  ('SHARON', 'L931', 'Absolutely not.'),
#  ('SHARON', 'L929', 'Your daughters went to the prom.'),
#  ('WALTER', 'L926', 'But -- who -- what --?'),
#  ('SHARON', 'L917', 'Dr. Ruth?'),
#  ('WALTER',
#   'L886',
#   "Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day."),
#  ('WALTER', 'L876', 'Pirate -- no question.'),
#  ('WALTER', 'L192', "You're not helping."),
#  ('SHARON', 'L191', 'Tumescent!'),
#  ('WALTER', 'L170', 'Sarah Lawrence is on the other side of the country.'),
#  ('WALTER', 'L161', 'Make anyone cry today?'),
#  ('ALONSO',
#   'L2180',
#   "Can't be that far, I say.  Also, I don't like the smell of the sea around here.  Smells like a cunt. Bad sign..."),
#  ('SAILOR', 'L2179', "We left three weeks ago, Alonso. Can't be that near."),
#  ('SAILOR', 'L2176', "We'll all go crazy..."),
#  ('ALONSO',
#   'L2174',
#   "With a face like that?  I don't want you looking at me.  You hear?"),
#  ('SAILOR', 'L2173', "Ah, leave him alone.  He's doing no harm."),
#  ('ALONSO',
#   'L2171',
#   "You'll be drinking your own piss... For the glory of Spain... and Admiral Colon...!  Bastard!"),
#  ('SAILOR', 'L2170', "The water's going putrid in the barrels."),
#  ('AROJAZ', 'L2024', 'IF-GOD-WILLS-IT!'),
#  ('COLUMBUS', 'L2022', 'Blind faith is what I consider heresy!'),
#  ('COLUMBUS',
#   'L2019',
#   "Did He not choose a carpenter's son to reveal Himself to the world?"),
#  ('AROJAZ', 'L2014', 'Is that all that interests you? Gold?'),
#  ('COLUMBUS',
#   'L2015',
#   'No.  The Portuguese have already discovered black-skinned people.  I, too, will find other populations -- and bring them to the word of God.'),
#  ('AROJAZ', 'L2010', 'Your life, and that of others!'),
#  ('COLUMBUS', 'L2011', 'If they agree to follow me, yes.'),
#  ('COLUMBUS', 'L2005', 'Excellency, you are right.'),
#  ('AROJAZ',
#   'L1992',
#   'Then you cannot ignore that according to their calculations, the circumference of the Earth is approximately...  22,000 leagues or more.  Which makes the ocean... uncrossable.'),
#  ('AROJAZ',
#   'L1990',
#   'Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?'),
#  ('COLUMBUS', 'L1991', 'I am, Your Eminence'),
#  ('COLUMBUS',
#   'L1989',
#   'Yes, your Eminence.  The voyage should not take more than six or seven weeks.'),
#  ('AROJAZ', 'L2522', 'What a tragedy... what a waste of a life...'),
#  ('SANCHEZ',
#   'L2523',
#   'A waste...?  Let me tell you something, Arojaz.  If your name, or mine, is ever remembered -- it will only be because of his.'),
#  ('SANCHEZ',
#   'L2274',
#   'On the contrary, Your Eminence.  It seems to me the man is preparing his own cross.'),
#  ('SANCHEZ',
#   'L2030',
#   'Indeed.  The world is full of mercenaries -- and states often make use of them, when it benefits them.  My only concern is the welfare and prosperity of Spain.'),
#  ('AROJAZ', 'L2027', 'The Judgment is ours!'),
#  ('SANCHEZ',
#   'L2028',
#   'Naturally.  But I would really deplore the loss of such a potential opportunity for Spain for a... dispute over a point of geography.'),
#  ('COLUMBUS',
#   'L2539',
#   "I can't keep my eyes off you.  I would like to catch up with all the moments I didn't spend with you."),
#  ('BEATRIX', 'L2537', 'I am busy inside.'),
#  ('COLUMBUS',
#   'L2473',
#   "Not everything... Do you think I care?  I'm a free man again.  Riches don't make a man rich, they only make him busier..."),
#  ('BEATRIX', 'L2471', "They tried... but I didn't let them."),
#  ('COLUMBUS',
#   'L2319',
#   'I can arrange for the Queen to take Fernando and Diego into her service.'),
#  ('BEATRIX', 'L2318', "You don't usually ask."),
#  ('COLUMBUS', 'L2121', "I don't want you to wait for me."),
#  ('BEATRIX', 'L2122', "That's something you can't decide."),
#  ('BEATRIX', 'L2118', 'Thank God...'),
#  ('BEATRIX', 'L1985', 'I find that hard to believe.'),
#  ('COLUMBUS', 'L1982', 'Are we going to argue?'),
#  ('COLUMBUS', 'L1980', "I haven't given you much of a life."),
#  ('BEATRIX',
#   'L1983',
#   "I'd love to argue with you sometimes.  But you're never here!"),
#  ('BEATRIX',
#   'L1981',
#   "Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving..."),
#  ('BEATRIX', 'L1979', 'I know.'),
#  ('COLUMBUS',
#   'L2430',
#   'How could I be?  The mainland has been found.  Exactly as I said it would.'),
#  ('BOBADILLA', 'L2431', 'I am afraid this is not the worst news.'),
#  ('BOBADILLA',
#   'L2429',
#   'I am not a seaman.  But I heard it is no more than a week at sea.  I hope you are not too disappointed.'),
#  ('COLUMBUS',
#   'L2425',
#   'Congratulations.  Then I am free to search for the mainland.'),
#  ('COLUMBUS', 'L2423', 'Appointment to what?'),
#  ('BOBADILLA', 'L2424', 'Viceroy of the West Indies.'),
#  ('COLUMBUS', 'L2421', 'Yes... I remember...'),
#  ('COLUMBUS', 'L2292', 'Bartolome and Giacomo Colon.'),
#  ('COLUMBUS',
#   'L2290',
#   'Forgive me, Don Bobadilla -- those positions have already been taken.'),
#  ('BOBADILLA', 'L2291', 'May I ask by whom?'),
#  ('COLUMBUS',
#   'L2550',
#   "Really?  God... I wouldn't know where to start... and yet..."),
#  ('FERNANDO', 'L2551', 'Tell me the first thing that comes to your mind.'),
#  ('COLUMBUS', 'L2548', 'He never had one... except aboard my ships!'),
#  ('FERNANDO',
#   'L2547',
#   'He asks when he can come to visit you.  He left his address.'),
#  ('FERNANDO',
#   'L2541',
#   "I am not listening, Father.  But I can't help hearing."),
#  ('COLUMBUS', 'L2500', 'There must be a passage to that other ocean.'),
#  ('FERNANDO', 'L2484', 'Not bad.'),
#  ('FERNANDO', 'L2439', 'This time with me!'),
#  ('COLUMBUS', 'L2130', 'Yes... Yes, I do... On all of them!'),
#  ('COLUMBUS', 'L2127', "There'll be a time."),
#  ('FERNANDO', 'L2128', 'You promise?  Do you swear on St. Christopher...?'),
#  ('COLUMBUS', 'L2468', 'All of them created by people like me.'),
#  ('SANCHEZ', 'L2467', 'Roofs... towers, palaces... spires...'),
#  ('COLUMBUS', 'L2465', 'Look out of that window.'),
#  ('COLUMBUS', 'L2463', 'Call them.'),
#  ('COLUMBUS', 'L2299', 'What...?  Do I have so many already?'),
#  ('SANCHEZ',
#   'L2300',
#   'To rise so high, in so short a time, is a dangerous occupation.  A little hypocrisy goes a long way.'),
#  ('COLUMBUS',
#   'L2296',
#   'Good!  We are also in need of judges.  Except there are no thieves!'),
#  ('SANCHEZ',
#   'L2295',
#   'Don Bobadilla is already a judge, my Dear Don Cristobal.'),
#  ('COLUMBUS', 'L2286', '... for a commoner?'),
#  ('SANCHEZ', 'L2281', 'Forgive me, Don Colon.  But what about gold?'),
#  ('SANCHEZ',
#   'L2109',
#   "If you won't accept our proposal, we'll simply find someone who will."),
#  ('COLUMBUS', 'L2106', "I'm not bargaining!"),
#  ('SANCHEZ', 'L2107', 'Then you are too ambitious.'),
#  ('COLUMBUS',
#   'L2104',
#   'NO...!  I have waited too long, fought too hard.  Now you expect me to take all the risks while you take the profit!  No... I will not be your servant!'),
#  ('SANCHEZ', 'L2103', 'No?'),
#  ('UTAPAN', 'L2409', 'You never learned how to speak my language.'),
#  ('UTAPAN', 'L2393', 'You did the same to your God!'),
#  ('COLUMBUS', 'L2342', 'Ask him if he will help.'),
#  ('UTAPAN', 'L2341', 'He understands.'),
#  ('COLUMBUS', 'L2259', 'He has medicine.  Tell him we admire his people.'),
#  ('COLUMBUS', 'L2257', '... and also to bring medicine.'),
#  ('UTAPAN', 'L2258', 'Chief says...'),
#  ('UTAPAN', 'L2256', 'Chief says -- he has a God.'),
#  ('COLUMBUS', 'L2253', 'Thousands.'),
#  ('UTAPAN', 'L2254', 'Why?'),
#  ('COLUMBUS',
#   'L2250',
#   'Tell him his country is very beautiful.  Tell him we are leaving men here -- to build a fort.'),
#  ('COLUMBUS', 'L2248', 'Tell the Chief we thank him.'),
#  ('UTAPAN', 'L2249', 'Chief knows.'),
#  ('COLUMBUS', 'L2237', 'What is it?  A tribe?  An island?'),
#  ('UTAPAN', 'L2238', 'Island.  Far.'),
#  ('COLUMBUS',
#   'L2534',
#   "I don't know... I have the impression that I didn't change that much.  I still can't accept the world as it is!"),
#  ('COLUMBUS', 'L2532', 'New worlds create new people.'),
#  ('MARCHENA', 'L2533', 'Oh?  So you are a new man?'),
#  ('MARCHENA', 'L2531', 'I knew you would.'),
#  ('COLUMBUS', 'L2525', "You'll always be older than me, Father."),
#  ('COLUMBUS', 'L2144', 'Give me absolution.'),
#  ('COLUMBUS', 'L2142', 'You are bound by an oath, Father.'),
#  ('COLUMBUS',
#   'L2140',
#   "If I tell them, they won't follow me.  You know that I am right, Father.  You trust me..."),
#  ('MARCHENA',
#   'L2141',
#   "My son, my son...  Your certitudes are sometimes frightening...  Christopher, you must speak to them. And if you don't I will."),
#  ('COLUMBUS', 'L2138', 'I am not sure... It could be twice the distance.'),
#  ('COLUMBUS', 'L2136', 'I lied.  The journey will be longer than I said.'),
#  ('COLUMBUS',
#   'L2134',
#   'Father, I have betrayed my family. I betrayed my men.  And I betrayed you.'),
#  ('MARCHENA', 'L2137', 'How long?'),
#  ('MARCHENA', 'L2135', 'What are you saying?'),
#  ('COLUMBUS', 'L2132', 'Forgive me, Father.  For I have sinned.'),
#  ('MARCHENA', 'L2045', "Colon!  Don't!"),
#  ('COLUMBUS',
#   'L2041',
#   'Damn all of you!  You all set up theories based on what?  You never leave the safety of your studies! Go out!  Find out what the world is about and then tell me something I can listen to!'),
#  ('COLUMBUS', 'L2039', 'Damn God!'),
#  ('COLUMBUS',
#   'L2037',
#   "Wait!  I've waited seven years already!  How much longer do you want me to wait?"),
#  ('MARCHENA', 'L2038', 'If God intends you to go, then you will go.'),
#  ('COLUMBUS', 'L1967', "I've been contradicted all my life... Eternity!"),
#  ('COLUMBUS', 'L1965', 'Passion is something one cannot control!'),
#  ('COLUMBUS', 'L1963', "I'll try to remember that, Marchena..."),
#  ('MARCHENA', 'L1968', 'Only God knows the meaning of such words, my son.'),
#  ('MARCHENA',
#   'L1966',
#   'You get so carried away when you are being contradicted!'),
#  ('MARCHENA', 'L1964', 'Father Marchena!'),
#  ('COLUMBUS', 'L1961', 'So was Christ!'),
#  ('COLUMBUS',
#   'L1959',
#   'The calculations of Toscanelli Marin de Tyr, Esdras...'),
#  ('COLUMBUS',
#   'L1957',
#   'Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.'),
#  ('MARCHENA', 'L1960', 'Esdras is a Jew.'),
#  ('MARCHENA', 'L1958', 'How can you be so certain?'),
#  ('COLUMBUS',
#   'L1951',
#   'To open a new route to Asia.  At the moment there are only two ways of reaching it...'),
#  ('COLUMBUS', 'L1948', 'How did you manage it?'),
#  ('MARCHENA',
#   'L1949',
#   'With some difficulty.  I had to promise them you were not a total fool.'),
#  ('MARCHENA', 'L1947', "That's what it says."),
#  ('COLUMBUS',
#   'L1942',
#   'Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.'),
#  ('COLUMBUS',
#   'L2458',
#   'Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.'),
#  ('COLUMBUS', 'L2456', 'Thank you.'),
#  ('ISABEL',
#   'L2457',
#   "There is one thing I'd like to understand... Why do you want to go back, after all this?"),
#  ('COLUMBUS',
#   'L2279',
#   'They come and go as naked as the day God created them...'),
#  ('COLUMBUS', 'L2085', 'Thirty seven, Your Majesty... And you?'),
#  ('COLUMBUS',
#   'L2080',
#   'I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...'),
#  ('ISABEL', 'L2081', 'A woman?'),
#  ('ISABEL', 'L2079', 'You show no inclination to speak otherwise!'),
#  ('COLUMBUS', 'L2076', 'Surely you can do anything you want.'),
#  ('COLUMBUS', 'L2073', 'What did they say about Granada before today?'),
#  ('ISABEL', 'L2074', 'That she was impregnable.'),
#  ('COLUMBUS',
#   'L2071',
#   'No more than the woman who said she would take Granada from the Moors.'),
#  ('COLUMBUS',
#   'L2387',
#   "You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?"),
#  ('MOXICA', 'L2388', 'You will regret this.'),
#  ('MOXICA', 'L2386', 'Savagery is what monkeys understand.'),
#  ('MOXICA', 'L2347', 'You did not hear me, Don Colon.  Not my horse.'),
#  ('MOXICA', 'L2345', "My horse doesn't work."),
#  ('COLUMBUS',
#   'L2332',
#   'We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.'),
#  ('MOXICA', 'L2331', "We don't need to know."),
#  ('COLUMBUS',
#   'L2328',
#   "If you want to keep your head on your shoulders, you'll do as I say."),
#  ('COLUMBUS', 'L2277', 'The Indians have no such word, Don Moxica.'),
#  ('COLUMBUS',
#   'L2490',
#   "He's drawing an isthmus... He's saying we're on an isthmus."),
#  ('MENDEZ', 'L2491', "We can't be."),
#  ('MENDEZ', 'L2164', 'Twenty eight.'),
#  ('COLUMBUS', 'L2159', 'Come over here.'),
#  ('COLUMBUS', 'L2157', 'And what do you think Mendez?'),
#  ('MENDEZ',
#   'L2158',
#   "Well, I surely know what a quadrant is!  But I've never seen it used at night before."),
#  ('MENDEZ', 'L2154', 'God be with us admiral.'),
#  ('COLUMBUS', 'L2210', "You're right.  Let the men decide."),
#  ('COLUMBUS',
#   'L2208',
#   'Pinzon, Pinzon... All we can do now is go forward!  Think about that!'),
#  ('COLUMBUS',
#   'L2206',
#   'You never did.  You did all the talking for both of us, remember?'),
#  ('COLUMBUS',
#   'L2204',
#   'And then what?  Half of the water has gone, the rest is nearly putrid! You know that!'),
#  ('COLUMBUS', 'L2202', 'The land is there.  I know it!'),
#  ('COLUMBUS', 'L2200', "You think I don't know that?"),
#  ('COLUMBUS', 'L2198', 'We have to keep the hopes of these men alive!'),
#  ('COLUMBUS', 'L2196', 'Six days ago, yes.'),
#  ('PINZON', 'L2209', 'You tell that to them!'),
#  ('PINZON', 'L2207', 'You bloody...'),
#  ('PINZON', 'L2205', 'Jesus Maria!  I should have never listened to you!'),
#  ('PINZON',
#   'L2203',
#   "You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!"),
#  ('PINZON', 'L2201', "We're lost!"),
#  ('PINZON', 'L2199', "We're on the verge of a mutiny, Colon!"),
#  ('PINZON', 'L2197', 'You must be mad...!'),
#  ('PINZON', 'L2064', 'Immediately.'),
#  ('SANCHEZ', 'L2460', 'Then why?'),
#  ('ISABEL', 'L2461', 'Because he is not afraid of me.'),
#  ('SANCHEZ', 'L2417', 'He must be replaced.'),
#  ('ISABEL', 'L2418', 'And who would you think of, for such a task?'),
#  ('ISABEL', 'L2414', 'Is this true, Brother Buyl?'),
#  ('ISABEL',
#   'L2376',
#   "We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time."),
#  ('ISABEL', 'L2115', "Yes.  It would be a pity, wouldn't it?  Call him back!"),
#  ('SANCHEZ', 'L2112', 'Never, Your Majesty.  Although...'),
#  ('SANCHEZ', 'L1930', 'Yes, Your Majesty.'),
#  ('CUTLER',
#   'L3545',
#   "Officers, there's your killer, do your duty, arrest him!"),
#  ('CUTLER', 'L3496', "I don't think it's abuse, I think it's torture."),
#  ('CUTLER', 'L3492', 'Can I see your back?'),
#  ('CUTLER', 'L3490', 'Your father put cigarettes out on you?'),
#  ('EMIL', 'L3491', 'Out on my back when I was a small boy.'),
#  ('CUTLER', 'L3487', "Your father blamed you for your mother's blindness?"),
#  ('CUTLER', 'L3485', 'Back in the Czech Republic?'),
#  ('CUTLER', 'L3483', 'Your mother was blind?'),
#  ('EMIL',
#   'L3488',
#   'Yeah, he hated me from day when I was born.  Put it out.  Can you put the cigarette out?'),
#  ('EMIL',
#   'L3486',
#   'Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...'),
#  ('EMIL',
#   'L3484',
#   'Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.'),
#  ('EMIL',
#   'L3482',
#   'My father always degraded me.  Killed my self-esteem.  And my mother was blind.'),
#  ('CUTLER',
#   'L3479',
#   "I need to know about your background.  I need to know about your upbringing.  Why you're here."),
#  ('CUTLER',
#   'L3477',
#   'This is not about money, Emil.  I need your trust in me.'),
#  ('CUTLER', 'L3475', "But it's..."),
#  ('CUTLER', 'L3473', 'I would say...half.  Half is fair.'),
#  ('CUTLER', 'L3471', "Look, I haven't really focused on that kind of thing."),
#  ('CUTLER', 'L3469', "Don't worry about him.  Think about yourself."),
#  ('CUTLER',
#   'L3467',
#   "Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia."),
#  ('CUTLER',
#   'L3465',
#   "Well, you didn't appreciate the severity of it until recently.  No question about that."),
#  ('EMIL', 'L3480', 'Give me another one, please.'),
#  ('EMIL', 'L3478', 'What else do you need?'),
#  ('EMIL',
#   'L3476',
#   "Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no."),
#  ('EMIL', 'L3474', 'No.  No way.'),
#  ('EMIL', 'L3472', "What's your cut?  How much?"),
#  ('EMIL', 'L3470', 'What about my movie rights?  Book rights?'),
#  ('EMIL', 'L3468', 'No, he is here.  Shit...'),
#  ('EMIL', 'L3466', 'What about Oleg?'),
#  ('EMIL', 'L3464', 'I was all of these.'),
#  ('CUTLER', 'L3460', 'Oh, sure.'),
#  ('EMIL', 'L3459', 'You bring the cigarettes?'),
#  ('CUTLER',
#   'L3395',
#   "I'm invoking rights - this man is represented by counsel.  I'm coming with him."),
#  ('CUTLER', 'L3393', "I'm coming with you."),
#  ('EMIL', 'L3394', 'Yes.  Yes, come with me!'),
#  ('EMIL', 'L3392', 'Where are we going?'),
#  ('CUTLER',
#   'L3383',
# ...
#  ('JORDY', 'L3220', "I took her there for a shower and that's it."),
#  ('EDDIE', 'L3221', 'Just a shower?'),
#  ('EDDIE',
#   'L3219',
#   "Well, you shoulda because nobody's gonna believe you didn't...including me."),
#  ('JORDY', 'L3080', "Hey.  I'm a professional."),
#  ('EDDIE',
#   'L3081',
#   'Women like that have a way of turning professionals into amateurs.'),
#  ('JORDY', 'L3078', "You know what I'm saying here."),
#  ('JORDY',
#   'L3076',
#   "C'mon.  You intimidate her 'cause you're a celebrity.  She sees me differently."),
#  ('JORDY', 'L3074', "I'm serious here."),
#  ('JORDY', 'L3072', "I don't have a girlfriend."),
#  ('JORDY', 'L3070', 'Yeah.'),
#  ('EDDIE',
#   'L3077',
#   "You're her Savior?  Is she the kid you're gonna save from the burning building?"),
#  ('EDDIE', 'L3075', 'So am I.'),
#  ('EDDIE', 'L3073', 'My point exactly.'),
#  ('EDDIE', 'L3071', 'What would your girlfriend think of that?'),
#  ('EDDIE', 'L3069', 'You wanna talk to her alone?'),
#  ('JORDY', 'L3067', 'Raw deal.'),
#  ('EDDIE', 'L3057', 'Something back home?'),
#  ('JORDY',
#   'L3052',
#   'She just saw two of her friends killed! They probably threatened her.'),
#  ('EDDIE', 'L3053', 'Is that all there is?'),
#  ('JORDY',
#   'L2997',
#   'I wanted to run up to a building on fire, kick in the door, rush into the smoke and save a kid.'),
#  ('JORDY', 'L2995', 'Of course.'),
#  ('JORDY', 'L2993', "I'm on duty."),
#  ('EDDIE',
#   'L2998',
#   "Then I guess we're doin' this the right way, aren't we?  If we pull up to a burning building I'll gladly let you go first."),
#  ('EDDIE',
#   'L2996',
#   "Hey!  I always wanted to be a cop when I was a kid.  I dreamed of running up to a door, kicking it in, pulling my gun and yelling 'Freeze!' at the bad guy! What'd you dream about?"),
#  ('EDDIE',
#   'L2994',
#   "So am I.  Alright, I'll go inside and you cover the back."),
#  ('JORDY',
#   'L2991',
#   "I'm on my way with Eddie.  Ludwig's. 63rd and Madison.  The suspects might be there already."),
#  ('EDDIE', 'L2962', 'Better than one.'),
#  ('JORDY', 'L2957', "I'll call it... tails."),
#  ('JORDY',
#   'L2955',
#   "This is ridiculous.  I'm not gonna be in your way - we can talk the case over."),
#  ('EDDIE',
#   'L2956',
#   "Tell you what - I'll flip you a coin. If you win you can come with me.  If you don't win, you don't come."),
#  ('JORDY', 'L2952', 'But what if it does?  You might need my help.'),
#  ('JORDY', 'L2950', 'Mind if I ride along with you?'),
#  ('EDDIE', 'L2951', 'This has nothing to do with your fire.'),
#  ('EDDIE', 'L2949', 'You got any better ideas?'),
#  ('JORDY', 'L2904', 'My folks are.'),
#  ('JORDY',
#   'L2902',
#   'My parents are from Poland.  I can help with the Eastern European angle.'),
#  ('JORDY', 'L2900', "I can watch you, Eddie.  Maybe I'll learn something."),
#  ('EDDIE', 'L2905', 'Stay here.'),
#  ('EDDIE', 'L2903', "You're Polish?"),
#  ('EDDIE', 'L2901', "This isn't homicide school."),
#  ('EDDIE',
#   'L2899',
#   "There wasn't a fire.  There'll be nothing for you to do."),
#  ('JORDY',
#   'L2896',
#   'Or Czechoslovakia.  The Slavs have been fighting the Germans and the Russians for a thousand years.  These are very intense people and they take things personally.'),
#  ('EDDIE', 'L2895', 'Eastern Europe.  Like what?  Romania? Hungary?'),
#  ('JORDY',
#   'L2892',
#   "Look, I'm not even sure she has anything to do with this.  I saw her outside after the fire - thought it was a lead. Maybe she saw something.  Maybe she was visiting somebody here.  Who knows?"),
#  ('JORDY', 'L2890', "Who says she's a suspect?"),
#  ('JORDY', 'L2888', 'Hmmmm.'),
#  ('EDDIE',
#   'L2889',
#   "Maybe you don't care about that either.  Prettiest suspect I've had in awhile."),
#  ('EDDIE', 'L2887', 'Pretty.'),
#  ('JORDY',
#   'L2884',
#   "If you found me steppin' on your crime scene - it might piss you off, too.  What about the report?"),
#  ('EDDIE',
#   'L2885',
#   "You were right, they were both dead before the fire.  The male was stabbed so hard the killer broke off the tip of the knife in his spine.  That's usually an indicator of something personal."),
#  ('EDDIE',
#   'L2883',
#   'Sure.  But I would like to ask you something.  You got a problem with me?'),
#  ('JORDY', 'L2880', "I don't even watch TV."),
#  ('JORDY', 'L2878', "Well, just so you know, I don't care about that stuff."),
#  ('JORDY', 'L2876', 'Nah, I musta missed it.'),
#  ('EDDIE', 'L2881', 'Good.  Good.  Commendable.'),
#  ('EDDIE', 'L2879', 'Nah, why should you?'),
#  ('EDDIE', 'L2877', 'Well, just so you know.  I gave you guys the credit.'),
#  ('EDDIE', 'L2875', 'Watch the news?'),
#  ('JORDY',
#   'L2747',
#   "Why don't you explain it, Bobby.  Hey Camello!  You mind punching a hole in the floor?"),
#  ('EDDIE', 'L2746', 'No, what is it?'),
#  ('EDDIE', 'L2730', "No, we don't mind.  You mind Leon?"),
#  ('EMIL',
#   'L3248',
#   "Smarter than Americans.  You're fed cry baby talk shows all day long.  Not only will Americans believe me, they'll cry for me.  So...Detective Eddie Flemming, would you like to say goodbye to your Nicolette? Maybe you can propose to her now?"),
#  ('EDDIE',
#   'L3243',
#   "If you kill me and film it you're putting a noose around your neck."),
#  ('EMIL',
#   'L3241',
#   'Good - be tough to the end.  Actor who plays you will want to die like hero.'),
#  ('EMIL', 'L3239', 'I kill someone famous.'),
#  ('EMIL',
#   'L3237',
#   'Your opinion.  You see, they going to make a movie about me, too, Eddie.  And write books.'),
#  ('EDDIE', 'L3240', 'Then do it, asshole.'),
#  ('EDDIE', 'L3238', "What's your accomplishment."),
#  ('EDDIE', 'L3236', 'What do you want?'),
#  ('EDDIE', 'L3156', "Don't be late."),
#  ('EDDIE', 'L3154', 'See you later.  Good luck.'),
#  ('EDDIE', 'L3152', 'Yeah, yeah.  Good thing.'),
#  ('EDDIE', 'L3150', 'Yeah.  I promise.'),
#  ('EDDIE', 'L3148', 'Tonight.'),
#  ('NICOLETTE', 'L3155', 'Thank you.'),
#  ('NICOLETTE', 'L3153', 'Okay.'),
#  ('NICOLETTE',
#   'L3151',
#   "Okay.  And you know what, I'll swing by my place, grab a couple pairs of shoes and maybe just test them out next to yours...How's that... Would that be a good thing."),
#  ('NICOLETTE', 'L3149', 'You promise?'),
#  ('EDDIE', 'L3145', 'Patronizing you... Nay, I love you.'),
#  ('EDDIE',
#   'L3143',
#   "I promise.  We'll talk.  You'll be great.  You'll be fine.  Go ahead, just imagine that, uh... Just look into the lens and imagine you're talking to me."),
#  ('EDDIE',
#   'L3141',
#   "I'll tell you tonight.  Let's do it tonight.  As soon as you get back we'll talk.  We'll talk."),
#  ('EDDIE', 'L3139', "No.  Go ahead.  You're gonna be great."),
#  ('EDDIE', 'L3137', "Well, that's great."),
#  ('EDDIE', 'L3135', "That's good."),
#  ('NICOLETTE', 'L3146', 'I love you.'),
#  ('NICOLETTE',
#   'L3144',
#   "Yeah.  I'll do that.  As long as you're not patronizing me."),
#  ('NICOLETTE', 'L3142', 'Promise?'),
#  ('NICOLETTE',
#   'L3140',
#   "No.  No, listen to me here.  I want to know what you're talking about.  You know, the shoe thing and the marriages and..."),
#  ('NICOLETTE',
#   'L3138',
#   "Okay.  That is great.  But I can't go now, we're in the middle of something here."),
#  ('NICOLETTE', 'L3136', 'Yeah.'),
#  ('EDDIE', 'L3128', 'Answer it.'),
#  ('EDDIE', 'L3126', 'Answer the phone.'),
#  ('NICOLETTE',
#   'L3129',
#   "Okay.  Okay.  Hold that thought just for a second.  They only call me when it's an emergency.  Just hold that thought.  Can you call back?"),
#  ('NICOLETTE', 'L3127', 'No.  Tell me what you want to say.'),
#  ('EDDIE', 'L3119', "Could be Leon's."),
#  ('NICOLETTE',
#   'L3120',
#   'Jesus.  And last week you came over with blood on your shoes.  What am I going to do with you?'),
#  ('EDDIE', 'L3115', "You're ruthless."),
#  ('EDDIE',
#   'L3113',
#   "You were merciless.  You didn't give a shit if you got me or not."),
#  ('EDDIE',
#   'L3111',
#   'Yeah, well you took the camera and put it right down on the evidence.  That was...'),
#  ('EDDIE', 'L3109', "I'm not."),
#  ('EDDIE',
#   'L3107',
#   'Maybe I should just, ya know...turn to the cameras and say, do you mind if we just work something out?'),
#  ('EDDIE', 'L3105', "Oh, I'm sorry.  Did I embarrass you, sweetheart?  Oh..."),
#  ('EDDIE',
#   'L3103',
#   "I can't...I can't answer you just because you want me to answer you!"),
#  ('NICOLETTE', 'L3116', "You're not so bad yourself."),
#  ('NICOLETTE',
#   'L3114',
#   'Well, who was it that taught me how to do that?  Huh?'),
#  ('NICOLETTE', 'L3112', 'That was good.  You were holding the evidence.'),
#  ('NICOLETTE',
#   'L3110',
#   "Yes you are.  I'm not just some reporter.  I don't just stick a microphone in your face.  You could give me something."),
#  ('NICOLETTE', 'L3108', "Alright, alright, Eddie.  Don't patronize me."),
#  ('NICOLETTE', 'L3106', 'Stop it.'),
#  ('NICOLETTE',
#   'L3104',
#   "You didn't have to embarrass me in front of my colleagues.  You could give me something."),
#  ('EDDIE', 'L3101', 'Hey.'),
#  ('EDDIE', 'L3042', 'Alright.'),
#  ('EDDIE', 'L3040', 'Alright?'),
#  ('EDDIE', 'L3038', "Yeah.  Now's not a good time."),
#  ('NICOLETTE', 'L3043', 'Okay.'),
#  ('NICOLETTE', 'L3041', 'Alright.'),
#  ('NICOLETTE', 'L3039', 'Alright.'),
#  ('EDDIE',
#   'L3035',
#   "Um...now is not a good time, okay. Detective Jackson's hurt.  He's fine. I've got a Fire Marshall shot, Detective Jackson is hurt but not seriously."),
#  ('EDDIE', 'L3033', "He was hurt, but not seriously.  He'll be fine."),
#  ('EDDIE',
#   'L3031',
#   "I really can't give out any information right now at this point."),
#  ('NICOLETTE', 'L3036', 'Alright, cut, cut, cut.'),
#  ('NICOLETTE', 'L3034', 'Do you have the suspect in custody?'),
#  ('NICOLETTE',
#   'L3032',
#   "Okay.  But I do understand that your partner, Leon Jackson's been injured. Is that correct?"),
#  ('EDDIE',
#   'L3029',
#   "I can't talk right now.  We have some things to take care of."),
#  ('EDDIE', 'L2764', "We don't know.  When I have more I'll let you know."),
#  ('EDDIE', 'L2762', "You know you can't do that.  C'mon."),
#  ('EDDIE', 'L2760', 'There are two bodies found at this point.'),
#  ('EDDIE',
#   'L2758',
#   "We don't know that yet.  It's much too early.  There's a lot to be done."),
#  ('NICOLETTE', 'L2763', 'Is it drug related?'),
#  ('NICOLETTE', 'L2761', 'Can we go up to the crime scene?'),
#  ('NICOLETTE', 'L2759', 'How many victims are up there?'),
#  ('EDDIE', 'L2664', "Again?  I didn't wanna do it the first time."),
#  ('EDDIE', 'L2655', 'Yeah, yeah.  Jesus.'),
#  ('EDDIE', 'L2653', 'Keep them out of my way.'),
#  ('HAWKINS', 'L2654', 'Okay.  You ready?'),
#  ('HAWKINS', 'L2651', "You're worried for my safety.  I'm touched."),
#  ('EDDIE', 'L2647', 'Yeah.  And he still went to the party.'),
#  ('HAWKINS', 'L2646', "That's unique."),
#  ('EDDIE', 'L2644', 'Not what.  Who.'),
#  ('HAWKINS',
#   'L2611',
#   "My kids?  Let's see...Susan's 15. Aundrea's 9.  Don't tell me you're thinking about having a kid!  How old are you?  Never mind. Let me just tell you this: Every stupid cliche you hear about kids - they change your life, they make you a better person, they make you whole...  It's all true!  Before I had kids when friends talked about their kids, I wanted to vomit.  Now -- I get it.  Am I right, Leon?"),
#  ('EDDIE', 'L2606', "I'm not moody."),
#  ('EDDIE',
#   'L2604',
#   'Not chopped up.  Not chopped up like that.  I mean, what do I got left? Coupla articles.  A medal or two. Plaque here and there and in a coupla years no one remembers me anymore.'),
#  ('HAWKINS', 'L2605', "I think you're getting a little moody there, Eddie."),
#  ('HAWKINS', 'L2595', 'Jesus Christ.'),
#  ('EMIL', 'L2627', 'No.  Are you proposing?'),
#  ('EMIL', 'L2625', 'Dog food.'),
#  ('EMIL', 'L2623', 'You stuff sausage in it.'),
#  ('EMIL', 'L2621', 'I am butcher.'),
#  ('SECONDARY OFFICER', 'L2624', 'And what do you do with the bones?'),
#  ('SECONDARY OFFICER',
#   'L2622',
#   "You're a butcher?  What do you use pig intestines for?"),
#  ('EMIL',
#   'L3285',
#   "Come alone.  Bring cash.  And we'll talk about surrendering."),
#  ('EMIL',
#   'L3283',
#   "If you don't want my film - I'll call another show.  And they will show it."),
#  ('EMIL',
#   'L3281',
#   "We'll talk about that.  Four o'clock gives you time to go to bank.  Three hundred thousand dollars."),
#  ('EMIL', 'L3279', "No.  I'm the best that's ever threatened you."),
#  ('HAWKINS', 'L3284', 'Wait a minute.  Wait a minute.'),
#  ('HAWKINS', 'L3282', "What?  It doesn't work that way."),
#  ('HAWKINS',
#   'L3280',
#   "I'll meet you on one condition - I get exclusivity and you surrender to me."),
#  ('HAWKINS',
#   'L3278',
#   "Look asshole.  I've been threatened by better than you."),
#  ('EMIL', 'L3555', "If he doesn't lower his gun I'll fucking kill her."),
#  ('JORDY', 'L3554', 'Let her go!  Let her go!!'),
#  ('EMIL',
#   'L3435',
#   "The Sheraton!  On Broadway!  Room 210. Go get Oleg.  He'll kill you."),
#  ('JORDY', 'L3433', 'Get down on your knees.'),
#  ('JORDY', 'L3431', "You'll be my first."),
#  ('EMIL',
#   'L3419',
#   "My father was.  He gave me many lessons about fire.  Now it's my friend."),
#  ('JORDY', 'L3420', 'Tommy, take a walk.'),
#  ('HONEY',
#   'L2857',
#   "Alright, alright - don't hurt me! Please, it's in my book, in my purse!"),
#  ('HONEY',
#   'L2855',
#   "Look, man, I don't give a shit if you want sex or not, but you're payin' for my time."),
#  ('EMIL',
#   'L2852',
#   'I like to talk to the person who runs the service.  Can you give me address?'),
#  ('EMIL', 'L2850', 'Where is escort service?'),
#  ('HONEY',
#   'L2853',
#   "Look.  Do we have a problem here? There's no reason to have a problem. I'm gonna make you feel real good.  You wanna Czech girl? After I'm done with you, you won't miss her.  Now why don't you pay me?"),
#  ('HONEY',
#   'L2851',
#   "That's confidential.  Could you put the money on the dresser?"),
#  ('EMIL', 'L2848', 'I ordered a Czech girl.  Daphne, you know her?'),
#  ('EMIL', 'L2845', "Where's Czech girl?"),
#  ('HONEY',
#   'L2846',
#   "Baby, I'm anybody you want me to be. I'm a little schoolgirl, I'm mommy, I'm a Czech girl."),
#  ('EMIL', 'L2580', "He doesn't speak English."),
#  ('EMIL', 'L2578', 'Two weeks.'),
#  ('IMMIGRATION OFFICER', 'L2579', "I'd like to speak for himself, okay?"),
#  ('IMMIGRATION OFFICER', 'L2577', 'How long are you planning to stay?'),
#  ('EMIL', 'L2572', 'Is there a problem?'),
#  ('EMIL', 'L2570', 'Yes.'),
#  ('IMMIGRATION OFFICER',
#   'L2573',
#   "No, you're travelling together.  I want to talk to you together.  Hi, how are you?  Can I take a look at your documents?  Are you related?"),
#  ('IMMIGRATION OFFICER', 'L2571', 'Please join us.  Come on forward.'),
#  ('EMIL', 'L2567', 'I have five-hundred dollars.'),
#  ('EMIL', 'L2565', 'Two weeks holiday.'),
#  ('IMMIGRATION OFFICER',
#   'L2568',
#   'Can you show me?  Sir, no cameras in the FIS area!'),
#  ('IMMIGRATION OFFICER', 'L2566', 'How much money are you carrying with you?'),
#  ('EMIL', 'L2563', 'Yes sir.'),
#  ('EMIL', 'L2914', 'Yes.  Both.'),
#  ('EMIL',
#   'L2912',
#   'Million?!  The killer gets one million dollars for a television interview?'),
#  ('EMIL', 'L2910', 'Do you know how much killer gets for movie rights?'),
#  ('VENDOR',
#   'L2913',
#   'Hey, tabloids paid Ted Bundy - famous serial killer - half a million for his interview.  And how much you think Monica got for writing book about the President coming on to her?  It pays to be a killer or a whore in this country. Look, you want magazine or not?'),
#  ('VENDOR', 'L2911', 'In here, says he wants a million.'),
#  ('VENDOR', 'L2908', "New York's finest.  This is his case."),
#  ('OLEG',
#   'L3547',
#   'No.  You are the traitor.  You are murderer.  I am director.  Action!'),
#  ('EMIL',
#   'L3377',
#   'You think you are a director?  You are a fucking little, small Russian piece of shit.  And I hate you.  I fucking hate you.'),
#  ('OLEG', 'L3376', "No, I don't get that!"),
#  ('EMIL',
#   'L3374',
#   "Yes.  But there's only one problem - you want credit but the problem is - I don't share credit."),
#  ('EMIL', 'L3372', 'Credit?'),
#  ('OLEG',
#   'L3373',
#   'Yes.  Before we hand in the next video - I put titles on it and my credit is going to read - Directed by Oleg Razgul.'),
#  ('EMIL', 'L3369', 'Your idea?  I thought it was my idea.'),
#  ...]

# %%
json_edges=[]

#   Creating a list of dictionaries containing the source, target, and text of each edge.

for source, target, text in edges:
    json_edges.append({"source": source, "target": target, "text": text})
    
json_edges
# Out:
# [{'source': 'BIANCA', 'target': 'L1044', 'text': 'They do not!'},
#  {'source': 'BIANCA', 'target': 'L984', 'text': 'I hope so.'},
#  {'source': 'BIANCA', 'target': 'L924', 'text': "Let's go."},
#  {'source': 'BIANCA',
#   'target': 'L871',
#   'text': "Okay -- you're gonna need to learn how to lie."},
#  {'source': 'CAMERON', 'target': 'L870', 'text': 'No'},
#  {'source': 'BIANCA',
#   'target': 'L868',
#   'text': 'Like my fear of wearing pastels?'},
#  {'source': 'BIANCA', 'target': 'L866', 'text': 'What good stuff?'},
#  {'source': 'CAMERON', 'target': 'L867', 'text': 'The "real you".'},
#  {'source': 'BIANCA',
#   'target': 'L863',
#   'text': "Me.  This endless ...blonde babble. I'm like, boring myself."},
#  {'source': 'CAMERON',
#   'target': 'L864',
#   'text': 'Thank God!  If I had to hear one more story about your coiffure...'},
#  {'source': 'CAMERON', 'target': 'L862', 'text': 'What crap?'},
#  {'source': 'CAMERON', 'target': 'L860', 'text': 'No...'},
#  {'source': 'BIANCA', 'target': 'L697', 'text': 'But'},
#  {'source': 'CAMERON',
#   'target': 'L698',
#   'text': 'You always been this selfish?'},
#  {'source': 'CAMERON',
#   'target': 'L696',
#   'text': "Then that's all you had to say."},
#  {'source': 'BIANCA', 'target': 'L693', 'text': 'I was?'},
#  {'source': 'CAMERON',
#   'target': 'L694',
#   'text': "You never wanted to go out with 'me, did you?"},
#  {'source': 'BIANCA', 'target': 'L662', 'text': 'Tons'},
#  {'source': 'CAMERON',
#   'target': 'L577',
#   'text': 'I believe we share an art instructor'},
#  {'source': 'CAMERON',
#   'target': 'L575',
#   'text': 'Looks like things worked out tonight, huh?'},
#  {'source': 'BIANCA',
#   'target': 'L406',
#   'text': "Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes."},
#  {'source': 'BIANCA',
#   'target': 'L404',
#   'text': "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies."},
#  {'source': 'CAMERON',
#   'target': 'L405',
#   'text': "So that's the kind of guy she likes? Pretty ones?"},
#  {'source': 'BIANCA',
#   'target': 'L401',
#   'text': "I really, really, really wanna go, but I can't.  Not unless my sister goes."},
#  {'source': 'CAMERON',
#   'target': 'L402',
#   'text': "I'm workin' on it. But she doesn't seem to be goin' for him."},
#  {'source': 'BIANCA',
#   'target': 'L367',
#   'text': "Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment."},
#  {'source': 'BIANCA', 'target': 'L365', 'text': "You're sweet."},
#  {'source': 'BIANCA',
#   'target': 'L363',
#   'text': "I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?"},
#  {'source': 'BIANCA', 'target': 'L280', 'text': 'Where?'},
#  {'source': 'CAMERON',
#   'target': 'L276',
#   'text': "Well, there's someone I think might be --"},
#  {'source': 'BIANCA', 'target': 'L274', 'text': 'Forget French.'},
#  {'source': 'BIANCA',
#   'target': 'L272',
#   'text': "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone."},
#  {'source': 'CAMERON',
#   'target': 'L273',
#   'text': "That's because it's such a nice one."},
#  {'source': 'CAMERON',
#   'target': 'L271',
#   'text': "Right.  See?  You're ready for the quiz."},
#  {'source': 'CAMERON', 'target': 'L207', 'text': 'Let me see what I can do.'},
#  {'source': 'BIANCA',
#   'target': 'L204',
#   'text': 'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.'},
#  {'source': 'CAMERON', 'target': 'L205', 'text': "That's a shame."},
#  {'source': 'BIANCA',
#   'target': 'L201',
#   'text': "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does."},
#  {'source': 'CAMERON',
#   'target': 'L202',
#   'text': 'Seems like she could get a date easy enough...'},
#  {'source': 'CAMERON', 'target': 'L200', 'text': 'Cameron.'},
#  {'source': 'CAMERON', 'target': 'L198', 'text': 'Forget it.'},
#  {'source': 'BIANCA',
#   'target': 'L195',
#   'text': 'Not the hacking and gagging and spitting part.  Please.'},
#  {'source': 'CAMERON',
#   'target': 'L196',
#   'text': "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?"},
#  {'source': 'CAMERON',
#   'target': 'L194',
#   'text': "Well, I thought we'd start with pronunciation, if that's okay with you."},
#  {'source': 'BIANCA', 'target': 'L952', 'text': 'I did.'},
#  {'source': 'CHASTITY',
#   'target': 'L659',
#   'text': "I don't have to be home 'til two."},
#  {'source': 'BIANCA',
#   'target': 'L598',
#   'text': "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?"},
#  {'source': 'CHASTITY',
#   'target': 'L599',
#   'text': "All I know is -- I'd give up my private line to go out with a guy like Joey."},
#  {'source': 'BIANCA',
#   'target': 'L596',
#   'text': "Combination.  I don't know -- I thought he'd be different.  More of a gentleman..."},
#  {'source': 'CHASTITY', 'target': 'L595', 'text': 'Is he oily or dry?'},
#  {'source': 'BIANCA',
#   'target': 'L579',
#   'text': 'Would you mind getting me a drink, Cameron?'},
#  {'source': 'BIANCA', 'target': 'L572', 'text': 'Joey.'},
#  {'source': 'CHASTITY', 'target': 'L571', 'text': 'Who?'},
#  {'source': 'BIANCA',
#   'target': 'L50',
#   'text': 'You might wanna think about it'},
#  {'source': 'CHASTITY', 'target': 'L49', 'text': 'No.'},
#  {'source': 'BIANCA',
#   'target': 'L759',
#   'text': "You know the deal.  I can ' t go if Kat doesn't go --"},
#  {'source': 'BIANCA', 'target': 'L756', 'text': 'Hi, Joey.'},
#  {'source': 'JOEY',
#   'target': 'L757',
#   'text': "You're concentrating awfully hard considering it's gym class."},
#  {'source': 'JOEY',
#   'target': 'L592',
#   'text': "My agent says I've got a good shot at being the Prada guy next year."},
#  {'source': 'BIANCA', 'target': 'L589', 'text': 'Queen Harry?'},
#  {'source': 'JOEY',
#   'target': 'L590',
#   'text': "It's a gay cruise line, but I'll be, like, wearing a uniform and stuff."},
#  {'source': 'BIANCA', 'target': 'L396', 'text': 'Hopefully.'},
#  {'source': 'BIANCA', 'target': 'L394', 'text': 'Expensive?'},
#  {'source': 'KAT', 'target': 'L1051', 'text': 'Perm?'},
#  {'source': 'KAT', 'target': 'L1021', 'text': "It's just you."},
#  {'source': 'BIANCA', 'target': 'L1010', 'text': 'No! I just wanted'},
#  {'source': 'BIANCA', 'target': 'L1008', 'text': 'I just wanted --'},
#  {'source': 'KAT',
#   'target': 'L1009',
#   'text': 'What? To completely damage me?  To send me to therapy forever? What?'},
#  {'source': 'KAT', 'target': 'L1007', 'text': 'You set me up.'},
#  {'source': 'KAT', 'target': 'L982', 'text': 'So did you'},
#  {'source': 'BIANCA',
#   'target': 'L913',
#   'text': "I guess I'll never know, will I?"},
#  {'source': 'BIANCA',
#   'target': 'L911',
#   'text': "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself"},
#  {'source': 'BIANCA',
#   'target': 'L909',
#   'text': "I'm not stupid enough to repeat your mistakes."},
#  {'source': 'KAT',
#   'target': 'L912',
#   'text': "Not all experiences are good, Bianca. You can't always trust the people you want to."},
#  {'source': 'KAT',
#   'target': 'L910',
#   'text': 'I guess I thought I was protecting you.'},
#  {'source': 'BIANCA',
#   'target': 'L907',
#   'text': "No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage."},
#  {'source': 'BIANCA', 'target': 'L905', 'text': "Why didn't you tell me?"},
#  {'source': 'KAT',
#   'target': 'L906',
#   'text': 'I wanted to let you make up your own mind about him.'},
#  {'source': 'KAT',
#   'target': 'L904',
#   'text': 'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --'},
#  {'source': 'BIANCA', 'target': 'L901', 'text': 'You did what?'},
#  {'source': 'KAT',
#   'target': 'L902',
#   'text': "Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me."},
#  {'source': 'BIANCA', 'target': 'L899', 'text': 'As in...'},
#  {'source': 'BIANCA', 'target': 'L897', 'text': 'But you hate Joey'},
#  {'source': 'BIANCA', 'target': 'L895', 'text': 'Why?'},
#  {'source': 'BIANCA', 'target': 'L893', 'text': 'What?'},
#  {'source': 'KAT',
#   'target': 'L898',
#   'text': 'Now I do.  Back then, was a different story.'},
#  {'source': 'KAT', 'target': 'L896', 'text': 'He was, like, a total babe'},
#  {'source': 'KAT', 'target': 'L894', 'text': 'In 9th.  For a month'},
#  {'source': 'BIANCA',
#   'target': 'L891',
#   'text': "I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t."},
#  {'source': 'BIANCA', 'target': 'L889', 'text': 'Like you care.'},
#  {'source': 'KAT',
#   'target': 'L890',
#   'text': "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s ."},
#  {'source': 'KAT', 'target': 'L655', 'text': "You're welcome."},
#  {'source': 'BIANCA',
#   'target': 'L601',
#   'text': "I really don't think I need any social advice from you right now."},
#  {'source': 'KAT', 'target': 'L542', 'text': 'Can we go now?'},
#  {'source': 'BIANCA',
#   'target': 'L532',
#   'text': "Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too."},
#  {'source': 'KAT',
#   'target': 'L531',
#   'text': "It's Shakespeare.  Maybe you've heard of him?"},
#  {'source': 'KAT',
#   'target': 'L529',
#   'text': "At least I'm not a clouted fen- sucked hedge-pig."},
#  {'source': 'BIANCA',
#   'target': 'L526',
#   'text': "Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that."},
#  {'source': 'KAT', 'target': 'L525', 'text': "What's normal?"},
#  {'source': 'BIANCA',
#   'target': 'L444',
#   'text': "I think you're a freak.  I think you do this to torture me.  And I think you suck."},
#  {'source': 'BIANCA',
#   'target': 'L442',
#   'text': "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?"},
#  {'source': 'KAT', 'target': 'L443', 'text': 'What do you think?'},
#  {'source': 'KAT',
#   'target': 'L441',
#   'text': "It means that Gigglepuss is playing at Club Skunk and we're going."},
#  {'source': 'BIANCA',
#   'target': 'L319',
#   'text': 'Can you at least start wearing a bra?'},
#  {'source': 'BIANCA', 'target': 'L164', 'text': 'Nowhere... Hi, Daddy.'},
#  {'source': 'BIANCA',
#   'target': 'L922',
#   'text': "I have a date, Daddy.  And he ' s not a captain of oppression like some men we know."},
#  {'source': 'BIANCA',
#   'target': 'L883',
#   'text': "Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!"},
#  {'source': 'BIANCA',
#   'target': 'L881',
#   'text': 'He\'s not a "hot rod".  Whatever that is.'},
#  {'source': 'BIANCA', 'target': 'L879', 'text': 'No, but'},
#  {'source': 'WALTER',
#   'target': 'L882',
#   'text': "You're not going unless your sister goes.  End of story."},
#  {'source': 'WALTER',
#   'target': 'L880',
#   'text': "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?"},
#  {'source': 'WALTER', 'target': 'L878', 'text': 'The prom?  Kat has a date?'},
#  {'source': 'BIANCA', 'target': 'L544', 'text': 'Why?'},
#  {'source': 'WALTER',
#   'target': 'L545',
#   'text': "Because she'll scare them away."},
#  {'source': 'BIANCA', 'target': 'L538', 'text': 'Daddy, no!'},
#  {'source': 'WALTER', 'target': 'L539', 'text': 'Just for a minute'},
#  {'source': 'BIANCA', 'target': 'L536', 'text': "It's just a party. Daddy."},
#  {'source': 'WALTER',
#   'target': 'L523',
#   'text': "If Kat's not going, you're not going."},
#  {'source': 'BIANCA',
#   'target': 'L520',
#   'text': 'It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --'},
#  {'source': 'BIANCA',
#   'target': 'L518',
#   'text': 'If you must know, we were attempting to go to a small study group of friends.'},
#  {'source': 'WALTER', 'target': 'L519', 'text': 'Otherwise known as an orgy?'},
#  {'source': 'WALTER', 'target': 'L517', 'text': "And where're you going?"},
#  {'source': 'WALTER', 'target': 'L189', 'text': 'Exactly my point'},
#  {'source': 'BIANCA',
#   'target': 'L182',
#   'text': "But it's not fair -- she's a mutant, Daddy!"},
#  {'source': 'BIANCA',
#   'target': 'L180',
#   'text': 'What if she never starts dating?'},
#  {'source': 'WALTER',
#   'target': 'L181',
#   'text': "Then neither will you.  And I'll get to sleep at night."},
#  {'source': 'WALTER',
#   'target': 'L179',
#   'text': "No! You're not dating until your sister starts dating.  End of discussion."},
#  {'source': 'BRUCE', 'target': 'L462', 'text': "Just sent 'em through."},
#  {'source': 'BRUCE', 'target': 'L460', 'text': 'Never'},
#  {'source': 'BRUCE',
#   'target': 'L458',
#   'text': "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?"},
#  {'source': 'PATRICK',
#   'target': 'L461',
#   'text': 'Padua girls.  One tall, decent body. The other one kinda short and undersexed?'},
#  {'source': 'PATRICK',
#   'target': 'L459',
#   'text': 'Fan of a fan.  You see a couple of minors come in?'},
#  {'source': 'MICHAEL',
#   'target': 'L778',
#   'text': "Best case scenario, you're back on the payroll for awhile."},
#  {'source': 'CAMERON', 'target': 'L585', 'text': "No, I ' m not."},
#  {'source': 'CAMERON',
#   'target': 'L583',
#   'text': "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?"},
#  {'source': 'MICHAEL',
#   'target': 'L584',
#   'text': "Buttholus extremus.  But hey, you're making progress."},
#  {'source': 'CAMERON',
#   'target': 'L499',
#   'text': "Hell, I've just been going over the whole thing in my head and -"},
#  {'source': 'CAMERON', 'target': 'L432', 'text': "It's her favorite band."},
#  {'source': 'CAMERON', 'target': 'L424', 'text': "Okay!  I wasn't sure"},
#  {'source': 'CAMERON', 'target': 'L417', 'text': 'Her favorite uncle'},
#  {'source': 'MICHAEL', 'target': 'L418', 'text': 'Dead at forty-one.'},
#  {'source': 'MICHAEL', 'target': 'L416', 'text': "It's a lung cancer issue"},
#  {'source': 'CAMERON', 'target': 'L389', 'text': 'Will Bogey get bent?'},
#  {'source': 'MICHAEL',
#   'target': 'L390',
#   'text': "Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass."},
#  {'source': 'MICHAEL',
#   'target': 'L388',
#   'text': "In that case, we'll need to make it a school-wide blow out."},
#  {'source': 'MICHAEL',
#   'target': 'L244',
#   'text': "Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca."},
#  {'source': 'CAMERON',
#   'target': 'L223',
#   'text': 'I thought you hated those people.'},
#  {'source': 'MICHAEL',
#   'target': 'L224',
#   'text': "Hey -- I've gotta have a few clients when I get to Wall Street."},
#  {'source': 'CAMERON', 'target': 'L221', 'text': "That's what I just said"},
#  {'source': 'CAMERON',
#   'target': 'L219',
#   'text': "Forget his reputation.  Do you think we've got a plan or not?"},
#  {'source': 'CAMERON',
#   'target': 'L217',
#   'text': 'They always let felons sit in on Honors Biology?'},
#  {'source': 'CAMERON',
#   'target': 'L215',
#   'text': 'He seems like he thrives on danger'},
#  {'source': 'MICHAEL',
#   'target': 'L220',
#   'text': "Did she actually say she'd go out with you?"},
#  {'source': 'MICHAEL',
#   'target': 'L218',
#   'text': "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers."},
#  {'source': 'MICHAEL',
#   'target': 'L216',
#   'text': "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz..."},
#  {'source': 'MICHAEL', 'target': 'L212', 'text': 'You wanna go out with him?'},
#  {'source': 'MICHAEL',
#   'target': 'L210',
#   'text': "Unlikely, but even so, she still can't go out with you.  So what's the point?"},
#  {'source': 'CAMERON',
#   'target': 'L157',
#   'text': "That's her?  Bianca's sister?"},
#  {'source': 'MICHAEL',
#   'target': 'L158',
#   'text': 'The mewling, rampalian wretch herself.'},
#  {'source': 'CAMERON',
#   'target': 'L145',
#   'text': "You mean I'd get a chance to talk to her?"},
#  {'source': 'CAMERON',
#   'target': 'L143',
#   'text': "Sure do ... my Mom's from Canada"},
#  {'source': 'MICHAEL',
#   'target': 'L146',
#   'text': 'You could consecrate with her, my friend.'},
#  {'source': 'MICHAEL',
#   'target': 'L144',
#   'text': 'Guess who just signed up for a tutor?'},
#  {'source': 'CAMERON',
#   'target': 'L140',
#   'text': 'He always have that shit-eating grin?'},
#  {'source': 'MICHAEL',
#   'target': 'L141',
#   'text': "Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out."},
#  {'source': 'MICHAEL',
#   'target': 'L139',
#   'text': "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted."},
#  {'source': 'CAMERON', 'target': 'L90', 'text': 'Why not?'},
#  {'source': 'CAMERON', 'target': 'L88', 'text': 'Who is she?'},
#  {'source': 'MICHAEL',
#   'target': 'L91',
#   'text': "I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility."},
#  {'source': 'MICHAEL',
#   'target': 'L89',
#   'text': "Bianca Stratford.  Sophomore. Don't even think about it"},
#  {'source': 'MICHAEL',
#   'target': 'L87',
#   'text': 'You burn, you pine, you perish?'},
#  {'source': 'MICHAEL',
#   'target': 'L77',
#   'text': 'Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.'},
#  {'source': 'CAMERON', 'target': 'L72', 'text': 'How many people go here?'},
#  {'source': 'CAMERON', 'target': 'L70', 'text': 'Thirty-two.'},
#  {'source': 'CAMERON',
#   'target': 'L68',
#   'text': "Yeah.  A couple.  We're outnumbered by the cows, though."},
#  {'source': 'CAMERON',
#   'target': 'L66',
#   'text': "North, actually.  How'd you   ?"},
#  {'source': 'MICHAEL',
#   'target': 'L73',
#   'text': 'Couple thousand. Most of them evil'},
#  {'source': 'MICHAEL', 'target': 'L71', 'text': 'Get out!'},
#  {'source': 'MICHAEL',
#   'target': 'L69',
#   'text': 'How many people were in your old school?'},
#  {'source': 'MICHAEL',
#   'target': 'L67',
#   'text': 'I was kidding. People actually live there?'},
#  {'source': 'CAMERON', 'target': 'L63', 'text': 'So they tell me...'},
#  {'source': 'MICHAEL',
#   'target': 'L64',
#   'text': "C'mon.  I'm supposed to give you the tour."},
#  {'source': 'CAMERON', 'target': 'L780', 'text': 'You get the girl.'},
#  {'source': 'CAMERON', 'target': 'L743', 'text': 'She kissed me.'},
#  {'source': 'PATRICK', 'target': 'L744', 'text': 'Where?'},
#  {'source': 'PATRICK',
#   'target': 'L740',
#   'text': "She just needs time to cool off I'll give it a day."},
#  {'source': 'PATRICK',
#   'target': 'L725',
#   'text': "I don ' t know.  I decided not to nail her when she was too drunk to remember it."},
#  {'source': 'CAMERON', 'target': 'L623', 'text': 'Sure'},
#  {'source': 'PATRICK', 'target': 'L624', 'text': 'Then, go get her'},
#  {'source': 'CAMERON',
#   'target': 'L621',
#   'text': "She's partial to Joey, not me"},
#  {'source': 'CAMERON', 'target': 'L619', 'text': "It's off. The whole thing."},
#  {'source': 'PATRICK', 'target': 'L430', 'text': "Don't make me do it, man"},
#  {'source': 'PATRICK',
#   'target': 'L426',
#   'text': "So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?"},
#  {'source': 'CAMERON',
#   'target': 'L411',
#   'text': "I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful."},
#  {'source': 'PATRICK', 'target': 'L385', 'text': "Yeah -- we'll see."},
#  {'source': 'JOEY', 'target': 'L557', 'text': 'And why would I do that?'},
#  {'source': 'JOEY', 'target': 'L555', 'text': 'Your sister here?'},
#  {'source': 'KAT', 'target': 'L554', 'text': 'Away.'},
#  {'source': 'JOEY', 'target': 'L335', 'text': 'Not at all'},
#  {'source': 'JOEY',
#   'target': 'L149',
#   'text': "They're running the rest of me next month."},
#  {'source': 'KAT',
#   'target': 'L148',
#   'text': 'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.'},
#  {'source': 'JOEY',
#   'target': 'L747',
#   'text': "Enough with the Barbie n' Ken shit. I know."},
#  {'source': 'JOEY', 'target': 'L608', 'text': 'Get her to act like a human'},
#  {'source': 'PATRICK', 'target': 'L607', 'text': 'Do what?'},
#  {'source': 'JOEY', 'target': 'L605', 'text': "A deal's a deal."},
#  {'source': 'JOEY', 'target': 'L356', 'text': 'Forget it.'},
#  {'source': 'JOEY', 'target': 'L354', 'text': 'What?'},
#  {'source': 'PATRICK', 'target': 'L357', 'text': 'Forget her sister, then.'},
#  {'source': 'PATRICK', 'target': 'L355', 'text': 'A hundred bucks a date.'},
#  {'source': 'JOEY',
#   'target': 'L350',
#   'text': "Watching the bitch trash my car doesn't count as a date."},
#  {'source': 'PATRICK',
#   'target': 'L351',
#   'text': 'I got her under control. She just acts crazed in public to keep up the image.'},
#  {'source': 'PATRICK', 'target': 'L349', 'text': "I'm on it"},
#  {'source': 'PATRICK',
#   'target': 'L300',
#   'text': "Fifty, and you've got your man."},
#  {'source': 'JOEY', 'target': 'L298', 'text': 'Fine, thirty.'},
#  {'source': 'JOEY',
#   'target': 'L295',
#   'text': "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend."},
#  {'source': 'PATRICK', 'target': 'L296', 'text': 'How much?'},
#  {'source': 'PATRICK',
#   'target': 'L294',
#   'text': "You're gonna pay me to take out some girl?"},
#  {'source': 'JOEY',
#   'target': 'L291',
#   'text': "But you'd go out with her if you had the cake?"},
#  {'source': 'JOEY', 'target': 'L289', 'text': 'You just said'},
#  {'source': 'JOEY',
#   'target': 'L287',
#   'text': 'Yeah, whatever.  I want you to go out with her.'},
#  {'source': 'PATRICK',
#   'target': 'L290',
#   'text': 'You need money to take a girl out'},
#  {'source': 'PATRICK',
#   'target': 'L288',
#   'text': "Sure, Sparky.  I'll get right on it."},
#  {'source': 'JOEY', 'target': 'L285', 'text': 'What do you think?'},
#  {'source': 'MICHAEL',
#   'target': 'L508',
#   'text': "Hey -- it's all for the higher good right?"},
#  {'source': 'JOEY', 'target': 'L503', 'text': 'You and Verona?'},
#  {'source': 'MICHAEL',
#   'target': 'L504',
#   'text': 'What?  We took bathes together when we were kids.'},
#  {'source': 'MICHAEL',
#   'target': 'L502',
#   'text': "Uh,  yeah.  We're old friend*"},
#  {'source': 'JOEY',
#   'target': 'L238',
#   'text': 'Does this conversation have a purpose?'},
#  {'source': 'MICHAEL',
#   'target': 'L239',
#   'text': "So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job."},
#  {'source': 'JOEY', 'target': 'L235', 'text': "We're not."},
#  {'source': 'JOEY', 'target': 'L233', 'text': "We don't chat."},
#  {'source': 'JOEY', 'target': 'L231', 'text': 'Are you lost?'},
#  {'source': 'MICHAEL',
#   'target': 'L234',
#   'text': "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested."},
#  {'source': 'MICHAEL',
#   'target': 'L232',
#   'text': 'Nope - just came by to chat'},
#  {'source': 'KAT',
#   'target': 'L948',
#   'text': "Oh, honey -- tell me we haven't' progressed to full-on hallucinations."},
#  {'source': 'KAT', 'target': 'L946', 'text': 'Who?'},
#  {'source': 'MANDELLA',
#   'target': 'L947',
#   'text': 'William - he asked me to meet him here.'},
#  {'source': 'KAT',
#   'target': 'L753',
#   'text': "You ' re looking at this from the wrong perspective.  We're making a statement."},
#  {'source': 'KAT',
#   'target': 'L751',
#   'text': 'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.'},
#  {'source': 'MANDELLA',
#   'target': 'L754',
#   'text': 'Oh, good.  Something new and different for us.'},
#  {'source': 'MANDELLA',
#   'target': 'L752',
#   'text': "Okay, okay, we won't go.  It's not like I have a dress anyway"},
#  {'source': 'MANDELLA',
#   'target': 'L750',
#   'text': "Well, I guess we're not, since we don't have dates ."},
#  {'source': 'KAT',
#   'target': 'L720',
#   'text': 'I got drunk.  I puked.  I got rejected. It was big fun.'},
#  {'source': 'KAT',
#   'target': 'L718',
#   'text': 'I did Bianca a favor and it backfired.'},
#  {'source': 'KAT', 'target': 'L716', 'text': "I didn't have a choice."},
#  {'source': 'MANDELLA', 'target': 'L719', 'text': "You didn't"},
#  {'source': 'MANDELLA',
#   'target': 'L717',
#   'text': "You didn't have a choice?  Where's Kat and what have you done with her?"},
#  {'source': 'KAT', 'target': 'L490', 'text': 'Who cares?'},
#  {'source': 'KAT', 'target': 'L447', 'text': 'No fear.'},
#  {'source': 'KAT',
#   'target': 'L253',
#   'text': 'If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."'},
#  {'source': 'MANDELLA', 'target': 'L252', 'text': 'Does it matter?'},
#  {'source': 'KAT',
#   'target': 'L250',
#   'text': 'Neither has his heterosexuality.'},
#  {'source': 'KAT',
#   'target': 'L248',
#   'text': "William didn't even go to high school"},
#  {'source': 'MANDELLA', 'target': 'L249', 'text': "That's never been proven"},
#  {'source': 'MANDELLA',
#   'target': 'L247',
#   'text': 'William would never have gone to a state school.'},
#  {'source': 'MANDELLA',
#   'target': 'L151',
#   'text': "You could always go with me.  I'm sure William has some friends."},
#  {'source': 'MANDELLA',
#   'target': 'L133',
#   'text': "But imagine the things he'd say during sex."},
#  {'source': 'MANDELLA', 'target': 'L131', 'text': 'An attempted slit.'},
#  {'source': 'MANDELLA', 'target': 'L129', 'text': 'Just a little.'},
#  {'source': 'KAT', 'target': 'L127', 'text': 'Block E?'},
#  {'source': 'KAT',
#   'target': 'L125',
#   'text': "I'm sure he's completely incapable of doing anything that interesting."},
#  {'source': 'KAT', 'target': 'L123', 'text': 'Patrick Verona   Random skid.'},
#  {'source': 'MANDELLA', 'target': 'L126', 'text': 'He always look so'},
#  {'source': 'MANDELLA',
#   'target': 'L124',
#   'text': "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies."},
#  {'source': 'KAT',
#   'target': 'L1041',
#   'text': 'Oh, Bianca?  Can you get me my freshman yearbook?'},
#  {'source': 'PATRICK',
#   'target': 'L1042',
#   'text': "Don ' t you even dare. . ."},
#  {'source': 'PATRICK',
#   'target': 'L1040',
#   'text': 'Because I like to torture you.'},
#  {'source': 'KAT', 'target': 'L1033', 'text': 'Is that right?'},
#  {'source': 'PATRICK',
#   'target': 'L1034',
#   'text': 'Yeah, but then I fucked up. I fell for her.'},
#  {'source': 'PATRICK',
#   'target': 'L1031',
#   'text': 'I thought you could use it. When you start your band.'},
#  {'source': 'KAT',
#   'target': 'L975',
#   'text': 'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?'},
#  {'source': 'KAT',
#   'target': 'L973',
#   'text': 'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!'},
#  {'source': 'PATRICK',
#   'target': 'L976',
#   'text': "I didn't care about the money."},
#  {'source': 'PATRICK', 'target': 'L974', 'text': "It wasn't like that."},
#  {'source': 'PATRICK',
#   'target': 'L960',
#   'text': 'It gets worse -- you still have your freshman yearbook?'},
#  {'source': 'KAT', 'target': 'L957', 'text': 'What?'},
#  {'source': 'PATRICK',
#   'target': 'L958',
#   'text': "That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story."},
#  {'source': 'KAT',
#   'target': 'L939',
#   'text': "Look, I'm  -- sorry -- that I questioned your motives.  I was wrong."},
#  {'source': 'KAT',
#   'target': 'L937',
#   'text': "It's just something I had.  You know"},
#  {'source': 'PATRICK', 'target': 'L938', 'text': 'Oh huh'},
#  {'source': 'PATRICK',
#   'target': 'L936',
#   'text': "It's Scurvy's.  His date got convicted. Where'd you get the dress?"},
#  {'source': 'KAT', 'target': 'L855', 'text': 'Answer the question, Patrick'},
#  {'source': 'KAT', 'target': 'L853', 'text': 'You tell me.'},
#  {'source': 'PATRICK',
#   'target': 'L856',
#   'text': "Nothing!  There's nothing in it for me. Just the pleasure of your company."},
#  {'source': 'PATRICK',
#   'target': 'L854',
#   'text': 'You need therapy.  Has anyone ever told you that?'},
#  {'source': 'PATRICK',
#   'target': 'L852',
#   'text': 'So I have to have a motive to be with you?'},
#  {'source': 'KAT',
#   'target': 'L847',
#   'text': "Because I don't want to. It's a stupid tradition."},
#  {'source': 'KAT', 'target': 'L845', 'text': "No, I won't go with you"},
#  {'source': 'KAT', 'target': 'L843', 'text': 'No.'},
#  {'source': 'PATRICK', 'target': 'L846', 'text': 'Why not?'},
#  {'source': 'PATRICK', 'target': 'L844', 'text': 'No what?'},
#  {'source': 'PATRICK', 'target': 'L842', 'text': 'You know what I mean'},
#  {'source': 'KAT',
#   'target': 'L839',
#   'text': "You're amazingly self-assured. Has anyone ever told you that?"},
#  {'source': 'KAT', 'target': 'L837', 'text': 'What?'},
#  {'source': 'KAT',
#   'target': 'L835',
#   'text': 'No -- something real.  Something no one else knows.'},
#  {'source': 'PATRICK', 'target': 'L840', 'text': 'Go to the prom with me'},
#  {'source': 'PATRICK', 'target': 'L838', 'text': 'No one else knows'},
#  {'source': 'PATRICK',
#   'target': 'L836',
#   'text': "You're sweet.  And sexy.  And completely hot for me."},
#  {'source': 'PATRICK', 'target': 'L834', 'text': 'I hate peas.'},
#  {'source': 'KAT',
#   'target': 'L831',
#   'text': "I know the porn career's a lie."},
#  {'source': 'KAT', 'target': 'L829', 'text': 'The duck?'},
#  {'source': 'PATRICK', 'target': 'L830', 'text': 'Hearsay.'},
#  {'source': 'PATRICK', 'target': 'L828', 'text': 'Fallacy.'},
#  {'source': 'KAT', 'target': 'L824', 'text': 'For. . . ?'},
#  {'source': 'KAT', 'target': 'L821', 'text': 'How?'},
#  {'source': 'KAT', 'target': 'L819', 'text': 'Something like that'},
#  {'source': 'KAT',
#   'target': 'L817',
#   'text': "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change."},
#  {'source': 'KAT', 'target': 'L815', 'text': 'Acting the way we do.'},
#  {'source': 'KAT',
#   'target': 'L813',
#   'text': "Yeah, well, don't let it get out"},
#  {'source': 'PATRICK', 'target': 'L822', 'text': 'You never disappointed me.'},
#  {'source': 'PATRICK', 'target': 'L820', 'text': 'Then you screwed up'},
#  {'source': 'PATRICK',
#   'target': 'L818',
#   'text': "So if you disappoint them from the start, you're covered?"},
#  {'source': 'PATRICK', 'target': 'L816', 'text': 'Yes'},
#  {'source': 'PATRICK', 'target': 'L814', 'text': "So what's your excuse?"},
#  {'source': 'KAT', 'target': 'L811', 'text': 'I dazzled him with my wit'},
#  {'source': 'KAT', 'target': 'L809', 'text': 'Good call.'},
#  {'source': 'PATRICK',
#   'target': 'L810',
#   'text': "So how'd you get Chapin to look the other way?"},
#  {'source': 'PATRICK',
#   'target': 'L808',
#   'text': 'I figured it had to be something ridiculous to win your respect.  And piss you off.'},
#  {'source': 'KAT',
#   'target': 'L804',
#   'text': 'You want me to climb up and show you how to get down?'},
#  {'source': 'PATRICK', 'target': 'L805', 'text': 'Maybe.'},
#  {'source': 'PATRICK', 'target': 'L803', 'text': "Forget it.  I'm stayin'."},
#  {'source': 'KAT', 'target': 'L800', 'text': "C'mon.  It's not that bad"},
#  {'source': 'PATRICK',
#   'target': 'L801',
#   'text': "Try lookin' at it from this angle"},
#  {'source': 'PATRICK', 'target': 'L798', 'text': 'Look up, sunshine'},
#  {'source': 'KAT',
#   'target': 'L773',
#   'text': 'Other than my upchuck reflex? Nothing.'},
#  {'source': 'KAT',
#   'target': 'L771',
#   'text': "Don't for one minute think that you had any effect whatsoever on my panties."},
#  {'source': 'KAT', 'target': 'L769', 'text': 'Unwelcome.'},
#  {'source': 'PATRICK',
#   'target': 'L772',
#   'text': 'So what did I have an effect on ?'},
#  {'source': 'PATRICK',
#   'target': 'L770',
#   'text': 'Unwelcome?  I guess someone still has her panties in a twist.'},
#  {'source': 'KAT', 'target': 'L766', 'text': "You 're so --"},
#  {'source': 'KAT', 'target': 'L764', 'text': 'What are you doing here?'},
#  {'source': 'PATRICK', 'target': 'L767', 'text': 'Pleasant?'},
#  {'source': 'PATRICK',
#   'target': 'L765',
#   'text': 'I heard there was a poetry reading.'},
#  {'source': 'KAT', 'target': 'L688', 'text': 'BIANCA'},
#  {'source': 'KAT',
#   'target': 'L686',
#   'text': "He just wants me to be someone I'm not."},
#  {'source': 'PATRICK',
#   'target': 'L689',
#   'text': "No offense, but you're sister is without.  I know everyone likes her and all, but ..."},
#  {'source': 'PATRICK', 'target': 'L687', 'text': 'Who?'},
#  {'source': 'PATRICK', 'target': 'L683', 'text': "I'm gettin' there"},
#  {'source': 'KAT',
#   'target': 'L680',
#   'text': "My father wouldn't approve of that that"},
#  {'source': 'PATRICK',
#   'target': 'L681',
#   'text': "You don't strike me as the type that would ask permission."},
#  {'source': 'KAT', 'target': 'L678', 'text': 'This.'},
#  {'source': 'PATRICK', 'target': 'L677', 'text': 'Do what?'},
#  {'source': 'KAT', 'target': 'L675', 'text': "Why'd you lie?"},
#  {'source': 'KAT', 'target': 'L673', 'text': "No, you weren't"},
#  {'source': 'KAT', 'target': 'L671', 'text': 'Were you in jail?'},
#  {'source': 'PATRICK', 'target': 'L674', 'text': "Then why'd you ask?"},
#  {'source': 'PATRICK', 'target': 'L672', 'text': 'Maybe.'},
#  {'source': 'PATRICK', 'target': 'L670', 'text': 'Busy'},
#  {'source': 'KAT',
#   'target': 'L668',
#   'text': "But it's Gigglepuss - I know you like them.  I saw you there."},
#  {'source': 'KAT', 'target': 'L650', 'text': 'What?'},
#  {'source': 'KAT', 'target': 'L645', 'text': 'You know what they say'},
#  {'source': 'KAT',
#   'target': 'L643',
#   'text': 'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?'},
#  {'source': 'KAT', 'target': 'L641', 'text': 'I hate him.'},
#  {'source': 'KAT', 'target': 'L639', 'text': 'Who?'},
#  {'source': 'PATRICK',
#   'target': 'L644',
#   'text': 'I thought you were above all that'},
#  {'source': 'PATRICK',
#   'target': 'L642',
#   'text': "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type."},
#  {'source': 'PATRICK', 'target': 'L640', 'text': 'Dorsey.'},
#  {'source': 'KAT', 'target': 'L635', 'text': 'Just let me sit down.'},
#  {'source': 'KAT', 'target': 'L633', 'text': 'Like you could find one'},
#  {'source': 'KAT', 'target': 'L631', 'text': 'Why?'},
#  {'source': 'KAT', 'target': 'L629', 'text': "You don't care if I die"},
#  {'source': 'KAT', 'target': 'L627', 'text': "Why 're you doing this?"},
#  {'source': 'PATRICK',
#   'target': 'L634',
#   'text': "See that?  Who needs affection when I've got blind hatred?"},
#  {'source': 'PATRICK',
#   'target': 'L632',
#   'text': "Because then I'd have to start taking out girls who like me."},
#  {'source': 'PATRICK', 'target': 'L630', 'text': 'Sure, I do'},
#  {'source': 'PATRICK', 'target': 'L628', 'text': 'I told you'},
#  {'source': 'PATRICK',
#   'target': 'L626',
#   'text': "Leave it to you to use big words when you're shitfaced."},
#  {'source': 'KAT', 'target': 'L614', 'text': 'I know, just let me sleep'},
#  {'source': 'KAT',
#   'target': 'L612',
#   'text': 'I just need to lie down for awhile'},
#  {'source': 'PATRICK',
#   'target': 'L615',
#   'text': 'What if you have a concussion? My dog went to sleep with a concussion and woke up a vegetable. Not that I could tell the difference...'},
#  {'source': 'PATRICK',
#   'target': 'L613',
#   'text': "Uh, uh. You lie down and you'll go to sleep"},
#  {'source': 'KAT', 'target': 'L610', 'text': "I'm fine. I'm"},
#  {'source': 'KAT', 'target': 'L566', 'text': "Funny, you're the only one"},
#  {'source': 'KAT',
#   'target': 'L564',
#   'text': '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?'},
#  {'source': 'PATRICK',
#   'target': 'L565',
#   'text': 'I say, do what you wanna do.'},
#  {'source': 'KAT',
#   'target': 'L481',
#   'text': 'You know who The Raincoats are?'},
#  {'source': 'PATRICK', 'target': 'L482', 'text': "Why, don't you?"},
#  {'source': 'KAT',
#   'target': 'L475',
#   'text': "That's what you want, isn't it?"},
#  {'source': 'PATRICK',
#   'target': 'L476',
#   'text': "Do you mind?  You're sort of ruining it for me."},
#  {'source': 'KAT', 'target': 'L473', 'text': ''},
#  {'source': 'KAT',
#   'target': 'L333',
#   'text': "Depends on the topic. My fenders don't really whip me into a verbal frenzy."},
#  {'source': 'KAT', 'target': 'L331', 'text': 'Hi'},
#  {'source': 'PATRICK',
#   'target': 'L330',
#   'text': "I was in the laundromat. I saw your car. Thought I'd say hi."},
#  {'source': 'KAT', 'target': 'L326', 'text': 'You -- covered in my vomit.'},
#  {'source': 'KAT', 'target': 'L324', 'text': 'And why would I do that?'},
#  {'source': 'KAT',
#   'target': 'L322',
#   'text': "I don't really think you warrant that strong an emotion."},
#  {'source': 'PATRICK', 'target': 'L327', 'text': 'Seven-thirty?'},
#  {'source': 'PATRICK',
#   'target': 'L325',
#   'text': 'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...'},
#  {'source': 'PATRICK',
#   'target': 'L323',
#   'text': "Then say you'll spend Dollar Night at the track with me."},
#  {'source': 'KAT',
#   'target': 'L311',
#   'text': 'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?'},
#  {'source': 'PATRICK',
#   'target': 'L312',
#   'text': 'I know a lot more than that'},
#  {'source': 'KAT', 'target': 'L309', 'text': 'Oh, right.  Friday.'},
#  {'source': 'KAT', 'target': 'L306', 'text': 'My mission in life.'},
#  {'source': 'KAT',
#   'target': 'L304',
#   'text': 'Sweating like a pig, actually.  And yourself?'},
#  {'source': 'PATRICK',
#   'target': 'L305',
#   'text': "There's a way to get a guy's attention."},
#  {'source': 'KAT', 'target': 'L998', 'text': 'When I go?'},
#  {'source': 'WALTER',
#   'target': 'L999',
#   'text': "Oh, Christ.  Don't tell me you've changed your mind.  I already sent 'em a check."},
#  {'source': 'KAT',
#   'target': 'L995',
#   'text': "What's the matter?  Upset that I rubbed off on her?"},
#  {'source': 'KAT',
#   'target': 'L993',
#   'text': 'The part where Bianca beat the hell out of some guy.'},
#  {'source': 'KAT', 'target': 'L991', 'text': 'Parts of it.'},
#  {'source': 'KAT', 'target': 'L989', 'text': 'No, Daddy.'},
#  {'source': 'WALTER', 'target': 'L996', 'text': 'No -- impressed.'},
#  {'source': 'WALTER', 'target': 'L994', 'text': 'Bianca did what?'},
#  {'source': 'WALTER', 'target': 'L992', 'text': 'Which parts?'},
#  {'source': 'WALTER',
#   'target': 'L990',
#   'text': 'So tell me about this dance. Was it fun?'},
#  {'source': 'KAT',
#   'target': 'L986',
#   'text': 'Yeah.  She left with some bikers Big ones.  Full of sperm.'},
#  {'source': 'WALTER', 'target': 'L987', 'text': 'Funny.'},
#  {'source': 'KAT',
#   'target': 'L346',
#   'text': 'I want to go to an East Coast school! I want you to trust me to make my own choices.  I want --'},
#  {'source': 'KAT', 'target': 'L344', 'text': "So what I want doesn't matter?"},
#  {'source': 'KAT',
#   'target': 'L342',
#   'text': "Because you're making decisions for me."},
#  {'source': 'KAT',
#   'target': 'L340',
#   'text': 'I thought you were punishing me.'},
#  {'source': 'KAT',
#   'target': 'L338',
#   'text': 'Then tell them I had a seizure.'},
#  {'source': 'WALTER',
#   'target': 'L345',
#   'text': "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it."},
#  {'source': 'WALTER',
#   'target': 'L343',
#   'text': "As a parent, that's my right"},
#  {'source': 'WALTER', 'target': 'L341', 'text': "Why can't we agree on this?"},
#  {'source': 'WALTER',
#   'target': 'L339',
#   'text': 'Is this about Sarah Lawrence? You punishing me?'},
#  {'source': 'WALTER', 'target': 'L184', 'text': 'Enough!'},
#  {'source': 'KAT', 'target': 'L173', 'text': 'You decided.'},
#  {'source': 'WALTER',
#   'target': 'L172',
#   'text': 'I thought we decided you were going to school here.  At U of 0.'},
#  {'source': 'MISS PERKY', 'target': 'L1017', 'text': 'Just smack her now.'},
#  {'source': 'MISS PERKY',
#   'target': 'L108',
#   'text': 'No ... I believe "heinous bitch" is the term used most often.'},
#  {'source': 'KAT',
#   'target': 'L105',
#   'text': 'I still maintain that he kicked himself in the balls.  I was merely a spectator.'},
#  {'source': 'KAT',
#   'target': 'L103',
#   'text': 'Expressing my opinion is not a terrorist action.'},
#  {'source': 'MISS PERKY',
#   'target': 'L106',
#   'text': 'The point is Kat -- people perceive you as somewhat ...'},
#  {'source': 'MISS PERKY',
#   'target': 'L104',
#   'text': "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested."},
#  {'source': 'MICHAEL', 'target': 'L736', 'text': 'Kat a fan, too?'},
#  {'source': 'MANDELLA', 'target': 'L737', 'text': 'Yeah...'},
#  {'source': 'MANDELLA', 'target': 'L735', 'text': 'Right.'},
#  {'source': 'MICHAEL', 'target': 'L732', 'text': 'Oh yeah.'},
#  {'source': 'MICHAEL', 'target': 'L729', 'text': 'Cool pictures.  You a fan?'},
#  {'source': 'MANDELLA', 'target': 'L730', 'text': 'Yeah.  I guess.'},
#  {'source': 'MANDELLA', 'target': 'L728', 'text': 'Hi.'},
#  {'source': 'PATRICK',
#   'target': 'L776',
#   'text': "Man -- don't say shit like that to  me. People can hear you."},
#  {'source': 'MICHAEL',
#   'target': 'L775',
#   'text': 'Sweet love, renew thy force!'},
#  {'source': 'PATRICK',
#   'target': 'L723',
#   'text': "No - I've got a sweet-payin' job that I'm about to lose."},
#  {'source': 'PATRICK', 'target': 'L436', 'text': "I'm likin' you guys better"},
#  {'source': 'PATRICK', 'target': 'L428', 'text': 'Yeah.'},
#  {'source': 'MICHAEL', 'target': 'L420', 'text': 'Just for now.'},
#  {'source': 'MICHAEL', 'target': 'L414', 'text': 'Good enough.'},
#  {'source': 'MICHAEL', 'target': 'L383', 'text': "We're your guys."},
#  {'source': 'PATRICK',
#   'target': 'L380',
#   'text': 'So Dorsey can get the girl?'},
#  {'source': 'MICHAEL',
#   'target': 'L381',
#   'text': "Patrick, Pat, you're not looking at the big picture.  Joey's just a pawn. We set this whole thing up so Cameron can get the girl."},
#  {'source': 'PATRICK',
#   'target': 'L378',
#   'text': "Dorsey can plow whoever he wants. I'm just in this for the cash."},
#  {'source': 'PATRICK',
#   'target': 'L376',
#   'text': 'What is it with this chick?  She have three tits?'},
#  {'source': 'MICHAEL',
#   'target': 'L375',
#   'text': 'The situation is, my man Cameron here has a major jones for Bianca Stratford.'},
#  {'source': 'PATRICK',
#   'target': 'L372',
#   'text': "Whatever the hell it is you're standin' there waitin' to say."},
#  {'source': 'MICHAEL', 'target': 'L371', 'text': 'What?'},
#  {'source': 'PATRICK', 'target': 'L511', 'text': 'See you next week!'},
#  {'source': 'PATRICK',
#   'target': 'L263',
#   'text': "Well, you know -- there's the prestige of the job title... and the benefits package is pretty good..."},
#  {'source': 'PATRICK', 'target': 'L261', 'text': "What's to discuss?"},
#  {'source': 'MISS PERKY',
#   'target': 'L262',
#   'text': "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?"},
#  {'source': 'PATRICK', 'target': 'L257', 'text': 'Touch of the flu.'},
#  {'source': 'MISS PERKY',
#   'target': 'L258',
#   'text': "I'm at a loss, then.  What should we talk about? Your year of absence?"},
#  {'source': 'PATRICK',
#   'target': 'L60',
#   'text': 'It was a bratwurst.  I was eating lunch.'},
#  {'source': 'MISS PERKY',
#   'target': 'L61',
#   'text': 'With the teeth of your zipper?'},
#  {'source': 'MISS PERKY',
#   'target': 'L59',
#   'text': 'It says here you exposed yourself to a group of freshmen girls.'},
#  {'source': 'WALTER', 'target': 'L932', 'text': "That ' s what I thought"},
#  {'source': 'WALTER',
#   'target': 'L930',
#   'text': 'Did I have anything to say about it?'},
#  {'source': 'SHARON', 'target': 'L931', 'text': 'Absolutely not.'},
#  {'source': 'SHARON',
#   'target': 'L929',
#   'text': 'Your daughters went to the prom.'},
#  {'source': 'WALTER', 'target': 'L926', 'text': 'But -- who -- what --?'},
#  {'source': 'SHARON', 'target': 'L917', 'text': 'Dr. Ruth?'},
#  {'source': 'WALTER',
#   'target': 'L886',
#   'text': "Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day."},
#  {'source': 'WALTER', 'target': 'L876', 'text': 'Pirate -- no question.'},
#  {'source': 'WALTER', 'target': 'L192', 'text': "You're not helping."},
#  {'source': 'SHARON', 'target': 'L191', 'text': 'Tumescent!'},
#  {'source': 'WALTER',
#   'target': 'L170',
#   'text': 'Sarah Lawrence is on the other side of the country.'},
#  {'source': 'WALTER', 'target': 'L161', 'text': 'Make anyone cry today?'},
#  {'source': 'ALONSO',
#   'target': 'L2180',
#   'text': "Can't be that far, I say.  Also, I don't like the smell of the sea around here.  Smells like a cunt. Bad sign..."},
#  {'source': 'SAILOR',
#   'target': 'L2179',
#   'text': "We left three weeks ago, Alonso. Can't be that near."},
#  {'source': 'SAILOR', 'target': 'L2176', 'text': "We'll all go crazy..."},
#  {'source': 'ALONSO',
#   'target': 'L2174',
#   'text': "With a face like that?  I don't want you looking at me.  You hear?"},
#  {'source': 'SAILOR',
#   'target': 'L2173',
#   'text': "Ah, leave him alone.  He's doing no harm."},
#  {'source': 'ALONSO',
#   'target': 'L2171',
#   'text': "You'll be drinking your own piss... For the glory of Spain... and Admiral Colon...!  Bastard!"},
#  {'source': 'SAILOR',
#   'target': 'L2170',
#   'text': "The water's going putrid in the barrels."},
#  {'source': 'AROJAZ', 'target': 'L2024', 'text': 'IF-GOD-WILLS-IT!'},
#  {'source': 'COLUMBUS',
#   'target': 'L2022',
#   'text': 'Blind faith is what I consider heresy!'},
#  {'source': 'COLUMBUS',
#   'target': 'L2019',
#   'text': "Did He not choose a carpenter's son to reveal Himself to the world?"},
#  {'source': 'AROJAZ',
#   'target': 'L2014',
#   'text': 'Is that all that interests you? Gold?'},
#  {'source': 'COLUMBUS',
#   'target': 'L2015',
#   'text': 'No.  The Portuguese have already discovered black-skinned people.  I, too, will find other populations -- and bring them to the word of God.'},
#  {'source': 'AROJAZ',
#   'target': 'L2010',
#   'text': 'Your life, and that of others!'},
#  {'source': 'COLUMBUS',
#   'target': 'L2011',
#   'text': 'If they agree to follow me, yes.'},
#  {'source': 'COLUMBUS',
#   'target': 'L2005',
#   'text': 'Excellency, you are right.'},
#  {'source': 'AROJAZ',
#   'target': 'L1992',
#   'text': 'Then you cannot ignore that according to their calculations, the circumference of the Earth is approximately...  22,000 leagues or more.  Which makes the ocean... uncrossable.'},
#  {'source': 'AROJAZ',
#   'target': 'L1990',
#   'text': 'Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?'},
#  {'source': 'COLUMBUS', 'target': 'L1991', 'text': 'I am, Your Eminence'},
#  {'source': 'COLUMBUS',
#   'target': 'L1989',
#   'text': 'Yes, your Eminence.  The voyage should not take more than six or seven weeks.'},
#  {'source': 'AROJAZ',
#   'target': 'L2522',
#   'text': 'What a tragedy... what a waste of a life...'},
#  {'source': 'SANCHEZ',
#   'target': 'L2523',
#   'text': 'A waste...?  Let me tell you something, Arojaz.  If your name, or mine, is ever remembered -- it will only be because of his.'},
#  {'source': 'SANCHEZ',
#   'target': 'L2274',
#   'text': 'On the contrary, Your Eminence.  It seems to me the man is preparing his own cross.'},
#  {'source': 'SANCHEZ',
#   'target': 'L2030',
#   'text': 'Indeed.  The world is full of mercenaries -- and states often make use of them, when it benefits them.  My only concern is the welfare and prosperity of Spain.'},
# ...
#  {'source': 'JORDY',
#   'target': 'L2878',
#   'text': "Well, just so you know, I don't care about that stuff."},
#  {'source': 'JORDY', 'target': 'L2876', 'text': 'Nah, I musta missed it.'},
#  {'source': 'EDDIE', 'target': 'L2881', 'text': 'Good.  Good.  Commendable.'},
#  {'source': 'EDDIE', 'target': 'L2879', 'text': 'Nah, why should you?'},
#  {'source': 'EDDIE',
#   'target': 'L2877',
#   'text': 'Well, just so you know.  I gave you guys the credit.'},
#  {'source': 'EDDIE', 'target': 'L2875', 'text': 'Watch the news?'},
#  {'source': 'JORDY',
#   'target': 'L2747',
#   'text': "Why don't you explain it, Bobby.  Hey Camello!  You mind punching a hole in the floor?"},
#  {'source': 'EDDIE', 'target': 'L2746', 'text': 'No, what is it?'},
#  {'source': 'EDDIE',
#   'target': 'L2730',
#   'text': "No, we don't mind.  You mind Leon?"},
#  {'source': 'EMIL',
#   'target': 'L3248',
#   'text': "Smarter than Americans.  You're fed cry baby talk shows all day long.  Not only will Americans believe me, they'll cry for me.  So...Detective Eddie Flemming, would you like to say goodbye to your Nicolette? Maybe you can propose to her now?"},
#  {'source': 'EDDIE',
#   'target': 'L3243',
#   'text': "If you kill me and film it you're putting a noose around your neck."},
#  {'source': 'EMIL',
#   'target': 'L3241',
#   'text': 'Good - be tough to the end.  Actor who plays you will want to die like hero.'},
#  {'source': 'EMIL', 'target': 'L3239', 'text': 'I kill someone famous.'},
#  {'source': 'EMIL',
#   'target': 'L3237',
#   'text': 'Your opinion.  You see, they going to make a movie about me, too, Eddie.  And write books.'},
#  {'source': 'EDDIE', 'target': 'L3240', 'text': 'Then do it, asshole.'},
#  {'source': 'EDDIE', 'target': 'L3238', 'text': "What's your accomplishment."},
#  {'source': 'EDDIE', 'target': 'L3236', 'text': 'What do you want?'},
#  {'source': 'EDDIE', 'target': 'L3156', 'text': "Don't be late."},
#  {'source': 'EDDIE', 'target': 'L3154', 'text': 'See you later.  Good luck.'},
#  {'source': 'EDDIE', 'target': 'L3152', 'text': 'Yeah, yeah.  Good thing.'},
#  {'source': 'EDDIE', 'target': 'L3150', 'text': 'Yeah.  I promise.'},
#  {'source': 'EDDIE', 'target': 'L3148', 'text': 'Tonight.'},
#  {'source': 'NICOLETTE', 'target': 'L3155', 'text': 'Thank you.'},
#  {'source': 'NICOLETTE', 'target': 'L3153', 'text': 'Okay.'},
#  {'source': 'NICOLETTE',
#   'target': 'L3151',
#   'text': "Okay.  And you know what, I'll swing by my place, grab a couple pairs of shoes and maybe just test them out next to yours...How's that... Would that be a good thing."},
#  {'source': 'NICOLETTE', 'target': 'L3149', 'text': 'You promise?'},
#  {'source': 'EDDIE',
#   'target': 'L3145',
#   'text': 'Patronizing you... Nay, I love you.'},
#  {'source': 'EDDIE',
#   'target': 'L3143',
#   'text': "I promise.  We'll talk.  You'll be great.  You'll be fine.  Go ahead, just imagine that, uh... Just look into the lens and imagine you're talking to me."},
#  {'source': 'EDDIE',
#   'target': 'L3141',
#   'text': "I'll tell you tonight.  Let's do it tonight.  As soon as you get back we'll talk.  We'll talk."},
#  {'source': 'EDDIE',
#   'target': 'L3139',
#   'text': "No.  Go ahead.  You're gonna be great."},
#  {'source': 'EDDIE', 'target': 'L3137', 'text': "Well, that's great."},
#  {'source': 'EDDIE', 'target': 'L3135', 'text': "That's good."},
#  {'source': 'NICOLETTE', 'target': 'L3146', 'text': 'I love you.'},
#  {'source': 'NICOLETTE',
#   'target': 'L3144',
#   'text': "Yeah.  I'll do that.  As long as you're not patronizing me."},
#  {'source': 'NICOLETTE', 'target': 'L3142', 'text': 'Promise?'},
#  {'source': 'NICOLETTE',
#   'target': 'L3140',
#   'text': "No.  No, listen to me here.  I want to know what you're talking about.  You know, the shoe thing and the marriages and..."},
#  {'source': 'NICOLETTE',
#   'target': 'L3138',
#   'text': "Okay.  That is great.  But I can't go now, we're in the middle of something here."},
#  {'source': 'NICOLETTE', 'target': 'L3136', 'text': 'Yeah.'},
#  {'source': 'EDDIE', 'target': 'L3128', 'text': 'Answer it.'},
#  {'source': 'EDDIE', 'target': 'L3126', 'text': 'Answer the phone.'},
#  {'source': 'NICOLETTE',
#   'target': 'L3129',
#   'text': "Okay.  Okay.  Hold that thought just for a second.  They only call me when it's an emergency.  Just hold that thought.  Can you call back?"},
#  {'source': 'NICOLETTE',
#   'target': 'L3127',
#   'text': 'No.  Tell me what you want to say.'},
#  {'source': 'EDDIE', 'target': 'L3119', 'text': "Could be Leon's."},
#  {'source': 'NICOLETTE',
#   'target': 'L3120',
#   'text': 'Jesus.  And last week you came over with blood on your shoes.  What am I going to do with you?'},
#  {'source': 'EDDIE', 'target': 'L3115', 'text': "You're ruthless."},
#  {'source': 'EDDIE',
#   'target': 'L3113',
#   'text': "You were merciless.  You didn't give a shit if you got me or not."},
#  {'source': 'EDDIE',
#   'target': 'L3111',
#   'text': 'Yeah, well you took the camera and put it right down on the evidence.  That was...'},
#  {'source': 'EDDIE', 'target': 'L3109', 'text': "I'm not."},
#  {'source': 'EDDIE',
#   'target': 'L3107',
#   'text': 'Maybe I should just, ya know...turn to the cameras and say, do you mind if we just work something out?'},
#  {'source': 'EDDIE',
#   'target': 'L3105',
#   'text': "Oh, I'm sorry.  Did I embarrass you, sweetheart?  Oh..."},
#  {'source': 'EDDIE',
#   'target': 'L3103',
#   'text': "I can't...I can't answer you just because you want me to answer you!"},
#  {'source': 'NICOLETTE',
#   'target': 'L3116',
#   'text': "You're not so bad yourself."},
#  {'source': 'NICOLETTE',
#   'target': 'L3114',
#   'text': 'Well, who was it that taught me how to do that?  Huh?'},
#  {'source': 'NICOLETTE',
#   'target': 'L3112',
#   'text': 'That was good.  You were holding the evidence.'},
#  {'source': 'NICOLETTE',
#   'target': 'L3110',
#   'text': "Yes you are.  I'm not just some reporter.  I don't just stick a microphone in your face.  You could give me something."},
#  {'source': 'NICOLETTE',
#   'target': 'L3108',
#   'text': "Alright, alright, Eddie.  Don't patronize me."},
#  {'source': 'NICOLETTE', 'target': 'L3106', 'text': 'Stop it.'},
#  {'source': 'NICOLETTE',
#   'target': 'L3104',
#   'text': "You didn't have to embarrass me in front of my colleagues.  You could give me something."},
#  {'source': 'EDDIE', 'target': 'L3101', 'text': 'Hey.'},
#  {'source': 'EDDIE', 'target': 'L3042', 'text': 'Alright.'},
#  {'source': 'EDDIE', 'target': 'L3040', 'text': 'Alright?'},
#  {'source': 'EDDIE',
#   'target': 'L3038',
#   'text': "Yeah.  Now's not a good time."},
#  {'source': 'NICOLETTE', 'target': 'L3043', 'text': 'Okay.'},
#  {'source': 'NICOLETTE', 'target': 'L3041', 'text': 'Alright.'},
#  {'source': 'NICOLETTE', 'target': 'L3039', 'text': 'Alright.'},
#  {'source': 'EDDIE',
#   'target': 'L3035',
#   'text': "Um...now is not a good time, okay. Detective Jackson's hurt.  He's fine. I've got a Fire Marshall shot, Detective Jackson is hurt but not seriously."},
#  {'source': 'EDDIE',
#   'target': 'L3033',
#   'text': "He was hurt, but not seriously.  He'll be fine."},
#  {'source': 'EDDIE',
#   'target': 'L3031',
#   'text': "I really can't give out any information right now at this point."},
#  {'source': 'NICOLETTE', 'target': 'L3036', 'text': 'Alright, cut, cut, cut.'},
#  {'source': 'NICOLETTE',
#   'target': 'L3034',
#   'text': 'Do you have the suspect in custody?'},
#  {'source': 'NICOLETTE',
#   'target': 'L3032',
#   'text': "Okay.  But I do understand that your partner, Leon Jackson's been injured. Is that correct?"},
#  {'source': 'EDDIE',
#   'target': 'L3029',
#   'text': "I can't talk right now.  We have some things to take care of."},
#  {'source': 'EDDIE',
#   'target': 'L2764',
#   'text': "We don't know.  When I have more I'll let you know."},
#  {'source': 'EDDIE',
#   'target': 'L2762',
#   'text': "You know you can't do that.  C'mon."},
#  {'source': 'EDDIE',
#   'target': 'L2760',
#   'text': 'There are two bodies found at this point.'},
#  {'source': 'EDDIE',
#   'target': 'L2758',
#   'text': "We don't know that yet.  It's much too early.  There's a lot to be done."},
#  {'source': 'NICOLETTE', 'target': 'L2763', 'text': 'Is it drug related?'},
#  {'source': 'NICOLETTE',
#   'target': 'L2761',
#   'text': 'Can we go up to the crime scene?'},
#  {'source': 'NICOLETTE',
#   'target': 'L2759',
#   'text': 'How many victims are up there?'},
#  {'source': 'EDDIE',
#   'target': 'L2664',
#   'text': "Again?  I didn't wanna do it the first time."},
#  {'source': 'EDDIE', 'target': 'L2655', 'text': 'Yeah, yeah.  Jesus.'},
#  {'source': 'EDDIE', 'target': 'L2653', 'text': 'Keep them out of my way.'},
#  {'source': 'HAWKINS', 'target': 'L2654', 'text': 'Okay.  You ready?'},
#  {'source': 'HAWKINS',
#   'target': 'L2651',
#   'text': "You're worried for my safety.  I'm touched."},
#  {'source': 'EDDIE',
#   'target': 'L2647',
#   'text': 'Yeah.  And he still went to the party.'},
#  {'source': 'HAWKINS', 'target': 'L2646', 'text': "That's unique."},
#  {'source': 'EDDIE', 'target': 'L2644', 'text': 'Not what.  Who.'},
#  {'source': 'HAWKINS',
#   'target': 'L2611',
#   'text': "My kids?  Let's see...Susan's 15. Aundrea's 9.  Don't tell me you're thinking about having a kid!  How old are you?  Never mind. Let me just tell you this: Every stupid cliche you hear about kids - they change your life, they make you a better person, they make you whole...  It's all true!  Before I had kids when friends talked about their kids, I wanted to vomit.  Now -- I get it.  Am I right, Leon?"},
#  {'source': 'EDDIE', 'target': 'L2606', 'text': "I'm not moody."},
#  {'source': 'EDDIE',
#   'target': 'L2604',
#   'text': 'Not chopped up.  Not chopped up like that.  I mean, what do I got left? Coupla articles.  A medal or two. Plaque here and there and in a coupla years no one remembers me anymore.'},
#  {'source': 'HAWKINS',
#   'target': 'L2605',
#   'text': "I think you're getting a little moody there, Eddie."},
#  {'source': 'HAWKINS', 'target': 'L2595', 'text': 'Jesus Christ.'},
#  {'source': 'EMIL', 'target': 'L2627', 'text': 'No.  Are you proposing?'},
#  {'source': 'EMIL', 'target': 'L2625', 'text': 'Dog food.'},
#  {'source': 'EMIL', 'target': 'L2623', 'text': 'You stuff sausage in it.'},
#  {'source': 'EMIL', 'target': 'L2621', 'text': 'I am butcher.'},
#  {'source': 'SECONDARY OFFICER',
#   'target': 'L2624',
#   'text': 'And what do you do with the bones?'},
#  {'source': 'SECONDARY OFFICER',
#   'target': 'L2622',
#   'text': "You're a butcher?  What do you use pig intestines for?"},
#  {'source': 'EMIL',
#   'target': 'L3285',
#   'text': "Come alone.  Bring cash.  And we'll talk about surrendering."},
#  {'source': 'EMIL',
#   'target': 'L3283',
#   'text': "If you don't want my film - I'll call another show.  And they will show it."},
#  {'source': 'EMIL',
#   'target': 'L3281',
#   'text': "We'll talk about that.  Four o'clock gives you time to go to bank.  Three hundred thousand dollars."},
#  {'source': 'EMIL',
#   'target': 'L3279',
#   'text': "No.  I'm the best that's ever threatened you."},
#  {'source': 'HAWKINS',
#   'target': 'L3284',
#   'text': 'Wait a minute.  Wait a minute.'},
#  {'source': 'HAWKINS',
#   'target': 'L3282',
#   'text': "What?  It doesn't work that way."},
#  {'source': 'HAWKINS',
#   'target': 'L3280',
#   'text': "I'll meet you on one condition - I get exclusivity and you surrender to me."},
#  {'source': 'HAWKINS',
#   'target': 'L3278',
#   'text': "Look asshole.  I've been threatened by better than you."},
#  {'source': 'EMIL',
#   'target': 'L3555',
#   'text': "If he doesn't lower his gun I'll fucking kill her."},
#  {'source': 'JORDY', 'target': 'L3554', 'text': 'Let her go!  Let her go!!'},
#  {'source': 'EMIL',
#   'target': 'L3435',
#   'text': "The Sheraton!  On Broadway!  Room 210. Go get Oleg.  He'll kill you."},
#  {'source': 'JORDY', 'target': 'L3433', 'text': 'Get down on your knees.'},
#  {'source': 'JORDY', 'target': 'L3431', 'text': "You'll be my first."},
#  {'source': 'EMIL',
#   'target': 'L3419',
#   'text': "My father was.  He gave me many lessons about fire.  Now it's my friend."},
#  {'source': 'JORDY', 'target': 'L3420', 'text': 'Tommy, take a walk.'},
#  {'source': 'HONEY',
#   'target': 'L2857',
#   'text': "Alright, alright - don't hurt me! Please, it's in my book, in my purse!"},
#  {'source': 'HONEY',
#   'target': 'L2855',
#   'text': "Look, man, I don't give a shit if you want sex or not, but you're payin' for my time."},
#  {'source': 'EMIL',
#   'target': 'L2852',
#   'text': 'I like to talk to the person who runs the service.  Can you give me address?'},
#  {'source': 'EMIL', 'target': 'L2850', 'text': 'Where is escort service?'},
#  {'source': 'HONEY',
#   'target': 'L2853',
#   'text': "Look.  Do we have a problem here? There's no reason to have a problem. I'm gonna make you feel real good.  You wanna Czech girl? After I'm done with you, you won't miss her.  Now why don't you pay me?"},
#  {'source': 'HONEY',
#   'target': 'L2851',
#   'text': "That's confidential.  Could you put the money on the dresser?"},
#  {'source': 'EMIL',
#   'target': 'L2848',
#   'text': 'I ordered a Czech girl.  Daphne, you know her?'},
#  {'source': 'EMIL', 'target': 'L2845', 'text': "Where's Czech girl?"},
#  {'source': 'HONEY',
#   'target': 'L2846',
#   'text': "Baby, I'm anybody you want me to be. I'm a little schoolgirl, I'm mommy, I'm a Czech girl."},
#  {'source': 'EMIL', 'target': 'L2580', 'text': "He doesn't speak English."},
#  {'source': 'EMIL', 'target': 'L2578', 'text': 'Two weeks.'},
#  {'source': 'IMMIGRATION OFFICER',
#   'target': 'L2579',
#   'text': "I'd like to speak for himself, okay?"},
#  {'source': 'IMMIGRATION OFFICER',
#   'target': 'L2577',
#   'text': 'How long are you planning to stay?'},
#  {'source': 'EMIL', 'target': 'L2572', 'text': 'Is there a problem?'},
#  {'source': 'EMIL', 'target': 'L2570', 'text': 'Yes.'},
#  {'source': 'IMMIGRATION OFFICER',
#   'target': 'L2573',
#   'text': "No, you're travelling together.  I want to talk to you together.  Hi, how are you?  Can I take a look at your documents?  Are you related?"},
#  {'source': 'IMMIGRATION OFFICER',
#   'target': 'L2571',
#   'text': 'Please join us.  Come on forward.'},
#  {'source': 'EMIL', 'target': 'L2567', 'text': 'I have five-hundred dollars.'},
#  {'source': 'EMIL', 'target': 'L2565', 'text': 'Two weeks holiday.'},
#  {'source': 'IMMIGRATION OFFICER',
#   'target': 'L2568',
#   'text': 'Can you show me?  Sir, no cameras in the FIS area!'},
#  {'source': 'IMMIGRATION OFFICER',
#   'target': 'L2566',
#   'text': 'How much money are you carrying with you?'},
#  {'source': 'EMIL', 'target': 'L2563', 'text': 'Yes sir.'},
#  {'source': 'EMIL', 'target': 'L2914', 'text': 'Yes.  Both.'},
#  {'source': 'EMIL',
#   'target': 'L2912',
#   'text': 'Million?!  The killer gets one million dollars for a television interview?'},
#  {'source': 'EMIL',
#   'target': 'L2910',
#   'text': 'Do you know how much killer gets for movie rights?'},
#  {'source': 'VENDOR',
#   'target': 'L2913',
#   'text': 'Hey, tabloids paid Ted Bundy - famous serial killer - half a million for his interview.  And how much you think Monica got for writing book about the President coming on to her?  It pays to be a killer or a whore in this country. Look, you want magazine or not?'},
#  {'source': 'VENDOR',
#   'target': 'L2911',
#   'text': 'In here, says he wants a million.'},
#  {'source': 'VENDOR',
#   'target': 'L2908',
#   'text': "New York's finest.  This is his case."},
#  {'source': 'OLEG',
#   'target': 'L3547',
#   'text': 'No.  You are the traitor.  You are murderer.  I am director.  Action!'},
#  {'source': 'EMIL',
#   'target': 'L3377',
#   'text': 'You think you are a director?  You are a fucking little, small Russian piece of shit.  And I hate you.  I fucking hate you.'},
#  {'source': 'OLEG', 'target': 'L3376', 'text': "No, I don't get that!"},
#  {'source': 'EMIL',
#   'target': 'L3374',
#   'text': "Yes.  But there's only one problem - you want credit but the problem is - I don't share credit."},
#  {'source': 'EMIL', 'target': 'L3372', 'text': 'Credit?'},
#  {'source': 'OLEG',
#   'target': 'L3373',
#   'text': 'Yes.  Before we hand in the next video - I put titles on it and my credit is going to read - Directed by Oleg Razgul.'},
#  {'source': 'EMIL',
#   'target': 'L3369',
#   'text': 'Your idea?  I thought it was my idea.'},
#  ...]

# %%
#   Saving the list of dictionaries as a JSON file.

with open(r"../data/conversation_network.json", "w") as f:
    json.dump(json_edges, f)

# %% [markdown]
# ### **• Topic Modelling:**

# %% [markdown]
# Topic modelling can be effectively applied to the Cornell Movie-Dialogs Corpus to reveal hidden thematic structures within the dialogues.

# %% [markdown]
# #### **What is Topic Modelling?**

# %% [markdown]
# Topic modelling is a type of statistical modeling used to identify abstract topics that occur in a collection of documents. It helps in organising and summarising large datasets of textual information. The most common techniques for topic modelling are Latent Dirichlet Allocation (LDA) and Non-Negative Matrix Factorisation (NMF).

# %%
tqdm.pandas()   #   Creating a progress bar.

# %%
stop_words=stopwords.words("english")   #   Creating a list of stopwords.
lemmatiser=WordNetLemmatizer()  #   Creating an instance of the WordNetLemmatizer class.

# %%
#   Function to preprocess the text data.

def preprocess_text(text):
    text=text.lower()   #   Converting the text to lowercase.
    text=re.sub(r"\d+", "", text)   #   Removing digits.
    text=re.sub(r"[^\w\s]", "", text)   #   Removing punctuation.
    text=re.sub(r"\s+", " ", text)  #   Removing extra whitespace.
    text=text.strip()   #   Removing leading and trailing whitespace.
    text=word_tokenize(text)    #   Tokenising the text.
    text=[i for i in text if not i in stop_words]   #   Removing stopwords.
    text=[lemmatiser.lemmatize(word=w, pos="v") for w in text]  #   Lemmatising the text.
    text=" ".join(text) #   Joining the text back together.
    return text

# %%
topic_modelling_dataframe=corpus_dataframe.copy()   #   Creating a copy of the corpus pandas.DataFrame.

# %%
topic_modelling_dataframe["text"]=topic_modelling_dataframe["text"].progress_apply(preprocess_text) #   Preprocessing the text data.
topic_modelling_dataframe.head()
# Out:
# 100%|██████████| 304713/304713 [00:17<00:00, 17080.90it/s]
#             meta.movie_name_x meta.release_year meta.rating meta.votes  \
# 0  10 things i hate about you              1999        6.90      62847
# 1  10 things i hate about you              1999        6.90      62847
# 2  10 things i hate about you              1999        6.90      62847
# 3  10 things i hate about you              1999        6.90      62847
# 4  10 things i hate about you              1999        6.90      62847
#
#               meta.genre meta.character_name    text speaker reply_to
# 0  ['comedy', 'romance']              BIANCA              u0    L1044
# 1  ['comedy', 'romance']             CAMERON              u2     None
# 2  ['comedy', 'romance']              BIANCA    hope      u0     L984
# 3  ['comedy', 'romance']             CAMERON    okay      u2     None
# 4  ['comedy', 'romance']              BIANCA  let go      u0     L924

# %%
topic_modelling_dataframe=topic_modelling_dataframe[topic_modelling_dataframe["text"]!=""]  #   Removing rows with empty text.
topic_modelling_dataframe.head()
# Out:
#             meta.movie_name_x meta.release_year meta.rating meta.votes  \
# 2  10 things i hate about you              1999        6.90      62847
# 3  10 things i hate about you              1999        6.90      62847
# 4  10 things i hate about you              1999        6.90      62847
# 5  10 things i hate about you              1999        6.90      62847
# 6  10 things i hate about you              1999        6.90      62847
#
#               meta.genre meta.character_name  \
# 2  ['comedy', 'romance']              BIANCA
# 3  ['comedy', 'romance']             CAMERON
# 4  ['comedy', 'romance']              BIANCA
# 5  ['comedy', 'romance']             CAMERON
# 6  ['comedy', 'romance']              BIANCA
#
#                                text speaker reply_to
# 2                              hope      u0     L984
# 3                              okay      u2     None
# 4                            let go      u0     L924
# 5                               wow      u2     None
# 6  okay youre gon na need learn lie      u0     L871

# %%
len(topic_modelling_dataframe)
# Out:
# 291834

# %%
count_vectorizer=CountVectorizer(stop_words="english")  #   Creating an instance of the CountVectorizer class.
count_data=count_vectorizer.fit_transform(topic_modelling_dataframe["text"])    #   Creating a document-term matrix.
count_data
# Out:
# <291834x56303 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1297581 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### **Latent Dirichlet Allocation (LDA):**

# %% [markdown]
# Latent Dirichlet Allocation (LDA) is a generative probabilistic model commonly used for topic modeling in natural language processing (NLP). It helps to uncover the underlying thematic structure in a collection of documents by identifying topics and the distribution of these topics within the documents.

# %% [markdown]
# ##### **Documents and Corpus:**
#
# - **Document:** A single piece of text, such as an article, book chapter, or in the case of the Cornell Movie-Dialogs Corpus, a movie dialogue.
# - **Corpus:** A collection of documents.

# %% [markdown]
# ##### **Topics:**
#
# - **Topic:** A distribution over a fixed vocabulary of words. Each topic is characterised by a set of words that frequently appear together.
# - **Word Distribution:** For each topic, Latent Dirichlet Allocation (LDA) assumes a probability distribution over all the words in the corpus vocabulary.

# %% [markdown]
# ##### **Assumptions:**
#
# - Each document is a mixture of a small number of topics.
# - Each word in a document can be attributed to one of the document's topics.

# %%
lda=LatentDirichletAllocation(n_components=10, learning_decay=0.7, max_iter=100, random_state=0, n_jobs=-1, verbose=1)  #   Creating an instance of the LatentDirichletAllocation class.
lda.fit(count_data) #   Fitting the model to the document-term matrix.
# Out:
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100
# iteration: 15 of max_iter: 100
# iteration: 16 of max_iter: 100
# iteration: 17 of max_iter: 100
# iteration: 18 of max_iter: 100
# iteration: 19 of max_iter: 100
# iteration: 20 of max_iter: 100
# iteration: 21 of max_iter: 100
# iteration: 22 of max_iter: 100
# iteration: 23 of max_iter: 100
# iteration: 24 of max_iter: 100
# iteration: 25 of max_iter: 100
# iteration: 26 of max_iter: 100
# iteration: 27 of max_iter: 100
# iteration: 28 of max_iter: 100
# iteration: 29 of max_iter: 100
# iteration: 30 of max_iter: 100
# iteration: 31 of max_iter: 100
# iteration: 32 of max_iter: 100
# iteration: 33 of max_iter: 100
# iteration: 34 of max_iter: 100
# iteration: 35 of max_iter: 100
# iteration: 36 of max_iter: 100
# iteration: 37 of max_iter: 100
# iteration: 38 of max_iter: 100
# iteration: 39 of max_iter: 100
# iteration: 40 of max_iter: 100
# iteration: 41 of max_iter: 100
# iteration: 42 of max_iter: 100
# iteration: 43 of max_iter: 100
# iteration: 44 of max_iter: 100
# iteration: 45 of max_iter: 100
# iteration: 46 of max_iter: 100
# iteration: 47 of max_iter: 100
# iteration: 48 of max_iter: 100
# iteration: 49 of max_iter: 100
# iteration: 50 of max_iter: 100
# iteration: 51 of max_iter: 100
# iteration: 52 of max_iter: 100
# iteration: 53 of max_iter: 100
# iteration: 54 of max_iter: 100
# iteration: 55 of max_iter: 100
# iteration: 56 of max_iter: 100
# iteration: 57 of max_iter: 100
# iteration: 58 of max_iter: 100
# iteration: 59 of max_iter: 100
# iteration: 60 of max_iter: 100
# iteration: 61 of max_iter: 100
# iteration: 62 of max_iter: 100
# iteration: 63 of max_iter: 100
# iteration: 64 of max_iter: 100
# iteration: 65 of max_iter: 100
# iteration: 66 of max_iter: 100
# iteration: 67 of max_iter: 100
# iteration: 68 of max_iter: 100
# iteration: 69 of max_iter: 100
# iteration: 70 of max_iter: 100
# iteration: 71 of max_iter: 100
# iteration: 72 of max_iter: 100
# iteration: 73 of max_iter: 100
# iteration: 74 of max_iter: 100
# iteration: 75 of max_iter: 100
# iteration: 76 of max_iter: 100
# iteration: 77 of max_iter: 100
# iteration: 78 of max_iter: 100
# iteration: 79 of max_iter: 100
# iteration: 80 of max_iter: 100
# iteration: 81 of max_iter: 100
# iteration: 82 of max_iter: 100
# iteration: 83 of max_iter: 100
# iteration: 84 of max_iter: 100
# iteration: 85 of max_iter: 100
# iteration: 86 of max_iter: 100
# iteration: 87 of max_iter: 100
# iteration: 88 of max_iter: 100
# iteration: 89 of max_iter: 100
# iteration: 90 of max_iter: 100
# iteration: 91 of max_iter: 100
# iteration: 92 of max_iter: 100
# iteration: 93 of max_iter: 100
# iteration: 94 of max_iter: 100
# iteration: 95 of max_iter: 100
# iteration: 96 of max_iter: 100
# iteration: 97 of max_iter: 100
# iteration: 98 of max_iter: 100
# iteration: 99 of max_iter: 100
# iteration: 100 of max_iter: 100
# LatentDirichletAllocation(max_iter=100, n_jobs=-1, random_state=0, verbose=1)

# %%
#   Function to retrieve the top words for each topic.

def get_topics(model, feature_names, n_top_words):
    topics=[]

    #   Iterating through each topic.

    for _, topic in enumerate(model.components_):
        topics.append(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))  #   Retrieving the top words for each topic.
        
    return topics

# %%
n_top_words=3
topic_list=get_topics(lda, count_vectorizer.get_feature_names_out(), n_top_words)   #   Retrieving the top words for each topic.
topic_list
# Out:
# ['tell want good',
#  'know dont like',
#  'make fuck money',
#  'say talk mean',
#  'ill hell mr',
#  'im think oh',
#  'youre right thats',
#  'hes man let',
#  'whats need thank',
#  'yes kill sure']

# %%
topic_distribution=lda.transform(count_data)    #   Retrieving the topic distribution for each document.
topic_distribution
# Out:
# array([[0.05000905, 0.05      , 0.05      , ..., 0.05      , 0.54998198,
#         0.05000897],
#        [0.05      , 0.05      , 0.05      , ..., 0.05      , 0.05      ,
#         0.05      ],
#        [0.05      , 0.05      , 0.05      , ..., 0.54998747, 0.05      ,
#         0.05      ],
#        ...,
#        [0.34999203, 0.01666763, 0.01666951, ..., 0.01666667, 0.01666667,
#         0.01667485],
#        [0.12222243, 0.01111111, 0.01111155, ..., 0.13408382, 0.34443742,
#         0.332584  ],
#        [0.01250337, 0.0125    , 0.15685496, ..., 0.0125    , 0.31044864,
#         0.33956012]])

# %%
topic_dataframe=pd.DataFrame(topic_distribution, columns=topic_list)    #   Creating a pandas.DataFrame from the topic distribution.
topic_dataframe
# Out:
#         tell want good  know dont like  make fuck money  say talk mean  \
# 0             0.050009        0.050000         0.050000       0.050000
# 1             0.050000        0.050000         0.050000       0.050000
# 2             0.050000        0.050000         0.050000       0.050000
# 3             0.050000        0.549995         0.050000       0.050000
# 4             0.137499        0.012500         0.012501       0.012500
# ...                ...             ...              ...            ...
# 291829        0.025000        0.025000         0.025006       0.025000
# 291830        0.128865        0.148061         0.259302       0.007144
# 291831        0.349992        0.016668         0.016670       0.016668
# 291832        0.122222        0.011111         0.011112       0.011111
# 291833        0.012503        0.012500         0.156855       0.012503
#
#         ill hell mr  im think oh  youre right thats  hes man let  \
# 0          0.050000     0.050000           0.050000     0.050000
# 1          0.050000     0.050000           0.550000     0.050000
# 2          0.050005     0.050000           0.050007     0.549987
# 3          0.050000     0.050000           0.050005     0.050000
# 4          0.012500     0.012500           0.637500     0.012500
# ...             ...          ...                ...          ...
# 291829     0.025010     0.025000           0.025000     0.025000
# 291830     0.007143     0.007146           0.007143     0.278052
# 291831     0.349993     0.183335           0.016667     0.016667
# 291832     0.011116     0.011111           0.011111     0.134084
# 291833     0.012500     0.012500           0.118130     0.012500
#
#         whats need thank  yes kill sure
# 0               0.549982       0.050009
# 1               0.050000       0.050000
# 2               0.050000       0.050000
# 3               0.050000       0.050000
# 4               0.137500       0.012500
# ...                  ...            ...
# 291829          0.774982       0.025002
# 291830          0.150000       0.007144
# 291831          0.016667       0.016675
# 291832          0.344437       0.332584
# 291833          0.310449       0.339560
#
# [291834 rows x 10 columns]

# %%
data=topic_dataframe.to_dict(orient="records")  #   Creating a list of dictionaries from the pandas.DataFrame.
data
# Out:
# [{'tell want good': 0.05000904963595088,
#   'know dont like': 0.050000000000807523,
#   'make fuck money': 0.05000000000100708,
#   'say talk mean': 0.05000000000132095,
#   'ill hell mr': 0.050000000001151616,
#   'im think oh': 0.050000000001203526,
#   'youre right thats': 0.05000000000119459,
#   'hes man let': 0.050000000000937836,
#   'whats need thank': 0.5499819807157692,
#   'yes kill sure': 0.05000896964065685},
#  {'tell want good': 0.05000000000012814,
#   'know dont like': 0.05000000000010083,
#   'make fuck money': 0.050000000000125826,
#   'say talk mean': 0.05000000000016499,
#   'ill hell mr': 0.05000000000014385,
#   'im think oh': 0.05000000000015033,
#   'youre right thats': 0.5499999999987552,
#   'hes man let': 0.050000000000117166,
#   'whats need thank': 0.050000000000147864,
#   'yes kill sure': 0.050000000000165794},
#  {'tell want good': 0.05000000000016822,
#   'know dont like': 0.05000000000013236,
#   'make fuck money': 0.050000000000165176,
#   'say talk mean': 0.050000000000216614,
#   'ill hell mr': 0.05000547733545428,
#   'im think oh': 0.05000000000019725,
#   'youre right thats': 0.05000705258177285,
#   'hes man let': 0.5499874700814815,
#   'whats need thank': 0.05000000000019409,
#   'yes kill sure': 0.05000000000021766},
#  {'tell want good': 0.05000000000390555,
#   'know dont like': 0.5499945464616766,
#   'make fuck money': 0.050000000003835206,
#   'say talk mean': 0.05000000000502818,
#   'ill hell mr': 0.05000000000438359,
#   'im think oh': 0.050000000004582344,
#   'youre right thats': 0.05000545350345803,
#   'hes man let': 0.05000000000357075,
#   'whats need thank': 0.050000000004506794,
#   'yes kill sure': 0.05000000000505302},
#  {'tell want good': 0.13749867304924718,
#   'know dont like': 0.012500201617907897,
#   'make fuck money': 0.012501269324951,
#   'say talk mean': 0.012500000000465167,
#   'ill hell mr': 0.012500000000405402,
#   'im think oh': 0.012500000000423634,
#   'youre right thats': 0.6374998538306336,
#   'hes man let': 0.012500000000330358,
#   'whats need thank': 0.1375000021751683,
#   'yes kill sure': 0.012500000000467571},
#  {'tell want good': 0.1574563044490433,
#   'know dont like': 0.617532440780225,
#   'make fuck money': 0.01250000004807865,
#   'say talk mean': 0.012500000063139529,
#   'ill hell mr': 0.012505815289102334,
#   'im think oh': 0.1375012611908741,
#   'youre right thats': 0.012502180077501958,
#   'hes man let': 0.01250199798166383,
#   'whats need thank': 0.012500000056617855,
#   'yes kill sure': 0.01250000006375338},
#  {'tell want good': 0.020000000079930472,
#   'know dont like': 0.4460828148439242,
#   'make fuck money': 0.020000754547037643,
#   'say talk mean': 0.020000000102905598,
#   'ill hell mr': 0.020000000089707738,
#   'im think oh': 0.020000000093883214,
#   'youre right thats': 0.020000000093044874,
#   'hes man let': 0.3939141650291888,
#   'whats need thank': 0.02000000009222997,
#   'yes kill sure': 0.020002265028147507},
#  {'tell want good': 0.6999658151759245,
#   'know dont like': 0.0333461481507467,
#   'make fuck money': 0.03334111397227833,
#   'say talk mean': 0.03333845303945719,
#   'ill hell mr': 0.03333333333455857,
#   'im think oh': 0.033333333334613656,
#   'youre right thats': 0.03333677263309506,
#   'hes man let': 0.033338363689988215,
#   'whats need thank': 0.03333333333459286,
#   'yes kill sure': 0.03333333333474494},
#  {'tell want good': 0.05000000000060326,
#   'know dont like': 0.05000619864573926,
#   'make fuck money': 0.5499868111879695,
#   'say talk mean': 0.050000000000776396,
#   'ill hell mr': 0.05000000000067691,
#   'im think oh': 0.05000699016150514,
#   'youre right thats': 0.05000000000070233,
#   'hes man let': 0.05000000000055154,
#   'whats need thank': 0.05000000000069555,
#   'yes kill sure': 0.05000000000078016},
#  {'tell want good': 0.4429398253780299,
#   'know dont like': 0.01667345895599714,
#   'make fuck money': 0.016668873532768896,
#   'say talk mean': 0.4237137844927887,
#   'ill hell mr': 0.01666666666844174,
#   'im think oh': 0.0166672651517992,
#   'youre right thats': 0.01666841240274781,
#   'hes man let': 0.016668380080220924,
#   'whats need thank': 0.016666666668492397,
#   'yes kill sure': 0.01666666666871325},
#  {'tell want good': 0.014286509979848771,
#   'know dont like': 0.2162546067953394,
#   'make fuck money': 0.014290324292634961,
#   'say talk mean': 0.014287628049406588,
#   'ill hell mr': 0.014286069389077805,
#   'im think oh': 0.24088685928134065,
#   'youre right thats': 0.014285714309720688,
#   'hes man let': 0.4428508592806636,
#   'whats need thank': 0.014285714309529081,
#   'yes kill sure': 0.014285714312438514},
#  {'tell want good': 0.6999453612833523,
#   'know dont like': 0.03334698584404144,
#   'make fuck money': 0.03335881715491467,
#   'say talk mean': 0.03333614084546963,
#   'ill hell mr': 0.03333333334126493,
#   'im think oh': 0.03334338477742777,
#   'youre right thats': 0.03333597672976417,
#   'hes man let': 0.03333333333979934,
#   'whats need thank': 0.033333333341485936,
#   'yes kill sure': 0.03333333334247985},
#  {'tell want good': 0.2660722014591692,
#   'know dont like': 0.01666666669725751,
#   'make fuck money': 0.016667130114251593,
#   'say talk mean': 0.26725467603480835,
#   'ill hell mr': 0.016666666710313843,
#   'im think oh': 0.18333432382021003,
#   'youre right thats': 0.01667069059990268,
#   'hes man let': 0.016666666702209513,
#   'whats need thank': 0.18333431114483972,
#   'yes kill sure': 0.016666666717037617},
#  {'tell want good': 0.05000594357695043,
#   'know dont like': 0.05001185425442997,
#   'make fuck money': 0.5499744182633515,
#   'say talk mean': 0.050000000008608346,
#   'ill hell mr': 0.05000000000749917,
#   'im think oh': 0.05000778385890446,
#   'youre right thats': 0.05000000000778655,
#   'hes man let': 0.05000000000611318,
#   'whats need thank': 0.05000000000770811,
#   'yes kill sure': 0.05000000000864823},
#  {'tell want good': 0.010000267535005327,
#   'know dont like': 0.1481208383720169,
#   'make fuck money': 0.01000737097808469,
#   'say talk mean': 0.21000464577675926,
#   'ill hell mr': 0.010000255654065216,
#   'im think oh': 0.010000270822247598,
#   'youre right thats': 0.34671611752964343,
#   'hes man let': 0.23514911956781823,
#   'whats need thank': 0.010000000096616229,
#   'yes kill sure': 0.010001113667743112},
#  {'tell want good': 0.1,
#   'know dont like': 0.1,
#   'make fuck money': 0.1,
#   'say talk mean': 0.1,
#   'ill hell mr': 0.1,
#   'im think oh': 0.1,
#   'youre right thats': 0.1,
#   'hes man let': 0.1,
#   'whats need thank': 0.1,
#   'yes kill sure': 0.1},
#  {'tell want good': 0.05000000001480944,
#   'know dont like': 0.05000000001164233,
#   'make fuck money': 0.5499999998534552,
#   'say talk mean': 0.050000000019078006,
#   'ill hell mr': 0.050000000016615094,
#   'im think oh': 0.05000000001737623,
#   'youre right thats': 0.05000000001724003,
#   'hes man let': 0.050000000013533864,
#   'whats need thank': 0.050000000017086196,
#   'yes kill sure': 0.05000000001916349},
#  {'tell want good': 0.033337187234481334,
#   'know dont like': 0.033333333333391425,
#   'make fuck money': 0.03333333333340583,
#   'say talk mean': 0.3666666672519214,
#   'ill hell mr': 0.03333333333341617,
#   'im think oh': 0.0333333333334199,
#   'youre right thats': 0.36666281217971586,
#   'hes man let': 0.03333333333340082,
#   'whats need thank': 0.0333333333334185,
#   'yes kill sure': 0.03333333333342884},
#  {'tell want good': 0.5499916599026309,
#   'know dont like': 0.05000834009673032,
#   'make fuck money': 0.05000000000006902,
#   'say talk mean': 0.050000000000090486,
#   'ill hell mr': 0.05000000000007887,
#   'im think oh': 0.050000000000082395,
#   'youre right thats': 0.050000000000081785,
#   'hes man let': 0.05000000000006425,
#   'whats need thank': 0.05000000000008107,
#   'yes kill sure': 0.050000000000090916},
#  {'tell want good': 0.02500321080038765,
#   'know dont like': 0.20951371093126422,
#   'make fuck money': 0.025004117615410326,
#   'say talk mean': 0.025000000013160693,
#   'ill hell mr': 0.2685559649542488,
#   'im think oh': 0.025003250133459973,
#   'youre right thats': 0.025004395936555766,
#   'hes man let': 0.025004805502151933,
#   'whats need thank': 0.3469105441001344,
#   'yes kill sure': 0.02500000001322628},
#  {'tell want good': 0.05000000002472018,
#   'know dont like': 0.05000000001945093,
#   'make fuck money': 0.5499938179398742,
#   'say talk mean': 0.050000000031830284,
#   'ill hell mr': 0.050000000027753205,
#   'im think oh': 0.050006181844420176,
#   'youre right thats': 0.05000000002880339,
#   'hes man let': 0.050000000022636736,
#   'whats need thank': 0.05000000002852744,
#   'yes kill sure': 0.05000000003198356},
#  {'tell want good': 0.03333333333450817,
#   'know dont like': 0.03333333333425777,
#   'make fuck money': 0.0333333333344867,
#   'say talk mean': 0.36666666148425536,
#   'ill hell mr': 0.03334256940203341,
#   'im think oh': 0.03333673162453582,
#   'youre right thats': 0.033333333334700975,
#   'hes man let': 0.03333333333440716,
#   'whats need thank': 0.0333333333346881,
#   'yes kill sure': 0.3666540374821266},
#  {'tell want good': 0.0333333333967287,
#   'know dont like': 0.6999914456410115,
#   'make fuck money': 0.033333333394816415,
#   'say talk mean': 0.03333333341392844,
#   'ill hell mr': 0.033333333403568866,
#   'im think oh': 0.03333333340680582,
#   'youre right thats': 0.033335327384129934,
#   'hes man let': 0.03333762147787862,
#   'whats need thank': 0.033333333405739615,
#   'yes kill sure': 0.03333560507539203},
#  {'tell want good': 0.020001199368012083,
#   'know dont like': 0.02000346810769968,
#   'make fuck money': 0.38740648962854196,
#   'say talk mean': 0.020000000056318672,
#   'ill hell mr': 0.020000000049104183,
#   'im think oh': 0.020000000051329122,
#   'youre right thats': 0.02000000005095226,
#   'hes man let': 0.020000000040047438,
#   'whats need thank': 0.24166725007993298,
#   'yes kill sure': 0.23092159256806177},
#  {'tell want good': 0.05000000000060188,
#   'know dont like': 0.0500000000004735,
#   'make fuck money': 0.050000000000590905,
#   'say talk mean': 0.05000000000077508,
#   'ill hell mr': 0.05000000000067564,
#   'im think oh': 0.05000000000070633,
#   'youre right thats': 0.549999999994153,
#   'hes man let': 0.05000000000055017,
#   'whats need thank': 0.05000000000069452,
#   'yes kill sure': 0.0500000000007788},
#  {'tell want good': 0.014294225850944177,
#   'know dont like': 0.5856996296262854,
#   'make fuck money': 0.014285714285964271,
#   'say talk mean': 0.014287764538360902,
#   'ill hell mr': 0.014288258556437356,
#   'im think oh': 0.01428789508371199,
#   'youre right thats': 0.014286102067551518,
#   'hes man let': 0.014286138137384961,
#   'whats need thank': 0.014286419185282147,
#   'yes kill sure': 0.2999978526680772},
#  {'tell want good': 0.3665572513478331,
#   'know dont like': 0.27358933051497714,
#   'make fuck money': 0.010004433952533183,
#   'say talk mean': 0.2898333490452896,
#   'ill hell mr': 0.010004966607891977,
#   'im think oh': 0.01000075660851124,
#   'youre right thats': 0.010003626660738327,
#   'hes man let': 0.010005369377597795,
#   'whats need thank': 0.010000915877735567,
#   'yes kill sure': 0.010000000006891907},
#  {'tell want good': 0.007694032267666631,
#   'know dont like': 0.00769281493631283,
#   'make fuck money': 0.007692987625484807,
#   'say talk mean': 0.007692710923919787,
#   'ill hell mr': 0.007692737299981628,
#   'im think oh': 0.41088300844637793,
#   'youre right thats': 0.007692609209912011,
#   'hes man let': 0.20700046211485934,
#   'whats need thank': 0.11607170868551306,
#   'yes kill sure': 0.21988692848997193},
#  {'tell want good': 0.2999877464594467,
#   'know dont like': 0.4296759704694502,
#   'make fuck money': 0.014290394706831471,
#   'say talk mean': 0.014286188668396945,
#   'ill hell mr': 0.014285714286423428,
#   'im think oh': 0.014287440206884574,
#   'youre right thats': 0.01429780698746392,
#   'hes man let': 0.014292911528363757,
#   'whats need thank': 0.17030956040988646,
#   'yes kill sure': 0.014286266276852522},
#  {'tell want good': 0.050000000000195444,
#   'know dont like': 0.05000000000015378,
#   'make fuck money': 0.050000000000191856,
#   'say talk mean': 0.05000000000025164,
#   'ill hell mr': 0.05000000000021934,
#   'im think oh': 0.5499999999981035,
#   'youre right thats': 0.050000000000227494,
#   'hes man let': 0.05000000000017866,
#   'whats need thank': 0.050000000000225475,
#   'yes kill sure': 0.0500000000002528},
#  {'tell want good': 0.012500612349206035,
#   'know dont like': 0.012501937083442933,
#   'make fuck money': 0.012501374812184801,
#   'say talk mean': 0.165083714140765,
#   'ill hell mr': 0.012500000000734084,
#   'im think oh': 0.012502892737726706,
#   'youre right thats': 0.7349087288726253,
#   'hes man let': 0.012500000000598222,
#   'whats need thank': 0.012500740001870597,
#   'yes kill sure': 0.012500000000846338},
#  {'tell want good': 0.020000000004508373,
#   'know dont like': 0.21999476533320553,
#   'make fuck money': 0.020002192140623095,
#   'say talk mean': 0.020000000005804756,
#   'ill hell mr': 0.02000000000506107,
#   'im think oh': 0.22000011529336425,
#   'youre right thats': 0.22000006982801923,
#   'hes man let': 0.2199997559201772,
#   'whats need thank': 0.02000310146340619,
#   'yes kill sure': 0.020000000005830285},
#  {'tell want good': 0.05000000000018695,
#   'know dont like': 0.05000000000014713,
#   'make fuck money': 0.05000000000018357,
#   'say talk mean': 0.050000000000240685,
#   'ill hell mr': 0.050000000000209814,
#   'im think oh': 0.050011439403919125,
#   'youre right thats': 0.05000000000021768,
#   'hes man let': 0.0500000000001709,
#   'whats need thank': 0.05000000000021566,
#   'yes kill sure': 0.5499885605945085},
#  {'tell want good': 0.011113241786807893,
#   'know dont like': 0.011113034161465453,
#   'make fuck money': 0.011115688494853658,
#   'say talk mean': 0.011113609177434675,
#   'ill hell mr': 0.011111111208202738,
#   'im think oh': 0.6777668826272572,
#   'youre right thats': 0.011111111211802659,
#   'hes man let': 0.23332431965873549,
#   'whats need thank': 0.011111111210916217,
#   'yes kill sure': 0.011119890462524212},
#  {'tell want good': 0.02500102278819482,
#   'know dont like': 0.4830080593976888,
#   'make fuck money': 0.025000000000707418,
#   'say talk mean': 0.025000000000927575,
#   'ill hell mr': 0.02500097730768554,
#   'im think oh': 0.02500103530589969,
#   'youre right thats': 0.02500139984939041,
#   'hes man let': 0.3169875053477427,
#   'whats need thank': 0.025000000000831298,
#   'yes kill sure': 0.025000000000931798},
#  {'tell want good': 0.03333333333400346,
#   'know dont like': 0.03333333333386113,
#   'make fuck money': 0.03333333333399145,
#   'say talk mean': 0.033333333334196316,
#   'ill hell mr': 0.03333555906394807,
#   'im think oh': 0.033333333334119544,
#   'youre right thats': 0.6999970117360582,
#   'hes man let': 0.0333340958615151,
#   'whats need thank': 0.03333333333410633,
#   'yes kill sure': 0.033333333334200466},
#  {'tell want good': 0.033333333342497266,
#   'know dont like': 0.033339418040854614,
#   'make fuck money': 0.03334248161509407,
#   'say talk mean': 0.033345073887036634,
#   'ill hell mr': 0.033334704478796905,
#   'im think oh': 0.03333333334407997,
#   'youre right thats': 0.033333333343990613,
#   'hes man let': 0.36664586789667347,
#   'whats need thank': 0.03334078206258119,
#   'yes kill sure': 0.36665167198839527},
#  {'tell want good': 0.1372632595699385,
#   'know dont like': 0.16874378331017909,
#   'make fuck money': 0.011114980016088013,
#   'say talk mean': 0.3894593592984005,
#   'ill hell mr': 0.011111937285236602,
#   'im think oh': 0.011113187060421663,
#   'youre right thats': 0.011113670785769676,
#   'hes man let': 0.011115142868312864,
#   'whats need thank': 0.12674177450435872,
#   'yes kill sure': 0.12222290530129427},
#  {'tell want good': 0.05000000000042322,
#   'know dont like': 0.05000697853792423,
#   'make fuck money': 0.0500000000004156,
#   'say talk mean': 0.05000000000054473,
#   'ill hell mr': 0.05000000000047486,
#   'im think oh': 0.05000000000049622,
#   'youre right thats': 0.05000000000049252,
#   'hes man let': 0.05000000000038687,
#   'whats need thank': 0.050000000000488216,
#   'yes kill sure': 0.5499930214583535},
#  {'tell want good': 0.1998780052618582,
#   'know dont like': 0.016669701348997167,
#   'make fuck money': 0.27879692812615564,
#   'say talk mean': 0.016669585939975713,
#   'ill hell mr': 0.4046356745133381,
#   'im think oh': 0.016670370156624915,
#   'youre right thats': 0.016675018023783957,
#   'hes man let': 0.01666731185072105,
#   'whats need thank': 0.016669120645704454,
#   'yes kill sure': 0.016668284132840733},
#  {'tell want good': 0.033333333333551304,
#   'know dont like': 0.0333435691176331,
#   'make fuck money': 0.03333647330373848,
#   'say talk mean': 0.6999561161741522,
#   'ill hell mr': 0.033336215085838596,
#   'im think oh': 0.03335297155783362,
#   'youre right thats': 0.033333333333587005,
#   'hes man let': 0.0333354020761243,
#   'whats need thank': 0.03333675918425065,
#   'yes kill sure': 0.03333582683329077},
#  {'tell want good': 0.033333333336947955,
#   'know dont like': 0.033336922516213646,
#   'make fuck money': 0.03333419481649819,
#   'say talk mean': 0.033333333337985945,
#   'ill hell mr': 0.36665905768383866,
#   'im think oh': 0.03333742285115091,
#   'youre right thats': 0.033333333337539385,
#   'hes man let': 0.36665605796733813,
#   'whats need thank': 0.03333857292402685,
#   'yes kill sure': 0.033337771228460114},
#  {'tell want good': 0.18444414436631315,
#   'know dont like': 0.46562683914902747,
#   'make fuck money': 0.2571747846027371,
#   'say talk mean': 0.06274984430566666,
#   'ill hell mr': 0.005000709076949982,
#   'im think oh': 0.005000240697638582,
#   'youre right thats': 0.005000322471882247,
#   'hes man let': 0.005001929997282113,
#   'whats need thank': 0.005001185330987,
#   'yes kill sure': 0.005000000001515671},
#  {'tell want good': 0.025000000321997597,
#   'know dont like': 0.025000000253378275,
#   'make fuck money': 0.02500265045426084,
#   'say talk mean': 0.02500000041456201,
#   'ill hell mr': 0.025000000361389364,
#   'im think oh': 0.025000000377645548,
#   'youre right thats': 0.02500000037483484,
#   'hes man let': 0.27500379304573314,
#   'whats need thank': 0.02500000037154906,
#   'yes kill sure': 0.5249935540246493},
#  {'tell want good': 0.03333718723460018,
#   'know dont like': 0.03333333333354471,
#   'make fuck money': 0.03333333333359705,
#   'say talk mean': 0.03333333333367912,
#   'ill hell mr': 0.3666666621021645,
#   'im think oh': 0.03333333333364835,
#   'youre right thats': 0.36666281732786343,
#   'hes man let': 0.03333333333357888,
#   'whats need thank': 0.03333333333364315,
#   'yes kill sure': 0.033333333333680736},
#  {'tell want good': 0.020005739123366385,
#   'know dont like': 0.020000000022689195,
#   'make fuck money': 0.020000727952117242,
#   'say talk mean': 0.2199945357194573,
#   'ill hell mr': 0.020002545442218744,
#   'im think oh': 0.02000282745247297,
#   'youre right thats': 0.6199905214753525,
#   'hes man let': 0.020001253295260216,
#   'whats need thank': 0.02000184947977378,
#   'yes kill sure': 0.020000000037291583},
#  {'tell want good': 0.27499754019400957,
#   'know dont like': 0.02500000001478919,
#   'make fuck money': 0.025000000018429443,
#   'say talk mean': 0.025000000024181106,
#   'ill hell mr': 0.025007717648046237,
#   'im think oh': 0.2750002052229732,
#   'youre right thats': 0.025000000021858697,
#   'hes man let': 0.02500270924596541,
#   'whats need thank': 0.2749918275854658,
#   'yes kill sure': 0.025000000024281367},
#  {'tell want good': 0.05000000000016822,
#   'know dont like': 0.05000000000013236,
#   'make fuck money': 0.050000000000165176,
#   'say talk mean': 0.050000000000216614,
#   'ill hell mr': 0.05000547733545428,
#   'im think oh': 0.05000000000019725,
#   'youre right thats': 0.05000705258177285,
#   'hes man let': 0.5499874700814815,
#   'whats need thank': 0.05000000000019409,
#   'yes kill sure': 0.05000000000021766},
#  {'tell want good': 0.009091185079452684,
#   'know dont like': 0.49255262295160007,
#   'make fuck money': 0.009092373539579538,
#   'say talk mean': 0.2671607541199714,
#   'ill hell mr': 0.009094048156222,
#   'im think oh': 0.17663670532912767,
#   'youre right thats': 0.009092364931579356,
#   'hes man let': 0.009092167217269746,
#   'whats need thank': 0.009094328684266123,
#   'yes kill sure': 0.009093449990931502},
#  {'tell want good': 0.03334066956370713,
#   'know dont like': 0.033333333336855606,
#   'make fuck money': 0.03333333333773022,
#   'say talk mean': 0.03333333333909345,
#   'ill hell mr': 0.36666307017273464,
#   'im think oh': 0.03333333333858247,
#   'youre right thats': 0.36666292689624896,
#   'hes man let': 0.0333333333374258,
#   'whats need thank': 0.03333333333849763,
#   'yes kill sure': 0.03333333333912423},
#  {'tell want good': 0.009091722415185414,
#   'know dont like': 0.009092536894980486,
#   'make fuck money': 0.009092967341509849,
#   'say talk mean': 0.2151239655690478,
#   'ill hell mr': 0.009091680948889146,
#   'im think oh': 0.39222111629153106,
#   'youre right thats': 0.009092860522276851,
#   'hes man let': 0.009093475746998782,
#   'whats need thank': 0.1078753030729217,
#   'yes kill sure': 0.230224371196659},
#  {'tell want good': 0.619966974524199,
#   'know dont like': 0.02000203122078198,
#   'make fuck money': 0.02000000002259524,
#   'say talk mean': 0.02000961997890566,
#   'ill hell mr': 0.020003602145414596,
#   'im think oh': 0.020000000026987225,
#   'youre right thats': 0.020000000026775783,
#   'hes man let': 0.020000000021026334,
#   'whats need thank': 0.02001904599066875,
#   'yes kill sure': 0.21999872604264548},
#  {'tell want good': 0.025000000001262377,
#   'know dont like': 0.3108944774102882,
#   'make fuck money': 0.02500000000123972,
#   'say talk mean': 0.025001369842810955,
#   'ill hell mr': 0.02500138917375708,
#   'im think oh': 0.025001614947484145,
#   'youre right thats': 0.48908728249073513,
#   'hes man let': 0.02501386612933343,
#   'whats need thank': 0.02500000000145628,
#   'yes kill sure': 0.025000000001632668},
#  {'tell want good': 0.05000000002225726,
#   'know dont like': 0.05000000001752971,
#   'make fuck money': 0.050000000021869884,
#   'say talk mean': 0.5499999997864403,
#   'ill hell mr': 0.05000000002498291,
#   'im think oh': 0.05000000002611981,
#   'youre right thats': 0.05000000002591565,
#   'hes man let': 0.05000000002035734,
#   'whats need thank': 0.050000000025700146,
#   'yes kill sure': 0.050000000028826985},
#  {'tell want good': 0.016667439696902726,
#   'know dont like': 0.34999828815098916,
#   'make fuck money': 0.01666666666758119,
#   'say talk mean': 0.016666666667865027,
#   'ill hell mr': 0.016666666667712073,
#   'im think oh': 0.01666754608981303,
#   'youre right thats': 0.3499992841611023,
#   'hes man let': 0.01666742359007376,
#   'whats need thank': 0.1833333516400896,
#   'yes kill sure': 0.016666666667871127},
#  {'tell want good': 0.05000000000065069,
#   'know dont like': 0.05000538377235218,
#   'make fuck money': 0.05000000000063903,
#   'say talk mean': 0.05000000000083767,
#   'ill hell mr': 0.5499884819495233,
#   'im think oh': 0.05000613427305259,
#   'youre right thats': 0.050000000000757376,
#   'hes man let': 0.05000000000059488,
#   'whats need thank': 0.05000000000075069,
#   'yes kill sure': 0.050000000000841725},
#  {'tell want good': 0.025000000012719494,
#   'know dont like': 0.0250000000100117,
#   'make fuck money': 0.02500046904731425,
#   'say talk mean': 0.02500000001637219,
#   'ill hell mr': 0.7749792671956913,
#   'im think oh': 0.02500000001491455,
#   'youre right thats': 0.025000000014811542,
#   'hes man let': 0.025019826901049827,
#   'whats need thank': 0.0250004367706614,
#   'yes kill sure': 0.0250000000164537},
#  {'tell want good': 0.00833353443636097,
#   'know dont like': 0.008333596180561328,
#   'make fuck money': 0.2699919779521736,
#   'say talk mean': 0.00833446898926799,
#   'ill hell mr': 0.008335051202004912,
#   'im think oh': 0.008333399274293139,
#   'youre right thats': 0.008336213791733011,
#   'hes man let': 0.008338655715499797,
#   'whats need thank': 0.008333826201242801,
#   'yes kill sure': 0.6633292762568623},
#  {'tell want good': 0.012501581138395682,
#   'know dont like': 0.012500000019426685,
#   'make fuck money': 0.14720803864201115,
#   'say talk mean': 0.01250083409698985,
#   'ill hell mr': 0.2198909136455154,
#   'im think oh': 0.012501858081094547,
#   'youre right thats': 0.13750062369508498,
#   'hes man let': 0.42039220456964754,
#   'whats need thank': 0.01250294587614152,
#   'yes kill sure': 0.012501000235692604},
#  {'tell want good': 0.014287541594941463,
#   'know dont like': 0.014288822371451732,
#   'make fuck money': 0.014286432092423489,
#   'say talk mean': 0.01429105426803496,
#   'ill hell mr': 0.014288234131813229,
#   'im think oh': 0.5315751376402797,
#   'youre right thats': 0.35412103818928525,
#   'hes man let': 0.014287104999882737,
#   'whats need thank': 0.014286643718430945,
#   'yes kill sure': 0.014287990993456534},
#  {'tell want good': 0.02500722198560134,
#   'know dont like': 0.7749815015917613,
#   'make fuck money': 0.025000000029598755,
#   'say talk mean': 0.025002179255330964,
#   'ill hell mr': 0.02500000003383204,
#   'im think oh': 0.025006790289661452,
#   'youre right thats': 0.025000000035124027,
#   'hes man let': 0.025002306705188302,
#   'whats need thank': 0.025000000034784167,
#   'yes kill sure': 0.025000000039117648},
#  {'tell want good': 0.03333333333424175,
#   'know dont like': 0.033333333334047796,
#   'make fuck money': 0.03333790373904823,
#   'say talk mean': 0.0333333333345028,
#   'ill hell mr': 0.3666666800241541,
#   'im think oh': 0.36665628705815606,
#   'youre right thats': 0.0333333333343909,
#   'hes man let': 0.03333542660932929,
#   'whats need thank': 0.03333703589762032,
#   'yes kill sure': 0.033333333334508816},
#  {'tell want good': 0.025000000002906572,
#   'know dont like': 0.2750000487998616,
#   'make fuck money': 0.025000000002856425,
#   'say talk mean': 0.02500739077417751,
#   'ill hell mr': 0.5249884548172346,
#   'im think oh': 0.02500000000341003,
#   'youre right thats': 0.025003064078398148,
#   'hes man let': 0.025000000002659943,
#   'whats need thank': 0.025000000003356317,
#   'yes kill sure': 0.025001041515138992},
#  {'tell want good': 0.011113957530406763,
#   'know dont like': 0.7888758782151468,
#   'make fuck money': 0.011113470939410739,
#   'say talk mean': 0.011115600652993298,
#   'ill hell mr': 0.011111111111789095,
#   'im think oh': 0.011111624179071997,
#   'youre right thats': 0.011113675470493608,
#   'hes man let': 0.011113137114356584,
#   'whats need thank': 0.12222043367443794,
#   'yes kill sure': 0.011111111111892964},
#  {'tell want good': 0.012500000001230586,
#   'know dont like': 0.5000810414477299,
#   'make fuck money': 0.012502596185973701,
#   'say talk mean': 0.173139295627004,
#   'ill hell mr': 0.012500000001381018,
#   'im think oh': 0.012500000001443103,
#   'youre right thats': 0.012500505160460373,
#   'hes man let': 0.012504294512973257,
#   'whats need thank': 0.012500000001420592,
#   'yes kill sure': 0.23927226706038346},
#  {'tell want good': 0.009090909171564767,
#   'know dont like': 0.47084101949448454,
#   'make fuck money': 0.009100732864922474,
#   'say talk mean': 0.4564143975005802,
#   'ill hell mr': 0.009091209007499232,
#   'im think oh': 0.009092289795771069,
#   'youre right thats': 0.009091837320963372,
#   'hes man let': 0.00909210429625127,
#   'whats need thank': 0.00909355733916035,
#   'yes kill sure': 0.009091943208802793},
#  {'tell want good': 0.012500131189303435,
#   'know dont like': 0.8874886340815753,
#   'make fuck money': 0.012500937671428776,
#   'say talk mean': 0.012501544979118916,
#   'ill hell mr': 0.012500175427783124,
#   'im think oh': 0.01250149512308407,
#   'youre right thats': 0.012500000005211273,
#   'hes man let': 0.012503997422268221,
#   'whats need thank': 0.012502335835134428,
#   'yes kill sure': 0.012500748265092301},
#  {'tell want good': 0.007694823077812399,
#   'know dont like': 0.31883024486811995,
#   'make fuck money': 0.007694191473297637,
#   'say talk mean': 0.24679752900452026,
#   'ill hell mr': 0.007694942944359927,
#   'im think oh': 0.007694439312964333,
#   'youre right thats': 0.00769545132234187,
#   'hes man let': 0.08796659626769547,
#   'whats need thank': 0.3002394739349964,
#   'yes kill sure': 0.0076923077938918834},
#  {'tell want good': 0.03333333338971012,
#   'know dont like': 0.03333333337770665,
#   'make fuck money': 0.03333333338870359,
#   'say talk mean': 0.033333333405928936,
#   'ill hell mr': 0.033333333396630235,
#   'im think oh': 0.03333333339945693,
#   'youre right thats': 0.03333333339896375,
#   'hes man let': 0.6999999994380018,
#   'whats need thank': 0.03333333339842286,
#   'yes kill sure': 0.033333333406475034},
#  {'tell want good': 0.025000000011601776,
#   'know dont like': 0.025003489272609838,
#   'make fuck money': 0.02500000001139959,
#   'say talk mean': 0.27499947305732203,
#   'ill hell mr': 0.02500000001302171,
#   'im think oh': 0.025000000013613626,
#   'youre right thats': 0.025000000013507537,
#   'hes man let': 0.2750002130985598,
#   'whats need thank': 0.025000000013394908,
#   'yes kill sure': 0.2749968244949693},
#  {'tell want good': 0.05000708248951745,
#   'know dont like': 0.05000000000044473,
#   'make fuck money': 0.0500048889647662,
#   'say talk mean': 0.05000000000072779,
#   'ill hell mr': 0.0500000000006345,
#   'im think oh': 0.05000653965820491,
#   'youre right thats': 0.5499756440256864,
#   'hes man let': 0.050000000000516895,
#   'whats need thank': 0.05000584485876956,
#   'yes kill sure': 0.050000000000731536},
#  {'tell want good': 0.050000000004469775,
#   'know dont like': 0.05000000000351738,
#   'make fuck money': 0.050000000004389256,
#   'say talk mean': 0.5499999999571306,
#   'ill hell mr': 0.050000000005015935,
#   'im think oh': 0.05000000000524223,
#   'youre right thats': 0.050000000005207226,
#   'hes man let': 0.050000000004087136,
#   'whats need thank': 0.05000000000516069,
#   'yes kill sure': 0.050000000005779845},
#  {'tell want good': 0.1,
#   'know dont like': 0.1,
#   'make fuck money': 0.1,
#   'say talk mean': 0.1,
#   'ill hell mr': 0.1,
#   'im think oh': 0.1,
#   'youre right thats': 0.1,
#   'hes man let': 0.1,
#   'whats need thank': 0.1,
#   'yes kill sure': 0.1},
#  {'tell want good': 0.02500000000018076,
#   'know dont like': 0.025005416505854954,
#   'make fuck money': 0.02500000000017752,
#   'say talk mean': 0.025003711928778354,
#   'ill hell mr': 0.025000000000202856,
#   'im think oh': 0.2749908729690015,
#   'youre right thats': 0.5249999985951964,
#   'hes man let': 0.025000000000165286,
#   'whats need thank': 0.02500000000020854,
#   'yes kill sure': 0.025000000000233842},
#  {'tell want good': 0.36665555304989494,
#   'know dont like': 0.033335603857184246,
#   'make fuck money': 0.03333588904342816,
#   'say talk mean': 0.033333333335524754,
#   'ill hell mr': 0.03333344743121925,
#   'im think oh': 0.03333333333532938,
#   'youre right thats': 0.033333333335314824,
#   'hes man let': 0.3666666540303746,
#   'whats need thank': 0.033333333335297574,
#   'yes kill sure': 0.033339519246432164},
#  {'tell want good': 0.020000000008692564,
#   'know dont like': 0.37165539667456965,
#   'make fuck money': 0.23962180439655048,
#   'say talk mean': 0.02000000001118915,
#   'ill hell mr': 0.020003490942418687,
#   'im think oh': 0.020000000010187684,
#   'youre right thats': 0.020000000010115728,
#   'hes man let': 0.02000000000794512,
#   'whats need thank': 0.24871930792709587,
#   'yes kill sure': 0.02000000001123508},
#  {'tell want good': 0.594844098613823,
#   'know dont like': 0.020002508089992134,
#   'make fuck money': 0.020000000001529274,
#   'say talk mean': 0.24515179056542458,
#   'ill hell mr': 0.020000000001748407,
#   'im think oh': 0.020000697407660167,
#   'youre right thats': 0.02000090531458779,
#   'hes man let': 0.020000000001424535,
#   'whats need thank': 0.020000000001795904,
#   'yes kill sure': 0.02000000000201401},
#  {'tell want good': 0.033333333336715426,
#   'know dont like': 0.03333333333599489,
#   'make fuck money': 0.033333333336654426,
#   'say talk mean': 0.36666660172390053,
#   'ill hell mr': 0.03333333333712871,
#   'im think oh': 0.03333333333730003,
#   'youre right thats': 0.3666667315809356,
#   'hes man let': 0.03333333333642585,
#   'whats need thank': 0.033333333337237786,
#   'yes kill sure': 0.03333333333770676},
#  {'tell want good': 0.012504477669667394,
#   'know dont like': 0.21753255240502836,
#   'make fuck money': 0.012501423318779516,
#   'say talk mean': 0.012505978791871626,
#   'ill hell mr': 0.012500000009296984,
#   'im think oh': 0.26895838259927807,
#   'youre right thats': 0.1375002090836106,
#   'hes man let': 0.012502163081816273,
#   'whats need thank': 0.30099423328661773,
#   'yes kill sure': 0.012500579754033419},
#  {'tell want good': 0.02500000000855132,
#   'know dont like': 0.025000000006729042,
#   'make fuck money': 0.02501087257362309,
#   'say talk mean': 0.025000000011010864,
#   'ill hell mr': 0.025001631082427627,
#   'im think oh': 0.025000000010025312,
#   'youre right thats': 0.5117150542744988,
#   'hes man let': 0.28827244201220936,
#   'whats need thank': 0.025000000009863587,
#   'yes kill sure': 0.02500000001106105},
#  {'tell want good': 0.05000000001237044,
#   'know dont like': 0.05000000000974381,
#   'make fuck money': 0.05000000001215857,
#   'say talk mean': 0.5499949952862586,
#   'ill hell mr': 0.05000500460892511,
#   'im think oh': 0.050000000014523906,
#   'youre right thats': 0.0500000000144071,
#   'hes man let': 0.050000000011319934,
#   'whats need thank': 0.050000000014280906,
#   'yes kill sure': 0.050000000016011535},
#  {'tell want good': 0.31216971296272833,
#   'know dont like': 0.011111538680937273,
#   'make fuck money': 0.011112835861422721,
#   'say talk mean': 0.23333046711015715,
#   'ill hell mr': 0.01111232716623628,
#   'im think oh': 0.011112165884612852,
#   'youre right thats': 0.011111315199356592,
#   'hes man let': 0.26559974127340763,
#   'whats need thank': 0.12222260287237702,
#   'yes kill sure': 0.011117292988764084},
#  {'tell want good': 0.033333333336788847,
#   'know dont like': 0.36666667534980485,
#   'make fuck money': 0.03333333333672721,
#   'say talk mean': 0.03333333333778174,
#   'ill hell mr': 0.36666665795253844,
#   'im think oh': 0.03333333333738603,
#   'youre right thats': 0.03333333333735529,
#   'hes man let': 0.03333333333649315,
#   'whats need thank': 0.03333333333732033,
#   'yes kill sure': 0.03333333333780418},
#  {'tell want good': 0.011111726066686728,
#   'know dont like': 0.3083805699473458,
#   'make fuck money': 0.011113728846541765,
#   'say talk mean': 0.01111254586668517,
#   'ill hell mr': 0.12222233327557203,
#   'im think oh': 0.011111111116577898,
#   'youre right thats': 0.01111138034927397,
#   'hes man let': 0.3568731295812115,
#   'whats need thank': 0.011111579996330188,
#   'yes kill sure': 0.14585189495377499},
#  {'tell want good': 0.16095752394969842,
#   'know dont like': 0.06937617131468149,
#   'make fuck money': 0.005557136884726382,
#   'say talk mean': 0.0055557767442204085,
#   'ill hell mr': 0.0976954143640629,
#   'im think oh': 0.26364495661428244,
#   'youre right thats': 0.380540547579868,
#   'hes man let': 0.00555902973422973,
#   'whats need thank': 0.005555889053855404,
#   'yes kill sure': 0.005557553760374851},
#  {'tell want good': 0.05000000002357532,
#   'know dont like': 0.050000000018538465,
#   'make fuck money': 0.050000000023155675,
#   'say talk mean': 0.050000000030334,
#   'ill hell mr': 0.5499999997700383,
#   'im think oh': 0.0500000000276351,
#   'youre right thats': 0.050000000027439775,
#   'hes man let': 0.05000000002152903,
#   'whats need thank': 0.050000000027239234,
#   'yes kill sure': 0.050000000030515},
#  {'tell want good': 0.016669544109273415,
#   'know dont like': 0.016672305592841746,
#   'make fuck money': 0.01666750474682504,
#   'say talk mean': 0.1930004982040415,
#   'ill hell mr': 0.18333782853968608,
#   'im think oh': 0.016667668597984436,
#   'youre right thats': 0.2680590538566257,
#   'hes man let': 0.016668176413656186,
#   'whats need thank': 0.016667791181203824,
#   'yes kill sure': 0.2555896287578621},
#  {'tell want good': 0.05000000000825184,
#   'know dont like': 0.050000000006492504,
#   'make fuck money': 0.5499999999183599,
#   'say talk mean': 0.0500000000106212,
#   'ill hell mr': 0.050000000009261414,
#   'im think oh': 0.050000000009674125,
#   'youre right thats': 0.05000000000960404,
#   'hes man let': 0.050000000007545155,
#   'whats need thank': 0.050000000009517875,
#   'yes kill sure': 0.05000000001067199},
#  {'tell want good': 0.050000000007371495,
#   'know dont like': 0.05000000000579862,
#   'make fuck money': 0.05000000000723577,
#   'say talk mean': 0.05000000000949486,
#   'ill hell mr': 0.050000000008271615,
#   'im think oh': 0.05000000000864312,
#   'youre right thats': 0.05000000000857862,
#   'hes man let': 0.05000000000673637,
#   'whats need thank': 0.5499999999283329,
#   'yes kill sure': 0.05000000000953657},
#  {'tell want good': 0.05000000009099936,
#   'know dont like': 0.050000000071676313,
#   'make fuck money': 0.050000000089436315,
#   'say talk mean': 0.05000000011718501,
#   'ill hell mr': 0.05000000010251387,
#   'im think oh': 0.05000332166062248,
#   'youre right thats': 0.05000000010615333,
#   'hes man let': 0.05000000008334919,
#   'whats need thank': 0.5499966775602617,
#   'yes kill sure': 0.050000000117802416},
#  {'tell want good': 0.2749922700012392,
#   'know dont like': 0.02500400369821704,
#   'make fuck money': 0.5249839988086746,
#   'say talk mean': 0.025002876047075295,
#   'ill hell mr': 0.025001571350434754,
#   'im think oh': 0.025003361089926842,
#   'youre right thats': 0.025000000250209313,
#   'hes man let': 0.02500503929821542,
#   'whats need thank': 0.025005299582571715,
#   'yes kill sure': 0.025001579873435688},
#  {'tell want good': 0.5499916599026309,
#   'know dont like': 0.05000834009673032,
#   'make fuck money': 0.05000000000006902,
#   'say talk mean': 0.050000000000090486,
#   'ill hell mr': 0.05000000000007887,
#   'im think oh': 0.050000000000082395,
#   'youre right thats': 0.050000000000081785,
#   'hes man let': 0.05000000000006425,
#   'whats need thank': 0.05000000000008107,
#   'yes kill sure': 0.050000000000090916},
#  {'tell want good': 0.5499916599026309,
#   'know dont like': 0.05000834009673032,
#   'make fuck money': 0.05000000000006902,
#   'say talk mean': 0.050000000000090486,
#   'ill hell mr': 0.05000000000007887,
#   'im think oh': 0.050000000000082395,
#   'youre right thats': 0.050000000000081785,
#   'hes man let': 0.05000000000006425,
#   'whats need thank': 0.05000000000008107,
#   'yes kill sure': 0.050000000000090916},
#  {'tell want good': 0.05000000000016822,
#   'know dont like': 0.05000000000013236,
#   'make fuck money': 0.050000000000165176,
#   'say talk mean': 0.050000000000216614,
#   'ill hell mr': 0.05000547733545428,
#   'im think oh': 0.05000000000019725,
#   'youre right thats': 0.05000705258177285,
#   'hes man let': 0.5499874700814815,
#   'whats need thank': 0.05000000000019409,
#   'yes kill sure': 0.05000000000021766},
#  {'tell want good': 0.01666736306888222,
#   'know dont like': 0.016669401667232072,
#   'make fuck money': 0.016670259763362522,
#   'say talk mean': 0.016667251079029034,
#   'ill hell mr': 0.35138640245073716,
#   'im think oh': 0.0166678965883838,
#   'youre right thats': 0.01666804501763541,
#   'hes man let': 0.2332842982826734,
#   'whats need thank': 0.2986498487671549,
#   'yes kill sure': 0.01666923331490961},
#  {'tell want good': 0.05000000000104052,
#   'know dont like': 0.05000000000081855,
#   'make fuck money': 0.5499935078266377,
#   'say talk mean': 0.05000000000133978,
#   'ill hell mr': 0.05000000000116815,
#   'im think oh': 0.0500000000012201,
#   'youre right thats': 0.0500000000012113,
#   'hes man let': 0.05000649216401618,
#   'whats need thank': 0.05000000000120101,
#   'yes kill sure': 0.05000000000134673},
#  {'tell want good': 0.2394624267737968,
#   'know dont like': 0.36943605849399647,
#   'make fuck money': 0.02000000000044368,
#   'say talk mean': 0.020000000000581775,
#   'ill hell mr': 0.020005787404766856,
#   'im think oh': 0.020000784807445274,
#   'youre right thats': 0.020001061138004535,
#   'hes man let': 0.25109388137985833,
#   'whats need thank': 0.020000000000521354,
#   'yes kill sure': 0.020000000000584797},
#  {'tell want good': 0.02500000000012898,
#   'know dont like': 0.29550099673453123,
#   'make fuck money': 0.025000000000126598,
#   'say talk mean': 0.02500000000016605,
#   'ill hell mr': 0.5044973527303216,
#   'im think oh': 0.025001650534141762,
#   'youre right thats': 0.025000000000150114,
#   'hes man let': 0.025000000000117897,
#   'whats need thank': 0.025000000000148764,
#   'yes kill sure': 0.02500000000016682},
#  {'tell want good': 0.012502594647942969,
#   'know dont like': 0.18232232926726272,
#   'make fuck money': 0.012503673049494556,
#   'say talk mean': 0.012501588294322382,
#   'ill hell mr': 0.012500628305544907,
#   'im think oh': 0.21472149101773344,
#   'youre right thats': 0.13750004645758762,
#   'hes man let': 0.20448407063034346,
#   'whats need thank': 0.1984607368386452,
#   'yes kill sure': 0.012502841491122728},
#  {'tell want good': 0.020000486764252395,
#   'know dont like': 0.020001605127658067,
#   'make fuck money': 0.21999999638287868,
#   'say talk mean': 0.020000770152569833,
#   'ill hell mr': 0.020000000003245758,
#   'im think oh': 0.41999681769353364,
#   'youre right thats': 0.020001237497513168,
#   'hes man let': 0.020000000002645194,
#   'whats need thank': 0.2199990863719596,
#   'yes kill sure': 0.020000000003743704},
#  {'tell want good': 0.4440810354998485,
#   'know dont like': 0.26757775268965367,
#   'make fuck money': 0.014288065616085676,
#   'say talk mean': 0.18832980352106388,
#   'ill hell mr': 0.014285714305309517,
#   'im think oh': 0.014285714306194925,
#   'youre right thats': 0.014285714306040953,
#   'hes man let': 0.014292039206914325,
#   'whats need thank': 0.014287450175921356,
#   'yes kill sure': 0.014286710372967222},
#  {'tell want good': 0.02500000000138708,
#   'know dont like': 0.02500423088162834,
#   'make fuck money': 0.025000000001362016,
#   'say talk mean': 0.025001472795002762,
#   'ill hell mr': 0.025012991143251066,
#   'im think oh': 0.5249813689725579,
#   'youre right thats': 0.025000000001614318,
#   'hes man let': 0.025000000001268015,
#   'whats need thank': 0.274996691445511,
#   'yes kill sure': 0.025003244756417548},
#  {'tell want good': 0.05000578085168579,
#   'know dont like': 0.050000000000054175,
#   'make fuck money': 0.05000000000006763,
#   'say talk mean': 0.050000000000088654,
#   'ill hell mr': 0.05000000000007726,
#   'im think oh': 0.05000000000008075,
#   'youre right thats': 0.5499942191477143,
#   'hes man let': 0.05000000000006294,
#   'whats need thank': 0.05000000000007944,
#   'yes kill sure': 0.05000000000008908},
#  {'tell want good': 0.007698861072750665,
#   'know dont like': 0.36965128993152185,
#   'make fuck money': 0.3380268263568805,
#   'say talk mean': 0.007696225441856018,
#   'ill hell mr': 0.16153014372898375,
#   'im think oh': 0.007694235038924008,
#   'youre right thats': 0.007695194988305249,
#   'hes man let': 0.0076994790897728866,
#   'whats need thank': 0.08461543665553074,
#   'yes kill sure': 0.0076923076954741685},
#  {'tell want good': 0.6999619060420772,
#   'know dont like': 0.03333879315098969,
#   'make fuck money': 0.033333333333514244,
#   'say talk mean': 0.033365967472162215,
#   'ill hell mr': 0.03333333333354007,
#   'im think oh': 0.03333333333354939,
#   'youre right thats': 0.03333333333354775,
#   'hes man let': 0.033333333333501816,
#   'whats need thank': 0.03333333333354585,
#   'yes kill sure': 0.033333333333571705},
#  {'tell want good': 0.41997840804461223,
#   'know dont like': 0.020007698418174683,
#   'make fuck money': 0.020016663773146745,
#   'say talk mean': 0.020000000000434084,
#   'ill hell mr': 0.020002185922596262,
#   'im think oh': 0.020000000000395424,
#   'youre right thats': 0.02000279019855104,
#   'hes man let': 0.21999502371437699,
#   'whats need thank': 0.020000000000389016,
#   'yes kill sure': 0.21999722992732343},
#  {'tell want good': 0.1376064206506921,
#   'know dont like': 0.45553472793225697,
#   'make fuck money': 0.01111299749918255,
#   'say talk mean': 0.011111603917681422,
#   'ill hell mr': 0.329066411066153,
#   'im think oh': 0.011112039379843695,
#   'youre right thats': 0.011111111209418668,
#   'hes man let': 0.011117629967032047,
#   'whats need thank': 0.011112781393596522,
#   'yes kill sure': 0.011114276984143107},
#  {'tell want good': 0.5510213824356115,
#   'know dont like': 0.011116532687308969,
#   'make fuck money': 0.011111512346744604,
#   'say talk mean': 0.011114233543738613,
#   'ill hell mr': 0.011111395762142998,
#   'im think oh': 0.12985355847789104,
#   'youre right thats': 0.011112475680306735,
#   'hes man let': 0.24133668684241433,
#   'whats need thank': 0.011111111111874336,
#   'yes kill sure': 0.011111111111966991},
#  {'tell want good': 0.050000000000041844,
#   'know dont like': 0.050000000000032935,
#   'make fuck money': 0.05000000000004109,
#   'say talk mean': 0.5499999999995987,
#   'ill hell mr': 0.050000000000046965,
#   'im think oh': 0.050000000000049075,
#   'youre right thats': 0.050000000000048714,
#   'hes man let': 0.05000000000003826,
#   'whats need thank': 0.05000000000004828,
#   'yes kill sure': 0.050000000000054154},
#  {'tell want good': 0.03333333333723522,
#   'know dont like': 0.03334254257062462,
#   'make fuck money': 0.03333333333716502,
#   'say talk mean': 0.36666661926531485,
#   'ill hell mr': 0.3666575048007556,
#   'im think oh': 0.03333333333790922,
#   'youre right thats': 0.033333333337877726,
#   'hes man let': 0.03333333333690136,
#   'whats need thank': 0.033333333337837195,
#   'yes kill sure': 0.03333333333837932},
#  {'tell want good': 0.36666667372790684,
#   'know dont like': 0.3666666595945417,
#   'make fuck money': 0.03333333333450931,
#   'say talk mean': 0.033333333334874884,
#   'ill hell mr': 0.033333333334676994,
#   'im think oh': 0.03333333333473736,
#   'youre right thats': 0.03333333333472701,
#   'hes man let': 0.03333333333442813,
#   'whats need thank': 0.03333333333471514,
#   'yes kill sure': 0.033333333334882774},
#  {'tell want good': 0.025000000007708786,
#   'know dont like': 0.35887562745224794,
#   'make fuck money': 0.1911229364893883,
#   'say talk mean': 0.025000000009923688,
#   'ill hell mr': 0.025001707981534546,
#   'im think oh': 0.025004776238683725,
#   'youre right thats': 0.27499495179459554,
#   'hes man let': 0.025000000007051805,
#   'whats need thank': 0.025000000008892187,
#   'yes kill sure': 0.02500000000997343},
#  {'tell want good': 0.03333333333818183,
#   'know dont like': 0.03333333333714681,
#   'make fuck money': 0.36665934185920385,
#   'say talk mean': 0.03334068671330358,
#   'ill hell mr': 0.033333333338777145,
#   'im think oh': 0.033333333339020506,
#   'youre right thats': 0.03333333333897767,
#   'hes man let': 0.3666650070415598,
#   'whats need thank': 0.033334964354222334,
#   'yes kill sure': 0.033333333339606516},
#  {'tell want good': 0.3666667308899187,
#   'know dont like': 0.03333333333571308,
#   'make fuck money': 0.033333333336302756,
#   'say talk mean': 0.36666660241743715,
#   'ill hell mr': 0.03333333333672662,
#   'im think oh': 0.033333333336879656,
#   'youre right thats': 0.033333333336855946,
#   'hes man let': 0.03333333333609843,
#   'whats need thank': 0.033333333336824464,
#   'yes kill sure': 0.033333333337243275},
#  {'tell want good': 0.014288174969265592,
#   'know dont like': 0.6610530177126762,
#   'make fuck money': 0.014285714302738296,
#   'say talk mean': 0.014285714308068635,
#   'ill hell mr': 0.014286218773216754,
#   'im think oh': 0.22465510177887352,
#   'youre right thats': 0.014285714305909782,
#   'hes man let': 0.014286547565287971,
#   'whats need thank': 0.014285714305707452,
#   'yes kill sure': 0.014288081978255877},
#  {'tell want good': 0.0333333333334749,
#   'know dont like': 0.6999999999985715,
#   'make fuck money': 0.03333333333347236,
#   'say talk mean': 0.033333333333515555,
#   'ill hell mr': 0.03333333333349223,
#   'im think oh': 0.033333333333499325,
#   'youre right thats': 0.03333333333349812,
#   'hes man let': 0.03333333333346277,
#   'whats need thank': 0.03333333333349667,
#   'yes kill sure': 0.03333333333351648},
#  {'tell want good': 0.0166666666743023,
#   'know dont like': 0.2049324899812678,
#   'make fuck money': 0.328400618133026,
#   'say talk mean': 0.016666666676491824,
#   'ill hell mr': 0.016666666675237515,
#   'im think oh': 0.3499996647568641,
#   'youre right thats': 0.016666850974356422,
#   'hes man let': 0.016666666673649647,
#   'whats need thank': 0.01666704277826254,
#   'yes kill sure': 0.01666666667654191},
#  {'tell want good': 0.010001212506227125,
#   'know dont like': 0.2156149741768418,
#   'make fuck money': 0.010000285313692719,
#   'say talk mean': 0.44010966276594543,
#   'ill hell mr': 0.16406229371025224,
#   'im think oh': 0.12020771195720342,
#   'youre right thats': 0.010000524592309783,
#   'hes man let': 0.010001214840909073,
#   'whats need thank': 0.010001860999907665,
#   'yes kill sure': 0.010000259136710779},
#  {'tell want good': 0.13750093396628546,
#   'know dont like': 0.5073637514485206,
# ...
#   'know dont like': 0.03333967949089644,
#   'make fuck money': 0.033340340203236334,
#   'say talk mean': 0.03333717104900277,
#   'ill hell mr': 0.0333333333377969,
#   'im think oh': 0.033333333337994306,
#   'youre right thats': 0.033333333337959084,
#   'hes man let': 0.3666555697001376,
#   'whats need thank': 0.033334057928208115,
#   'yes kill sure': 0.03334100740461638},
#  {'tell want good': 0.0333333333460644,
#   'know dont like': 0.03333333334335993,
#   'make fuck money': 0.033340725569350915,
#   'say talk mean': 0.03333333334974276,
#   'ill hell mr': 0.033333333347627093,
#   'im think oh': 0.03333333334827591,
#   'youre right thats': 0.03333333334815292,
#   'hes man let': 0.03333385805935659,
#   'whats need thank': 0.699992082938242,
#   'yes kill sure': 0.03333333334982746},
#  {'tell want good': 0.03333333333497619,
#   'know dont like': 0.03333333333462576,
#   'make fuck money': 0.03333754766964883,
#   'say talk mean': 0.03333333333544846,
#   'ill hell mr': 0.03333333333517644,
#   'im think oh': 0.03333333333525954,
#   'youre right thats': 0.03333333333524393,
#   'hes man let': 0.03333333333483528,
#   'whats need thank': 0.3666624081805235,
#   'yes kill sure': 0.36666671080426216},
#  {'tell want good': 0.03334216057462831,
#   'know dont like': 0.033346109490128624,
#   'make fuck money': 0.03334176895010154,
#   'say talk mean': 0.03333333333394516,
#   'ill hell mr': 0.03336317072895384,
#   'im think oh': 0.6999284449520072,
#   'youre right thats': 0.03334501196863743,
#   'hes man let': 0.03333333333376785,
#   'whats need thank': 0.0333333333338818,
#   'yes kill sure': 0.03333333333394836},
#  {'tell want good': 0.025002454323819596,
#   'know dont like': 0.025000936003090616,
#   'make fuck money': 0.3158668467544035,
#   'say talk mean': 0.025000000004513648,
#   'ill hell mr': 0.025000000003937994,
#   'im think oh': 0.02500000000411202,
#   'youre right thats': 0.025000000004084387,
#   'hes man let': 0.025001394106658723,
#   'whats need thank': 0.025002904579073493,
#   'yes kill sure': 0.484125464216306},
#  {'tell want good': 0.03333333395026024,
#   'know dont like': 0.033333333818769025,
#   'make fuck money': 0.36666343179660654,
#   'say talk mean': 0.033337707832171194,
#   'ill hell mr': 0.3666534477452784,
#   'im think oh': 0.03333333405689209,
#   'youre right thats': 0.03333333405150747,
#   'hes man let': 0.033336776248871346,
#   'whats need thank': 0.03334196636798504,
#   'yes kill sure': 0.03333333413165857},
#  {'tell want good': 0.05000000000029414,
#   'know dont like': 0.050005423348314794,
#   'make fuck money': 0.0500000000002889,
#   'say talk mean': 0.05000000000037869,
#   'ill hell mr': 0.5499945766490474,
#   'im think oh': 0.050000000000344866,
#   'youre right thats': 0.050000000000342354,
#   'hes man let': 0.050000000000268975,
#   'whats need thank': 0.050000000000339447,
#   'yes kill sure': 0.05000000000038055},
#  {'tell want good': 0.1,
#   'know dont like': 0.1,
#   'make fuck money': 0.1,
#   'say talk mean': 0.1,
#   'ill hell mr': 0.1,
#   'im think oh': 0.1,
#   'youre right thats': 0.1,
#   'hes man let': 0.1,
#   'whats need thank': 0.1,
#   'yes kill sure': 0.1},
#  {'tell want good': 0.05000000000428836,
#   'know dont like': 0.050004052958325794,
#   'make fuck money': 0.05000000000420973,
#   'say talk mean': 0.050009021139892224,
#   'ill hell mr': 0.05000000000481258,
#   'im think oh': 0.5499869258690778,
#   'youre right thats': 0.050000000004989026,
#   'hes man let': 0.05000000000391799,
#   'whats need thank': 0.050000000004942736,
#   'yes kill sure': 0.050000000005543575},
#  {'tell want good': 0.35040043936493537,
#   'know dont like': 0.010001054748463599,
#   'make fuck money': 0.010000000075051758,
#   'say talk mean': 0.010000000098394454,
#   'ill hell mr': 0.1461290967629144,
#   'im think oh': 0.010000000089635726,
#   'youre right thats': 0.010000000088966328,
#   'hes man let': 0.11000142451375118,
#   'whats need thank': 0.010002619256343916,
#   'yes kill sure': 0.3334653650015433},
#  {'tell want good': 0.05000000000057157,
#   'know dont like': 0.050000000000449754,
#   'make fuck money': 0.05000000000056089,
#   'say talk mean': 0.0500000000007356,
#   'ill hell mr': 0.05000000000064157,
#   'im think oh': 0.5499949810317445,
#   'youre right thats': 0.0500050189633757,
#   'hes man let': 0.05000000000052237,
#   'whats need thank': 0.050000000000659045,
#   'yes kill sure': 0.050000000000738926},
#  {'tell want good': 0.5499999999974223,
#   'know dont like': 0.05000000000020533,
#   'make fuck money': 0.050000000000256235,
#   'say talk mean': 0.050000000000336005,
#   'ill hell mr': 0.05000000000029296,
#   'im think oh': 0.050000000000306,
#   'youre right thats': 0.05000000000030379,
#   'hes man let': 0.05000000000023862,
#   'whats need thank': 0.05000000000030116,
#   'yes kill sure': 0.05000000000033774},
#  {'tell want good': 0.014285714287002592,
#   'know dont like': 0.01428609222744287,
#   'make fuck money': 0.014289869177753977,
#   'say talk mean': 0.1571428856930289,
#   'ill hell mr': 0.01428571428716,
#   'im think oh': 0.014285714287225863,
#   'youre right thats': 0.014285918396483773,
#   'hes man let': 0.014286657147370136,
#   'whats need thank': 0.7285643717879127,
#   'yes kill sure': 0.014287062708619349},
#  {'tell want good': 0.033333333334009584,
#   'know dont like': 0.36666667746650294,
#   'make fuck money': 0.033340014592671705,
#   'say talk mean': 0.033333333334204386,
#   'ill hell mr': 0.033333333334092705,
#   'im think oh': 0.03333333333412633,
#   'youre right thats': 0.033333333334120266,
#   'hes man let': 0.36664902552894607,
#   'whats need thank': 0.0333333333341141,
#   'yes kill sure': 0.03334428240721196},
#  {'tell want good': 0.025001073611650722,
#   'know dont like': 0.02500027497621389,
#   'make fuck money': 0.02500097023862676,
#   'say talk mean': 0.025000000004268313,
#   'ill hell mr': 0.025000000003721927,
#   'im think oh': 0.025000000003889647,
#   'youre right thats': 0.02500000000385798,
#   'hes man let': 0.025000000003031472,
#   'whats need thank': 0.7749976811504491,
#   'yes kill sure': 0.025000000004290097},
#  {'tell want good': 0.020001905451044494,
#   'know dont like': 0.02000000007189522,
#   'make fuck money': 0.02000172313901047,
#   'say talk mean': 0.020000000117743864,
#   'ill hell mr': 0.02000000010253711,
#   'im think oh': 0.2199933195839157,
#   'youre right thats': 0.24934159981133724,
#   'hes man let': 0.39066145149886994,
#   'whats need thank': 0.020000000105426127,
#   'yes kill sure': 0.02000000011821984},
#  {'tell want good': 0.033333333334319974,
#   'know dont like': 0.03333333333410981,
#   'make fuck money': 0.3666592795064187,
#   'say talk mean': 0.033333333334603206,
#   'ill hell mr': 0.033333333334440184,
#   'im think oh': 0.033333333334490164,
#   'youre right thats': 0.0333333333344823,
#   'hes man let': 0.03334069483200413,
#   'whats need thank': 0.033333333334471485,
#   'yes kill sure': 0.36666669232066},
#  {'tell want good': 0.007143780309210468,
#   'know dont like': 0.007143659279861735,
#   'make fuck money': 0.11283164148705259,
#   'say talk mean': 0.08410029648216523,
#   'ill hell mr': 0.3665237169540784,
#   'im think oh': 0.007143932793962813,
#   'youre right thats': 0.007145675540991468,
#   'hes man let': 0.39367825228636133,
#   'whats need thank': 0.00714480365527628,
#   'yes kill sure': 0.007144241211039573},
#  {'tell want good': 0.2199973622363714,
#   'know dont like': 0.020002061655946018,
#   'make fuck money': 0.4199964029806563,
#   'say talk mean': 0.020000000000597692,
#   'ill hell mr': 0.020002632492249622,
#   'im think oh': 0.02000000000054454,
#   'youre right thats': 0.22000001014673826,
#   'hes man let': 0.0200015304857593,
#   'whats need thank': 0.020000000000535773,
#   'yes kill sure': 0.020000000000600805},
#  {'tell want good': 0.00833350025648691,
#   'know dont like': 0.0916676637067507,
#   'make fuck money': 0.008335822689843559,
#   'say talk mean': 0.008333333407864619,
#   'ill hell mr': 0.008337792344205477,
#   'im think oh': 0.09166815866708113,
#   'youre right thats': 0.09166814575249156,
#   'hes man let': 0.22647348880078566,
#   'whats need thank': 0.2716732312207986,
#   'yes kill sure': 0.19350886315369173},
#  {'tell want good': 0.24997458771982614,
#   'know dont like': 0.010002764847104306,
#   'make fuck money': 0.11000094143066681,
#   'say talk mean': 0.010000000058029108,
#   'ill hell mr': 0.01000056204073802,
#   'im think oh': 0.010000595400360798,
#   'youre right thats': 0.2700275642942832,
#   'hes man let': 0.010000879994345823,
#   'whats need thank': 0.3099921041563232,
#   'yes kill sure': 0.010000000058322647},
#  {'tell want good': 0.050000000001407814,
#   'know dont like': 0.05000000000110786,
#   'make fuck money': 0.5499889577396133,
#   'say talk mean': 0.05000000000181203,
#   'ill hell mr': 0.05000000000157934,
#   'im think oh': 0.050000000001650696,
#   'youre right thats': 0.05000000000163954,
#   'hes man let': 0.05001104224774423,
#   'whats need thank': 0.05000000000162404,
#   'yes kill sure': 0.050000000001821185},
#  {'tell want good': 0.2749871938928734,
#   'know dont like': 0.275000702671959,
#   'make fuck money': 0.025000000040091445,
#   'say talk mean': 0.27500115079124415,
#   'ill hell mr': 0.025000000045913864,
#   'im think oh': 0.025000000047767378,
#   'youre right thats': 0.025000000047448716,
#   'hes man let': 0.025000000037244043,
#   'whats need thank': 0.025010952372753633,
#   'yes kill sure': 0.025000000052704377},
#  {'tell want good': 0.35342245752525303,
#   'know dont like': 0.2625010837308898,
#   'make fuck money': 0.012500288099925906,
#   'say talk mean': 0.1375007190206578,
#   'ill hell mr': 0.012500000028735674,
#   'im think oh': 0.012500264605116808,
#   'youre right thats': 0.012500000029778765,
#   'hes man let': 0.012500000023378713,
#   'whats need thank': 0.1715748948882857,
#   'yes kill sure': 0.012500292047977837},
#  {'tell want good': 0.36666670132303164,
#   'know dont like': 0.03333333333464837,
#   'make fuck money': 0.033333333334975526,
#   'say talk mean': 0.03333333333548484,
#   'ill hell mr': 0.03333333333520954,
#   'im think oh': 0.03333333333529383,
#   'youre right thats': 0.033336445051750846,
#   'hes man let': 0.03333333333486252,
#   'whats need thank': 0.36666352027924676,
#   'yes kill sure': 0.033333333335496186},
#  {'tell want good': 0.03333333333464538,
#   'know dont like': 0.03333333333436561,
#   'make fuck money': 0.03333333333462245,
#   'say talk mean': 0.03333333333502222,
#   'ill hell mr': 0.03333333333480613,
#   'im think oh': 0.033333333334872296,
#   'youre right thats': 0.03333585817481738,
#   'hes man let': 0.033333333334533734,
#   'whats need thank': 0.6999974751472836,
#   'yes kill sure': 0.033333333335031155},
#  {'tell want good': 0.2750000011874946,
#   'know dont like': 0.025000000000130595,
#   'make fuck money': 0.02500000000016295,
#   'say talk mean': 0.2749999973797549,
#   'ill hell mr': 0.0250039124555166,
#   'im think oh': 0.025000000000194575,
#   'youre right thats': 0.27499608897618805,
#   'hes man let': 0.02500000000015172,
#   'whats need thank': 0.025000000000191418,
#   'yes kill sure': 0.025000000000214663},
#  {'tell want good': 0.29999690759410425,
#   'know dont like': 0.014286977246738414,
#   'make fuck money': 0.014286047407636141,
#   'say talk mean': 0.014287831102873712,
#   'ill hell mr': 0.014286091359365052,
#   'im think oh': 0.014287340669380534,
#   'youre right thats': 0.17902705144194359,
#   'hes man let': 0.4209612595014047,
#   'whats need thank': 0.01428571432228661,
#   'yes kill sure': 0.014294779354266929},
#  {'tell want good': 0.4736735299610446,
#   'know dont like': 0.020003322079547456,
#   'make fuck money': 0.020000000000542435,
#   'say talk mean': 0.02001341615214379,
#   'ill hell mr': 0.020000000000619664,
#   'im think oh': 0.020000000000647392,
#   'youre right thats': 0.020000000000642882,
#   'hes man let': 0.020000000000504756,
#   'whats need thank': 0.3663097318035927,
#   'yes kill sure': 0.020000000000714283},
#  {'tell want good': 0.1,
#   'know dont like': 0.1,
#   'make fuck money': 0.1,
#   'say talk mean': 0.1,
#   'ill hell mr': 0.1,
#   'im think oh': 0.1,
#   'youre right thats': 0.1,
#   'hes man let': 0.1,
#   'whats need thank': 0.1,
#   'yes kill sure': 0.1},
#  {'tell want good': 0.016668377920225866,
#   'know dont like': 0.6652934750809828,
#   'make fuck money': 0.016667921959219033,
#   'say talk mean': 0.01666809041238085,
#   'ill hell mr': 0.2013574522951224,
#   'im think oh': 0.016667297868899186,
#   'youre right thats': 0.016667288927722887,
#   'hes man let': 0.016667742082561332,
#   'whats need thank': 0.016668364806293696,
#   'yes kill sure': 0.01667398864659192},
#  {'tell want good': 0.02000558072152176,
#   'know dont like': 0.020000000002718232,
#   'make fuck money': 0.22000003119948128,
#   'say talk mean': 0.02000000000444721,
#   'ill hell mr': 0.3111211437052775,
#   'im think oh': 0.3288698055917735,
#   'youre right thats': 0.02000221724735859,
#   'hes man let': 0.020001221518961974,
#   'whats need thank': 0.02000000000398624,
#   'yes kill sure': 0.020000000004473734},
#  {'tell want good': 0.01428635854955608,
#   'know dont like': 0.014289901122560239,
#   'make fuck money': 0.01429275734820209,
#   'say talk mean': 0.014285714381087286,
#   'ill hell mr': 0.3950968416435228,
#   'im think oh': 0.014286366446731678,
#   'youre right thats': 0.014286596062025198,
#   'hes man let': 0.4905975178354009,
#   'whats need thank': 0.014290276635985448,
#   'yes kill sure': 0.014287669974928372},
#  {'tell want good': 0.05000000000467401,
#   'know dont like': 0.05000000000367764,
#   'make fuck money': 0.5499999999537578,
#   'say talk mean': 0.0500000000060144,
#   'ill hell mr': 0.05000000000524435,
#   'im think oh': 0.05000000000547943,
#   'youre right thats': 0.050000000005438854,
#   'hes man let': 0.050000000004271995,
#   'whats need thank': 0.050000000005393244,
#   'yes kill sure': 0.05000000000604832},
#  {'tell want good': 0.012501628530050348,
#   'know dont like': 0.012500000006276572,
#   'make fuck money': 0.012500242646518177,
#   'say talk mean': 0.012500677413882777,
#   'ill hell mr': 0.012501917800338089,
#   'im think oh': 0.44249928911114034,
#   'youre right thats': 0.15470987521066354,
#   'hes man let': 0.3152820495072831,
#   'whats need thank': 0.012501168048560387,
#   'yes kill sure': 0.012503151725286562},
#  {'tell want good': 0.0250000000004606,
#   'know dont like': 0.0250000000003624,
#   'make fuck money': 0.02500000000045222,
#   'say talk mean': 0.025000000000592975,
#   'ill hell mr': 0.02500000000051702,
#   'im think oh': 0.5250000267702302,
#   'youre right thats': 0.025000000000536413,
#   'hes man let': 0.2749999732257208,
#   'whats need thank': 0.02500000000053149,
#   'yes kill sure': 0.025000000000595938},
#  {'tell want good': 0.011111111116875861,
#   'know dont like': 0.24622660188623482,
#   'make fuck money': 0.19990217142525854,
#   'say talk mean': 0.011112001898896683,
#   'ill hell mr': 0.011111390358197736,
#   'im think oh': 0.12222236933606098,
#   'youre right thats': 0.011111111117820162,
#   'hes man let': 0.011111111116380211,
#   'whats need thank': 0.3649810206257079,
#   'yes kill sure': 0.011111111118567265},
#  {'tell want good': 0.05000000000007474,
#   'know dont like': 0.05000000000005882,
#   'make fuck money': 0.05000000000007339,
#   'say talk mean': 0.05000000000009624,
#   'ill hell mr': 0.05000000000008391,
#   'im think oh': 0.5499999999992746,
#   'youre right thats': 0.050000000000087017,
#   'hes man let': 0.05000000000006834,
#   'whats need thank': 0.05000000000008624,
#   'yes kill sure': 0.05000000000009674},
#  {'tell want good': 0.05000000000194436,
#   'know dont like': 0.05000000000153029,
#   'make fuck money': 0.050000000001910974,
#   'say talk mean': 0.050000000002504076,
#   'ill hell mr': 0.05000000000218365,
#   'im think oh': 0.050000000002281435,
#   'youre right thats': 0.050000000002264615,
#   'hes man let': 0.050000000001778594,
#   'whats need thank': 0.5499999999810854,
#   'yes kill sure': 0.05000000000251666},
#  {'tell want good': 0.6999687142749138,
#   'know dont like': 0.03333865750310863,
#   'make fuck money': 0.03333554787039393,
#   'say talk mean': 0.033333333336424784,
#   'ill hell mr': 0.033333333336027046,
#   'im think oh': 0.03333333333614735,
#   'youre right thats': 0.03333689624301582,
#   'hes man let': 0.03333885191532741,
#   'whats need thank': 0.033333333336102555,
#   'yes kill sure': 0.03334799884853854},
#  ...]

# %%
columns=topic_dataframe.columns.tolist()    #   Creating a list of the columns.

#   Creating a list of dictionaries containing the topic distribution for each document.

json_data=[
    {column: row[column] for column in columns} 
    for row in data
]

json_data
# Out:
# [{'tell want good': 0.05000904963595088,
#   'know dont like': 0.050000000000807523,
#   'make fuck money': 0.05000000000100708,
#   'say talk mean': 0.05000000000132095,
#   'ill hell mr': 0.050000000001151616,
#   'im think oh': 0.050000000001203526,
#   'youre right thats': 0.05000000000119459,
#   'hes man let': 0.050000000000937836,
#   'whats need thank': 0.5499819807157692,
#   'yes kill sure': 0.05000896964065685},
#  {'tell want good': 0.05000000000012814,
#   'know dont like': 0.05000000000010083,
#   'make fuck money': 0.050000000000125826,
#   'say talk mean': 0.05000000000016499,
#   'ill hell mr': 0.05000000000014385,
#   'im think oh': 0.05000000000015033,
#   'youre right thats': 0.5499999999987552,
#   'hes man let': 0.050000000000117166,
#   'whats need thank': 0.050000000000147864,
#   'yes kill sure': 0.050000000000165794},
#  {'tell want good': 0.05000000000016822,
#   'know dont like': 0.05000000000013236,
#   'make fuck money': 0.050000000000165176,
#   'say talk mean': 0.050000000000216614,
#   'ill hell mr': 0.05000547733545428,
#   'im think oh': 0.05000000000019725,
#   'youre right thats': 0.05000705258177285,
#   'hes man let': 0.5499874700814815,
#   'whats need thank': 0.05000000000019409,
#   'yes kill sure': 0.05000000000021766},
#  {'tell want good': 0.05000000000390555,
#   'know dont like': 0.5499945464616766,
#   'make fuck money': 0.050000000003835206,
#   'say talk mean': 0.05000000000502818,
#   'ill hell mr': 0.05000000000438359,
#   'im think oh': 0.050000000004582344,
#   'youre right thats': 0.05000545350345803,
#   'hes man let': 0.05000000000357075,
#   'whats need thank': 0.050000000004506794,
#   'yes kill sure': 0.05000000000505302},
#  {'tell want good': 0.13749867304924718,
#   'know dont like': 0.012500201617907897,
#   'make fuck money': 0.012501269324951,
#   'say talk mean': 0.012500000000465167,
#   'ill hell mr': 0.012500000000405402,
#   'im think oh': 0.012500000000423634,
#   'youre right thats': 0.6374998538306336,
#   'hes man let': 0.012500000000330358,
#   'whats need thank': 0.1375000021751683,
#   'yes kill sure': 0.012500000000467571},
#  {'tell want good': 0.1574563044490433,
#   'know dont like': 0.617532440780225,
#   'make fuck money': 0.01250000004807865,
#   'say talk mean': 0.012500000063139529,
#   'ill hell mr': 0.012505815289102334,
#   'im think oh': 0.1375012611908741,
#   'youre right thats': 0.012502180077501958,
#   'hes man let': 0.01250199798166383,
#   'whats need thank': 0.012500000056617855,
#   'yes kill sure': 0.01250000006375338},
#  {'tell want good': 0.020000000079930472,
#   'know dont like': 0.4460828148439242,
#   'make fuck money': 0.020000754547037643,
#   'say talk mean': 0.020000000102905598,
#   'ill hell mr': 0.020000000089707738,
#   'im think oh': 0.020000000093883214,
#   'youre right thats': 0.020000000093044874,
#   'hes man let': 0.3939141650291888,
#   'whats need thank': 0.02000000009222997,
#   'yes kill sure': 0.020002265028147507},
#  {'tell want good': 0.6999658151759245,
#   'know dont like': 0.0333461481507467,
#   'make fuck money': 0.03334111397227833,
#   'say talk mean': 0.03333845303945719,
#   'ill hell mr': 0.03333333333455857,
#   'im think oh': 0.033333333334613656,
#   'youre right thats': 0.03333677263309506,
#   'hes man let': 0.033338363689988215,
#   'whats need thank': 0.03333333333459286,
#   'yes kill sure': 0.03333333333474494},
#  {'tell want good': 0.05000000000060326,
#   'know dont like': 0.05000619864573926,
#   'make fuck money': 0.5499868111879695,
#   'say talk mean': 0.050000000000776396,
#   'ill hell mr': 0.05000000000067691,
#   'im think oh': 0.05000699016150514,
#   'youre right thats': 0.05000000000070233,
#   'hes man let': 0.05000000000055154,
#   'whats need thank': 0.05000000000069555,
#   'yes kill sure': 0.05000000000078016},
#  {'tell want good': 0.4429398253780299,
#   'know dont like': 0.01667345895599714,
#   'make fuck money': 0.016668873532768896,
#   'say talk mean': 0.4237137844927887,
#   'ill hell mr': 0.01666666666844174,
#   'im think oh': 0.0166672651517992,
#   'youre right thats': 0.01666841240274781,
#   'hes man let': 0.016668380080220924,
#   'whats need thank': 0.016666666668492397,
#   'yes kill sure': 0.01666666666871325},
#  {'tell want good': 0.014286509979848771,
#   'know dont like': 0.2162546067953394,
#   'make fuck money': 0.014290324292634961,
#   'say talk mean': 0.014287628049406588,
#   'ill hell mr': 0.014286069389077805,
#   'im think oh': 0.24088685928134065,
#   'youre right thats': 0.014285714309720688,
#   'hes man let': 0.4428508592806636,
#   'whats need thank': 0.014285714309529081,
#   'yes kill sure': 0.014285714312438514},
#  {'tell want good': 0.6999453612833523,
#   'know dont like': 0.03334698584404144,
#   'make fuck money': 0.03335881715491467,
#   'say talk mean': 0.03333614084546963,
#   'ill hell mr': 0.03333333334126493,
#   'im think oh': 0.03334338477742777,
#   'youre right thats': 0.03333597672976417,
#   'hes man let': 0.03333333333979934,
#   'whats need thank': 0.033333333341485936,
#   'yes kill sure': 0.03333333334247985},
#  {'tell want good': 0.2660722014591692,
#   'know dont like': 0.01666666669725751,
#   'make fuck money': 0.016667130114251593,
#   'say talk mean': 0.26725467603480835,
#   'ill hell mr': 0.016666666710313843,
#   'im think oh': 0.18333432382021003,
#   'youre right thats': 0.01667069059990268,
#   'hes man let': 0.016666666702209513,
#   'whats need thank': 0.18333431114483972,
#   'yes kill sure': 0.016666666717037617},
#  {'tell want good': 0.05000594357695043,
#   'know dont like': 0.05001185425442997,
#   'make fuck money': 0.5499744182633515,
#   'say talk mean': 0.050000000008608346,
#   'ill hell mr': 0.05000000000749917,
#   'im think oh': 0.05000778385890446,
#   'youre right thats': 0.05000000000778655,
#   'hes man let': 0.05000000000611318,
#   'whats need thank': 0.05000000000770811,
#   'yes kill sure': 0.05000000000864823},
#  {'tell want good': 0.010000267535005327,
#   'know dont like': 0.1481208383720169,
#   'make fuck money': 0.01000737097808469,
#   'say talk mean': 0.21000464577675926,
#   'ill hell mr': 0.010000255654065216,
#   'im think oh': 0.010000270822247598,
#   'youre right thats': 0.34671611752964343,
#   'hes man let': 0.23514911956781823,
#   'whats need thank': 0.010000000096616229,
#   'yes kill sure': 0.010001113667743112},
#  {'tell want good': 0.1,
#   'know dont like': 0.1,
#   'make fuck money': 0.1,
#   'say talk mean': 0.1,
#   'ill hell mr': 0.1,
#   'im think oh': 0.1,
#   'youre right thats': 0.1,
#   'hes man let': 0.1,
#   'whats need thank': 0.1,
#   'yes kill sure': 0.1},
#  {'tell want good': 0.05000000001480944,
#   'know dont like': 0.05000000001164233,
#   'make fuck money': 0.5499999998534552,
#   'say talk mean': 0.050000000019078006,
#   'ill hell mr': 0.050000000016615094,
#   'im think oh': 0.05000000001737623,
#   'youre right thats': 0.05000000001724003,
#   'hes man let': 0.050000000013533864,
#   'whats need thank': 0.050000000017086196,
#   'yes kill sure': 0.05000000001916349},
#  {'tell want good': 0.033337187234481334,
#   'know dont like': 0.033333333333391425,
#   'make fuck money': 0.03333333333340583,
#   'say talk mean': 0.3666666672519214,
#   'ill hell mr': 0.03333333333341617,
#   'im think oh': 0.0333333333334199,
#   'youre right thats': 0.36666281217971586,
#   'hes man let': 0.03333333333340082,
#   'whats need thank': 0.0333333333334185,
#   'yes kill sure': 0.03333333333342884},
#  {'tell want good': 0.5499916599026309,
#   'know dont like': 0.05000834009673032,
#   'make fuck money': 0.05000000000006902,
#   'say talk mean': 0.050000000000090486,
#   'ill hell mr': 0.05000000000007887,
#   'im think oh': 0.050000000000082395,
#   'youre right thats': 0.050000000000081785,
#   'hes man let': 0.05000000000006425,
#   'whats need thank': 0.05000000000008107,
#   'yes kill sure': 0.050000000000090916},
#  {'tell want good': 0.02500321080038765,
#   'know dont like': 0.20951371093126422,
#   'make fuck money': 0.025004117615410326,
#   'say talk mean': 0.025000000013160693,
#   'ill hell mr': 0.2685559649542488,
#   'im think oh': 0.025003250133459973,
#   'youre right thats': 0.025004395936555766,
#   'hes man let': 0.025004805502151933,
#   'whats need thank': 0.3469105441001344,
#   'yes kill sure': 0.02500000001322628},
#  {'tell want good': 0.05000000002472018,
#   'know dont like': 0.05000000001945093,
#   'make fuck money': 0.5499938179398742,
#   'say talk mean': 0.050000000031830284,
#   'ill hell mr': 0.050000000027753205,
#   'im think oh': 0.050006181844420176,
#   'youre right thats': 0.05000000002880339,
#   'hes man let': 0.050000000022636736,
#   'whats need thank': 0.05000000002852744,
#   'yes kill sure': 0.05000000003198356},
#  {'tell want good': 0.03333333333450817,
#   'know dont like': 0.03333333333425777,
#   'make fuck money': 0.0333333333344867,
#   'say talk mean': 0.36666666148425536,
#   'ill hell mr': 0.03334256940203341,
#   'im think oh': 0.03333673162453582,
#   'youre right thats': 0.033333333334700975,
#   'hes man let': 0.03333333333440716,
#   'whats need thank': 0.0333333333346881,
#   'yes kill sure': 0.3666540374821266},
#  {'tell want good': 0.0333333333967287,
#   'know dont like': 0.6999914456410115,
#   'make fuck money': 0.033333333394816415,
#   'say talk mean': 0.03333333341392844,
#   'ill hell mr': 0.033333333403568866,
#   'im think oh': 0.03333333340680582,
#   'youre right thats': 0.033335327384129934,
#   'hes man let': 0.03333762147787862,
#   'whats need thank': 0.033333333405739615,
#   'yes kill sure': 0.03333560507539203},
#  {'tell want good': 0.020001199368012083,
#   'know dont like': 0.02000346810769968,
#   'make fuck money': 0.38740648962854196,
#   'say talk mean': 0.020000000056318672,
#   'ill hell mr': 0.020000000049104183,
#   'im think oh': 0.020000000051329122,
#   'youre right thats': 0.02000000005095226,
#   'hes man let': 0.020000000040047438,
#   'whats need thank': 0.24166725007993298,
#   'yes kill sure': 0.23092159256806177},
#  {'tell want good': 0.05000000000060188,
#   'know dont like': 0.0500000000004735,
#   'make fuck money': 0.050000000000590905,
#   'say talk mean': 0.05000000000077508,
#   'ill hell mr': 0.05000000000067564,
#   'im think oh': 0.05000000000070633,
#   'youre right thats': 0.549999999994153,
#   'hes man let': 0.05000000000055017,
#   'whats need thank': 0.05000000000069452,
#   'yes kill sure': 0.0500000000007788},
#  {'tell want good': 0.014294225850944177,
#   'know dont like': 0.5856996296262854,
#   'make fuck money': 0.014285714285964271,
#   'say talk mean': 0.014287764538360902,
#   'ill hell mr': 0.014288258556437356,
#   'im think oh': 0.01428789508371199,
#   'youre right thats': 0.014286102067551518,
#   'hes man let': 0.014286138137384961,
#   'whats need thank': 0.014286419185282147,
#   'yes kill sure': 0.2999978526680772},
#  {'tell want good': 0.3665572513478331,
#   'know dont like': 0.27358933051497714,
#   'make fuck money': 0.010004433952533183,
#   'say talk mean': 0.2898333490452896,
#   'ill hell mr': 0.010004966607891977,
#   'im think oh': 0.01000075660851124,
#   'youre right thats': 0.010003626660738327,
#   'hes man let': 0.010005369377597795,
#   'whats need thank': 0.010000915877735567,
#   'yes kill sure': 0.010000000006891907},
#  {'tell want good': 0.007694032267666631,
#   'know dont like': 0.00769281493631283,
#   'make fuck money': 0.007692987625484807,
#   'say talk mean': 0.007692710923919787,
#   'ill hell mr': 0.007692737299981628,
#   'im think oh': 0.41088300844637793,
#   'youre right thats': 0.007692609209912011,
#   'hes man let': 0.20700046211485934,
#   'whats need thank': 0.11607170868551306,
#   'yes kill sure': 0.21988692848997193},
#  {'tell want good': 0.2999877464594467,
#   'know dont like': 0.4296759704694502,
#   'make fuck money': 0.014290394706831471,
#   'say talk mean': 0.014286188668396945,
#   'ill hell mr': 0.014285714286423428,
#   'im think oh': 0.014287440206884574,
#   'youre right thats': 0.01429780698746392,
#   'hes man let': 0.014292911528363757,
#   'whats need thank': 0.17030956040988646,
#   'yes kill sure': 0.014286266276852522},
#  {'tell want good': 0.050000000000195444,
#   'know dont like': 0.05000000000015378,
#   'make fuck money': 0.050000000000191856,
#   'say talk mean': 0.05000000000025164,
#   'ill hell mr': 0.05000000000021934,
#   'im think oh': 0.5499999999981035,
#   'youre right thats': 0.050000000000227494,
#   'hes man let': 0.05000000000017866,
#   'whats need thank': 0.050000000000225475,
#   'yes kill sure': 0.0500000000002528},
#  {'tell want good': 0.012500612349206035,
#   'know dont like': 0.012501937083442933,
#   'make fuck money': 0.012501374812184801,
#   'say talk mean': 0.165083714140765,
#   'ill hell mr': 0.012500000000734084,
#   'im think oh': 0.012502892737726706,
#   'youre right thats': 0.7349087288726253,
#   'hes man let': 0.012500000000598222,
#   'whats need thank': 0.012500740001870597,
#   'yes kill sure': 0.012500000000846338},
#  {'tell want good': 0.020000000004508373,
#   'know dont like': 0.21999476533320553,
#   'make fuck money': 0.020002192140623095,
#   'say talk mean': 0.020000000005804756,
#   'ill hell mr': 0.02000000000506107,
#   'im think oh': 0.22000011529336425,
#   'youre right thats': 0.22000006982801923,
#   'hes man let': 0.2199997559201772,
#   'whats need thank': 0.02000310146340619,
#   'yes kill sure': 0.020000000005830285},
#  {'tell want good': 0.05000000000018695,
#   'know dont like': 0.05000000000014713,
#   'make fuck money': 0.05000000000018357,
#   'say talk mean': 0.050000000000240685,
#   'ill hell mr': 0.050000000000209814,
#   'im think oh': 0.050011439403919125,
#   'youre right thats': 0.05000000000021768,
#   'hes man let': 0.0500000000001709,
#   'whats need thank': 0.05000000000021566,
#   'yes kill sure': 0.5499885605945085},
#  {'tell want good': 0.011113241786807893,
#   'know dont like': 0.011113034161465453,
#   'make fuck money': 0.011115688494853658,
#   'say talk mean': 0.011113609177434675,
#   'ill hell mr': 0.011111111208202738,
#   'im think oh': 0.6777668826272572,
#   'youre right thats': 0.011111111211802659,
#   'hes man let': 0.23332431965873549,
#   'whats need thank': 0.011111111210916217,
#   'yes kill sure': 0.011119890462524212},
#  {'tell want good': 0.02500102278819482,
#   'know dont like': 0.4830080593976888,
#   'make fuck money': 0.025000000000707418,
#   'say talk mean': 0.025000000000927575,
#   'ill hell mr': 0.02500097730768554,
#   'im think oh': 0.02500103530589969,
#   'youre right thats': 0.02500139984939041,
#   'hes man let': 0.3169875053477427,
#   'whats need thank': 0.025000000000831298,
#   'yes kill sure': 0.025000000000931798},
#  {'tell want good': 0.03333333333400346,
#   'know dont like': 0.03333333333386113,
#   'make fuck money': 0.03333333333399145,
#   'say talk mean': 0.033333333334196316,
#   'ill hell mr': 0.03333555906394807,
#   'im think oh': 0.033333333334119544,
#   'youre right thats': 0.6999970117360582,
#   'hes man let': 0.0333340958615151,
#   'whats need thank': 0.03333333333410633,
#   'yes kill sure': 0.033333333334200466},
#  {'tell want good': 0.033333333342497266,
#   'know dont like': 0.033339418040854614,
#   'make fuck money': 0.03334248161509407,
#   'say talk mean': 0.033345073887036634,
#   'ill hell mr': 0.033334704478796905,
#   'im think oh': 0.03333333334407997,
#   'youre right thats': 0.033333333343990613,
#   'hes man let': 0.36664586789667347,
#   'whats need thank': 0.03334078206258119,
#   'yes kill sure': 0.36665167198839527},
#  {'tell want good': 0.1372632595699385,
#   'know dont like': 0.16874378331017909,
#   'make fuck money': 0.011114980016088013,
#   'say talk mean': 0.3894593592984005,
#   'ill hell mr': 0.011111937285236602,
#   'im think oh': 0.011113187060421663,
#   'youre right thats': 0.011113670785769676,
#   'hes man let': 0.011115142868312864,
#   'whats need thank': 0.12674177450435872,
#   'yes kill sure': 0.12222290530129427},
#  {'tell want good': 0.05000000000042322,
#   'know dont like': 0.05000697853792423,
#   'make fuck money': 0.0500000000004156,
#   'say talk mean': 0.05000000000054473,
#   'ill hell mr': 0.05000000000047486,
#   'im think oh': 0.05000000000049622,
#   'youre right thats': 0.05000000000049252,
#   'hes man let': 0.05000000000038687,
#   'whats need thank': 0.050000000000488216,
#   'yes kill sure': 0.5499930214583535},
#  {'tell want good': 0.1998780052618582,
#   'know dont like': 0.016669701348997167,
#   'make fuck money': 0.27879692812615564,
#   'say talk mean': 0.016669585939975713,
#   'ill hell mr': 0.4046356745133381,
#   'im think oh': 0.016670370156624915,
#   'youre right thats': 0.016675018023783957,
#   'hes man let': 0.01666731185072105,
#   'whats need thank': 0.016669120645704454,
#   'yes kill sure': 0.016668284132840733},
#  {'tell want good': 0.033333333333551304,
#   'know dont like': 0.0333435691176331,
#   'make fuck money': 0.03333647330373848,
#   'say talk mean': 0.6999561161741522,
#   'ill hell mr': 0.033336215085838596,
#   'im think oh': 0.03335297155783362,
#   'youre right thats': 0.033333333333587005,
#   'hes man let': 0.0333354020761243,
#   'whats need thank': 0.03333675918425065,
#   'yes kill sure': 0.03333582683329077},
#  {'tell want good': 0.033333333336947955,
#   'know dont like': 0.033336922516213646,
#   'make fuck money': 0.03333419481649819,
#   'say talk mean': 0.033333333337985945,
#   'ill hell mr': 0.36665905768383866,
#   'im think oh': 0.03333742285115091,
#   'youre right thats': 0.033333333337539385,
#   'hes man let': 0.36665605796733813,
#   'whats need thank': 0.03333857292402685,
#   'yes kill sure': 0.033337771228460114},
#  {'tell want good': 0.18444414436631315,
#   'know dont like': 0.46562683914902747,
#   'make fuck money': 0.2571747846027371,
#   'say talk mean': 0.06274984430566666,
#   'ill hell mr': 0.005000709076949982,
#   'im think oh': 0.005000240697638582,
#   'youre right thats': 0.005000322471882247,
#   'hes man let': 0.005001929997282113,
#   'whats need thank': 0.005001185330987,
#   'yes kill sure': 0.005000000001515671},
#  {'tell want good': 0.025000000321997597,
#   'know dont like': 0.025000000253378275,
#   'make fuck money': 0.02500265045426084,
#   'say talk mean': 0.02500000041456201,
#   'ill hell mr': 0.025000000361389364,
#   'im think oh': 0.025000000377645548,
#   'youre right thats': 0.02500000037483484,
#   'hes man let': 0.27500379304573314,
#   'whats need thank': 0.02500000037154906,
#   'yes kill sure': 0.5249935540246493},
#  {'tell want good': 0.03333718723460018,
#   'know dont like': 0.03333333333354471,
#   'make fuck money': 0.03333333333359705,
#   'say talk mean': 0.03333333333367912,
#   'ill hell mr': 0.3666666621021645,
#   'im think oh': 0.03333333333364835,
#   'youre right thats': 0.36666281732786343,
#   'hes man let': 0.03333333333357888,
#   'whats need thank': 0.03333333333364315,
#   'yes kill sure': 0.033333333333680736},
#  {'tell want good': 0.020005739123366385,
#   'know dont like': 0.020000000022689195,
#   'make fuck money': 0.020000727952117242,
#   'say talk mean': 0.2199945357194573,
#   'ill hell mr': 0.020002545442218744,
#   'im think oh': 0.02000282745247297,
#   'youre right thats': 0.6199905214753525,
#   'hes man let': 0.020001253295260216,
#   'whats need thank': 0.02000184947977378,
#   'yes kill sure': 0.020000000037291583},
#  {'tell want good': 0.27499754019400957,
#   'know dont like': 0.02500000001478919,
#   'make fuck money': 0.025000000018429443,
#   'say talk mean': 0.025000000024181106,
#   'ill hell mr': 0.025007717648046237,
#   'im think oh': 0.2750002052229732,
#   'youre right thats': 0.025000000021858697,
#   'hes man let': 0.02500270924596541,
#   'whats need thank': 0.2749918275854658,
#   'yes kill sure': 0.025000000024281367},
#  {'tell want good': 0.05000000000016822,
#   'know dont like': 0.05000000000013236,
#   'make fuck money': 0.050000000000165176,
#   'say talk mean': 0.050000000000216614,
#   'ill hell mr': 0.05000547733545428,
#   'im think oh': 0.05000000000019725,
#   'youre right thats': 0.05000705258177285,
#   'hes man let': 0.5499874700814815,
#   'whats need thank': 0.05000000000019409,
#   'yes kill sure': 0.05000000000021766},
#  {'tell want good': 0.009091185079452684,
#   'know dont like': 0.49255262295160007,
#   'make fuck money': 0.009092373539579538,
#   'say talk mean': 0.2671607541199714,
#   'ill hell mr': 0.009094048156222,
#   'im think oh': 0.17663670532912767,
#   'youre right thats': 0.009092364931579356,
#   'hes man let': 0.009092167217269746,
#   'whats need thank': 0.009094328684266123,
#   'yes kill sure': 0.009093449990931502},
#  {'tell want good': 0.03334066956370713,
#   'know dont like': 0.033333333336855606,
#   'make fuck money': 0.03333333333773022,
#   'say talk mean': 0.03333333333909345,
#   'ill hell mr': 0.36666307017273464,
#   'im think oh': 0.03333333333858247,
#   'youre right thats': 0.36666292689624896,
#   'hes man let': 0.0333333333374258,
#   'whats need thank': 0.03333333333849763,
#   'yes kill sure': 0.03333333333912423},
#  {'tell want good': 0.009091722415185414,
#   'know dont like': 0.009092536894980486,
#   'make fuck money': 0.009092967341509849,
#   'say talk mean': 0.2151239655690478,
#   'ill hell mr': 0.009091680948889146,
#   'im think oh': 0.39222111629153106,
#   'youre right thats': 0.009092860522276851,
#   'hes man let': 0.009093475746998782,
#   'whats need thank': 0.1078753030729217,
#   'yes kill sure': 0.230224371196659},
#  {'tell want good': 0.619966974524199,
#   'know dont like': 0.02000203122078198,
#   'make fuck money': 0.02000000002259524,
#   'say talk mean': 0.02000961997890566,
#   'ill hell mr': 0.020003602145414596,
#   'im think oh': 0.020000000026987225,
#   'youre right thats': 0.020000000026775783,
#   'hes man let': 0.020000000021026334,
#   'whats need thank': 0.02001904599066875,
#   'yes kill sure': 0.21999872604264548},
#  {'tell want good': 0.025000000001262377,
#   'know dont like': 0.3108944774102882,
#   'make fuck money': 0.02500000000123972,
#   'say talk mean': 0.025001369842810955,
#   'ill hell mr': 0.02500138917375708,
#   'im think oh': 0.025001614947484145,
#   'youre right thats': 0.48908728249073513,
#   'hes man let': 0.02501386612933343,
#   'whats need thank': 0.02500000000145628,
#   'yes kill sure': 0.025000000001632668},
#  {'tell want good': 0.05000000002225726,
#   'know dont like': 0.05000000001752971,
#   'make fuck money': 0.050000000021869884,
#   'say talk mean': 0.5499999997864403,
#   'ill hell mr': 0.05000000002498291,
#   'im think oh': 0.05000000002611981,
#   'youre right thats': 0.05000000002591565,
#   'hes man let': 0.05000000002035734,
#   'whats need thank': 0.050000000025700146,
#   'yes kill sure': 0.050000000028826985},
#  {'tell want good': 0.016667439696902726,
#   'know dont like': 0.34999828815098916,
#   'make fuck money': 0.01666666666758119,
#   'say talk mean': 0.016666666667865027,
#   'ill hell mr': 0.016666666667712073,
#   'im think oh': 0.01666754608981303,
#   'youre right thats': 0.3499992841611023,
#   'hes man let': 0.01666742359007376,
#   'whats need thank': 0.1833333516400896,
#   'yes kill sure': 0.016666666667871127},
#  {'tell want good': 0.05000000000065069,
#   'know dont like': 0.05000538377235218,
#   'make fuck money': 0.05000000000063903,
#   'say talk mean': 0.05000000000083767,
#   'ill hell mr': 0.5499884819495233,
#   'im think oh': 0.05000613427305259,
#   'youre right thats': 0.050000000000757376,
#   'hes man let': 0.05000000000059488,
#   'whats need thank': 0.05000000000075069,
#   'yes kill sure': 0.050000000000841725},
#  {'tell want good': 0.025000000012719494,
#   'know dont like': 0.0250000000100117,
#   'make fuck money': 0.02500046904731425,
#   'say talk mean': 0.02500000001637219,
#   'ill hell mr': 0.7749792671956913,
#   'im think oh': 0.02500000001491455,
#   'youre right thats': 0.025000000014811542,
#   'hes man let': 0.025019826901049827,
#   'whats need thank': 0.0250004367706614,
#   'yes kill sure': 0.0250000000164537},
#  {'tell want good': 0.00833353443636097,
#   'know dont like': 0.008333596180561328,
#   'make fuck money': 0.2699919779521736,
#   'say talk mean': 0.00833446898926799,
#   'ill hell mr': 0.008335051202004912,
#   'im think oh': 0.008333399274293139,
#   'youre right thats': 0.008336213791733011,
#   'hes man let': 0.008338655715499797,
#   'whats need thank': 0.008333826201242801,
#   'yes kill sure': 0.6633292762568623},
#  {'tell want good': 0.012501581138395682,
#   'know dont like': 0.012500000019426685,
#   'make fuck money': 0.14720803864201115,
#   'say talk mean': 0.01250083409698985,
#   'ill hell mr': 0.2198909136455154,
#   'im think oh': 0.012501858081094547,
#   'youre right thats': 0.13750062369508498,
#   'hes man let': 0.42039220456964754,
#   'whats need thank': 0.01250294587614152,
#   'yes kill sure': 0.012501000235692604},
#  {'tell want good': 0.014287541594941463,
#   'know dont like': 0.014288822371451732,
#   'make fuck money': 0.014286432092423489,
#   'say talk mean': 0.01429105426803496,
#   'ill hell mr': 0.014288234131813229,
#   'im think oh': 0.5315751376402797,
#   'youre right thats': 0.35412103818928525,
#   'hes man let': 0.014287104999882737,
#   'whats need thank': 0.014286643718430945,
#   'yes kill sure': 0.014287990993456534},
#  {'tell want good': 0.02500722198560134,
#   'know dont like': 0.7749815015917613,
#   'make fuck money': 0.025000000029598755,
#   'say talk mean': 0.025002179255330964,
#   'ill hell mr': 0.02500000003383204,
#   'im think oh': 0.025006790289661452,
#   'youre right thats': 0.025000000035124027,
#   'hes man let': 0.025002306705188302,
#   'whats need thank': 0.025000000034784167,
#   'yes kill sure': 0.025000000039117648},
#  {'tell want good': 0.03333333333424175,
#   'know dont like': 0.033333333334047796,
#   'make fuck money': 0.03333790373904823,
#   'say talk mean': 0.0333333333345028,
#   'ill hell mr': 0.3666666800241541,
#   'im think oh': 0.36665628705815606,
#   'youre right thats': 0.0333333333343909,
#   'hes man let': 0.03333542660932929,
#   'whats need thank': 0.03333703589762032,
#   'yes kill sure': 0.033333333334508816},
#  {'tell want good': 0.025000000002906572,
#   'know dont like': 0.2750000487998616,
#   'make fuck money': 0.025000000002856425,
#   'say talk mean': 0.02500739077417751,
#   'ill hell mr': 0.5249884548172346,
#   'im think oh': 0.02500000000341003,
#   'youre right thats': 0.025003064078398148,
#   'hes man let': 0.025000000002659943,
#   'whats need thank': 0.025000000003356317,
#   'yes kill sure': 0.025001041515138992},
#  {'tell want good': 0.011113957530406763,
#   'know dont like': 0.7888758782151468,
#   'make fuck money': 0.011113470939410739,
#   'say talk mean': 0.011115600652993298,
#   'ill hell mr': 0.011111111111789095,
#   'im think oh': 0.011111624179071997,
#   'youre right thats': 0.011113675470493608,
#   'hes man let': 0.011113137114356584,
#   'whats need thank': 0.12222043367443794,
#   'yes kill sure': 0.011111111111892964},
#  {'tell want good': 0.012500000001230586,
#   'know dont like': 0.5000810414477299,
#   'make fuck money': 0.012502596185973701,
#   'say talk mean': 0.173139295627004,
#   'ill hell mr': 0.012500000001381018,
#   'im think oh': 0.012500000001443103,
#   'youre right thats': 0.012500505160460373,
#   'hes man let': 0.012504294512973257,
#   'whats need thank': 0.012500000001420592,
#   'yes kill sure': 0.23927226706038346},
#  {'tell want good': 0.009090909171564767,
#   'know dont like': 0.47084101949448454,
#   'make fuck money': 0.009100732864922474,
#   'say talk mean': 0.4564143975005802,
#   'ill hell mr': 0.009091209007499232,
#   'im think oh': 0.009092289795771069,
#   'youre right thats': 0.009091837320963372,
#   'hes man let': 0.00909210429625127,
#   'whats need thank': 0.00909355733916035,
#   'yes kill sure': 0.009091943208802793},
#  {'tell want good': 0.012500131189303435,
#   'know dont like': 0.8874886340815753,
#   'make fuck money': 0.012500937671428776,
#   'say talk mean': 0.012501544979118916,
#   'ill hell mr': 0.012500175427783124,
#   'im think oh': 0.01250149512308407,
#   'youre right thats': 0.012500000005211273,
#   'hes man let': 0.012503997422268221,
#   'whats need thank': 0.012502335835134428,
#   'yes kill sure': 0.012500748265092301},
#  {'tell want good': 0.007694823077812399,
#   'know dont like': 0.31883024486811995,
#   'make fuck money': 0.007694191473297637,
#   'say talk mean': 0.24679752900452026,
#   'ill hell mr': 0.007694942944359927,
#   'im think oh': 0.007694439312964333,
#   'youre right thats': 0.00769545132234187,
#   'hes man let': 0.08796659626769547,
#   'whats need thank': 0.3002394739349964,
#   'yes kill sure': 0.0076923077938918834},
#  {'tell want good': 0.03333333338971012,
#   'know dont like': 0.03333333337770665,
#   'make fuck money': 0.03333333338870359,
#   'say talk mean': 0.033333333405928936,
#   'ill hell mr': 0.033333333396630235,
#   'im think oh': 0.03333333339945693,
#   'youre right thats': 0.03333333339896375,
#   'hes man let': 0.6999999994380018,
#   'whats need thank': 0.03333333339842286,
#   'yes kill sure': 0.033333333406475034},
#  {'tell want good': 0.025000000011601776,
#   'know dont like': 0.025003489272609838,
#   'make fuck money': 0.02500000001139959,
#   'say talk mean': 0.27499947305732203,
#   'ill hell mr': 0.02500000001302171,
#   'im think oh': 0.025000000013613626,
#   'youre right thats': 0.025000000013507537,
#   'hes man let': 0.2750002130985598,
#   'whats need thank': 0.025000000013394908,
#   'yes kill sure': 0.2749968244949693},
#  {'tell want good': 0.05000708248951745,
#   'know dont like': 0.05000000000044473,
#   'make fuck money': 0.0500048889647662,
#   'say talk mean': 0.05000000000072779,
#   'ill hell mr': 0.0500000000006345,
#   'im think oh': 0.05000653965820491,
#   'youre right thats': 0.5499756440256864,
#   'hes man let': 0.050000000000516895,
#   'whats need thank': 0.05000584485876956,
#   'yes kill sure': 0.050000000000731536},
#  {'tell want good': 0.050000000004469775,
#   'know dont like': 0.05000000000351738,
#   'make fuck money': 0.050000000004389256,
#   'say talk mean': 0.5499999999571306,
#   'ill hell mr': 0.050000000005015935,
#   'im think oh': 0.05000000000524223,
#   'youre right thats': 0.050000000005207226,
#   'hes man let': 0.050000000004087136,
#   'whats need thank': 0.05000000000516069,
#   'yes kill sure': 0.050000000005779845},
#  {'tell want good': 0.1,
#   'know dont like': 0.1,
#   'make fuck money': 0.1,
#   'say talk mean': 0.1,
#   'ill hell mr': 0.1,
#   'im think oh': 0.1,
#   'youre right thats': 0.1,
#   'hes man let': 0.1,
#   'whats need thank': 0.1,
#   'yes kill sure': 0.1},
#  {'tell want good': 0.02500000000018076,
#   'know dont like': 0.025005416505854954,
#   'make fuck money': 0.02500000000017752,
#   'say talk mean': 0.025003711928778354,
#   'ill hell mr': 0.025000000000202856,
#   'im think oh': 0.2749908729690015,
#   'youre right thats': 0.5249999985951964,
#   'hes man let': 0.025000000000165286,
#   'whats need thank': 0.02500000000020854,
#   'yes kill sure': 0.025000000000233842},
#  {'tell want good': 0.36665555304989494,
#   'know dont like': 0.033335603857184246,
#   'make fuck money': 0.03333588904342816,
#   'say talk mean': 0.033333333335524754,
#   'ill hell mr': 0.03333344743121925,
#   'im think oh': 0.03333333333532938,
#   'youre right thats': 0.033333333335314824,
#   'hes man let': 0.3666666540303746,
#   'whats need thank': 0.033333333335297574,
#   'yes kill sure': 0.033339519246432164},
#  {'tell want good': 0.020000000008692564,
#   'know dont like': 0.37165539667456965,
#   'make fuck money': 0.23962180439655048,
#   'say talk mean': 0.02000000001118915,
#   'ill hell mr': 0.020003490942418687,
#   'im think oh': 0.020000000010187684,
#   'youre right thats': 0.020000000010115728,
#   'hes man let': 0.02000000000794512,
#   'whats need thank': 0.24871930792709587,
#   'yes kill sure': 0.02000000001123508},
#  {'tell want good': 0.594844098613823,
#   'know dont like': 0.020002508089992134,
#   'make fuck money': 0.020000000001529274,
#   'say talk mean': 0.24515179056542458,
#   'ill hell mr': 0.020000000001748407,
#   'im think oh': 0.020000697407660167,
#   'youre right thats': 0.02000090531458779,
#   'hes man let': 0.020000000001424535,
#   'whats need thank': 0.020000000001795904,
#   'yes kill sure': 0.02000000000201401},
#  {'tell want good': 0.033333333336715426,
#   'know dont like': 0.03333333333599489,
#   'make fuck money': 0.033333333336654426,
#   'say talk mean': 0.36666660172390053,
#   'ill hell mr': 0.03333333333712871,
#   'im think oh': 0.03333333333730003,
#   'youre right thats': 0.3666667315809356,
#   'hes man let': 0.03333333333642585,
#   'whats need thank': 0.033333333337237786,
#   'yes kill sure': 0.03333333333770676},
#  {'tell want good': 0.012504477669667394,
#   'know dont like': 0.21753255240502836,
#   'make fuck money': 0.012501423318779516,
#   'say talk mean': 0.012505978791871626,
#   'ill hell mr': 0.012500000009296984,
#   'im think oh': 0.26895838259927807,
#   'youre right thats': 0.1375002090836106,
#   'hes man let': 0.012502163081816273,
#   'whats need thank': 0.30099423328661773,
#   'yes kill sure': 0.012500579754033419},
#  {'tell want good': 0.02500000000855132,
#   'know dont like': 0.025000000006729042,
#   'make fuck money': 0.02501087257362309,
#   'say talk mean': 0.025000000011010864,
#   'ill hell mr': 0.025001631082427627,
#   'im think oh': 0.025000000010025312,
#   'youre right thats': 0.5117150542744988,
#   'hes man let': 0.28827244201220936,
#   'whats need thank': 0.025000000009863587,
#   'yes kill sure': 0.02500000001106105},
#  {'tell want good': 0.05000000001237044,
#   'know dont like': 0.05000000000974381,
#   'make fuck money': 0.05000000001215857,
#   'say talk mean': 0.5499949952862586,
#   'ill hell mr': 0.05000500460892511,
#   'im think oh': 0.050000000014523906,
#   'youre right thats': 0.0500000000144071,
#   'hes man let': 0.050000000011319934,
#   'whats need thank': 0.050000000014280906,
#   'yes kill sure': 0.050000000016011535},
#  {'tell want good': 0.31216971296272833,
#   'know dont like': 0.011111538680937273,
#   'make fuck money': 0.011112835861422721,
#   'say talk mean': 0.23333046711015715,
#   'ill hell mr': 0.01111232716623628,
#   'im think oh': 0.011112165884612852,
#   'youre right thats': 0.011111315199356592,
#   'hes man let': 0.26559974127340763,
#   'whats need thank': 0.12222260287237702,
#   'yes kill sure': 0.011117292988764084},
#  {'tell want good': 0.033333333336788847,
#   'know dont like': 0.36666667534980485,
#   'make fuck money': 0.03333333333672721,
#   'say talk mean': 0.03333333333778174,
#   'ill hell mr': 0.36666665795253844,
#   'im think oh': 0.03333333333738603,
#   'youre right thats': 0.03333333333735529,
#   'hes man let': 0.03333333333649315,
#   'whats need thank': 0.03333333333732033,
#   'yes kill sure': 0.03333333333780418},
#  {'tell want good': 0.011111726066686728,
#   'know dont like': 0.3083805699473458,
#   'make fuck money': 0.011113728846541765,
#   'say talk mean': 0.01111254586668517,
#   'ill hell mr': 0.12222233327557203,
#   'im think oh': 0.011111111116577898,
#   'youre right thats': 0.01111138034927397,
#   'hes man let': 0.3568731295812115,
#   'whats need thank': 0.011111579996330188,
#   'yes kill sure': 0.14585189495377499},
#  {'tell want good': 0.16095752394969842,
#   'know dont like': 0.06937617131468149,
#   'make fuck money': 0.005557136884726382,
#   'say talk mean': 0.0055557767442204085,
#   'ill hell mr': 0.0976954143640629,
#   'im think oh': 0.26364495661428244,
#   'youre right thats': 0.380540547579868,
#   'hes man let': 0.00555902973422973,
#   'whats need thank': 0.005555889053855404,
#   'yes kill sure': 0.005557553760374851},
#  {'tell want good': 0.05000000002357532,
#   'know dont like': 0.050000000018538465,
#   'make fuck money': 0.050000000023155675,
#   'say talk mean': 0.050000000030334,
#   'ill hell mr': 0.5499999997700383,
#   'im think oh': 0.0500000000276351,
#   'youre right thats': 0.050000000027439775,
#   'hes man let': 0.05000000002152903,
#   'whats need thank': 0.050000000027239234,
#   'yes kill sure': 0.050000000030515},
#  {'tell want good': 0.016669544109273415,
#   'know dont like': 0.016672305592841746,
#   'make fuck money': 0.01666750474682504,
#   'say talk mean': 0.1930004982040415,
#   'ill hell mr': 0.18333782853968608,
#   'im think oh': 0.016667668597984436,
#   'youre right thats': 0.2680590538566257,
#   'hes man let': 0.016668176413656186,
#   'whats need thank': 0.016667791181203824,
#   'yes kill sure': 0.2555896287578621},
#  {'tell want good': 0.05000000000825184,
#   'know dont like': 0.050000000006492504,
#   'make fuck money': 0.5499999999183599,
#   'say talk mean': 0.0500000000106212,
#   'ill hell mr': 0.050000000009261414,
#   'im think oh': 0.050000000009674125,
#   'youre right thats': 0.05000000000960404,
#   'hes man let': 0.050000000007545155,
#   'whats need thank': 0.050000000009517875,
#   'yes kill sure': 0.05000000001067199},
#  {'tell want good': 0.050000000007371495,
#   'know dont like': 0.05000000000579862,
#   'make fuck money': 0.05000000000723577,
#   'say talk mean': 0.05000000000949486,
#   'ill hell mr': 0.050000000008271615,
#   'im think oh': 0.05000000000864312,
#   'youre right thats': 0.05000000000857862,
#   'hes man let': 0.05000000000673637,
#   'whats need thank': 0.5499999999283329,
#   'yes kill sure': 0.05000000000953657},
#  {'tell want good': 0.05000000009099936,
#   'know dont like': 0.050000000071676313,
#   'make fuck money': 0.050000000089436315,
#   'say talk mean': 0.05000000011718501,
#   'ill hell mr': 0.05000000010251387,
#   'im think oh': 0.05000332166062248,
#   'youre right thats': 0.05000000010615333,
#   'hes man let': 0.05000000008334919,
#   'whats need thank': 0.5499966775602617,
#   'yes kill sure': 0.050000000117802416},
#  {'tell want good': 0.2749922700012392,
#   'know dont like': 0.02500400369821704,
#   'make fuck money': 0.5249839988086746,
#   'say talk mean': 0.025002876047075295,
#   'ill hell mr': 0.025001571350434754,
#   'im think oh': 0.025003361089926842,
#   'youre right thats': 0.025000000250209313,
#   'hes man let': 0.02500503929821542,
#   'whats need thank': 0.025005299582571715,
#   'yes kill sure': 0.025001579873435688},
#  {'tell want good': 0.5499916599026309,
#   'know dont like': 0.05000834009673032,
#   'make fuck money': 0.05000000000006902,
#   'say talk mean': 0.050000000000090486,
#   'ill hell mr': 0.05000000000007887,
#   'im think oh': 0.050000000000082395,
#   'youre right thats': 0.050000000000081785,
#   'hes man let': 0.05000000000006425,
#   'whats need thank': 0.05000000000008107,
#   'yes kill sure': 0.050000000000090916},
#  {'tell want good': 0.5499916599026309,
#   'know dont like': 0.05000834009673032,
#   'make fuck money': 0.05000000000006902,
#   'say talk mean': 0.050000000000090486,
#   'ill hell mr': 0.05000000000007887,
#   'im think oh': 0.050000000000082395,
#   'youre right thats': 0.050000000000081785,
#   'hes man let': 0.05000000000006425,
#   'whats need thank': 0.05000000000008107,
#   'yes kill sure': 0.050000000000090916},
#  {'tell want good': 0.05000000000016822,
#   'know dont like': 0.05000000000013236,
#   'make fuck money': 0.050000000000165176,
#   'say talk mean': 0.050000000000216614,
#   'ill hell mr': 0.05000547733545428,
#   'im think oh': 0.05000000000019725,
#   'youre right thats': 0.05000705258177285,
#   'hes man let': 0.5499874700814815,
#   'whats need thank': 0.05000000000019409,
#   'yes kill sure': 0.05000000000021766},
#  {'tell want good': 0.01666736306888222,
#   'know dont like': 0.016669401667232072,
#   'make fuck money': 0.016670259763362522,
#   'say talk mean': 0.016667251079029034,
#   'ill hell mr': 0.35138640245073716,
#   'im think oh': 0.0166678965883838,
#   'youre right thats': 0.01666804501763541,
#   'hes man let': 0.2332842982826734,
#   'whats need thank': 0.2986498487671549,
#   'yes kill sure': 0.01666923331490961},
#  {'tell want good': 0.05000000000104052,
#   'know dont like': 0.05000000000081855,
#   'make fuck money': 0.5499935078266377,
#   'say talk mean': 0.05000000000133978,
#   'ill hell mr': 0.05000000000116815,
#   'im think oh': 0.0500000000012201,
#   'youre right thats': 0.0500000000012113,
#   'hes man let': 0.05000649216401618,
#   'whats need thank': 0.05000000000120101,
#   'yes kill sure': 0.05000000000134673},
#  {'tell want good': 0.2394624267737968,
#   'know dont like': 0.36943605849399647,
#   'make fuck money': 0.02000000000044368,
#   'say talk mean': 0.020000000000581775,
#   'ill hell mr': 0.020005787404766856,
#   'im think oh': 0.020000784807445274,
#   'youre right thats': 0.020001061138004535,
#   'hes man let': 0.25109388137985833,
#   'whats need thank': 0.020000000000521354,
#   'yes kill sure': 0.020000000000584797},
#  {'tell want good': 0.02500000000012898,
#   'know dont like': 0.29550099673453123,
#   'make fuck money': 0.025000000000126598,
#   'say talk mean': 0.02500000000016605,
#   'ill hell mr': 0.5044973527303216,
#   'im think oh': 0.025001650534141762,
#   'youre right thats': 0.025000000000150114,
#   'hes man let': 0.025000000000117897,
#   'whats need thank': 0.025000000000148764,
#   'yes kill sure': 0.02500000000016682},
#  {'tell want good': 0.012502594647942969,
#   'know dont like': 0.18232232926726272,
#   'make fuck money': 0.012503673049494556,
#   'say talk mean': 0.012501588294322382,
#   'ill hell mr': 0.012500628305544907,
#   'im think oh': 0.21472149101773344,
#   'youre right thats': 0.13750004645758762,
#   'hes man let': 0.20448407063034346,
#   'whats need thank': 0.1984607368386452,
#   'yes kill sure': 0.012502841491122728},
#  {'tell want good': 0.020000486764252395,
#   'know dont like': 0.020001605127658067,
#   'make fuck money': 0.21999999638287868,
#   'say talk mean': 0.020000770152569833,
#   'ill hell mr': 0.020000000003245758,
#   'im think oh': 0.41999681769353364,
#   'youre right thats': 0.020001237497513168,
#   'hes man let': 0.020000000002645194,
#   'whats need thank': 0.2199990863719596,
#   'yes kill sure': 0.020000000003743704},
#  {'tell want good': 0.4440810354998485,
#   'know dont like': 0.26757775268965367,
#   'make fuck money': 0.014288065616085676,
#   'say talk mean': 0.18832980352106388,
#   'ill hell mr': 0.014285714305309517,
#   'im think oh': 0.014285714306194925,
#   'youre right thats': 0.014285714306040953,
#   'hes man let': 0.014292039206914325,
#   'whats need thank': 0.014287450175921356,
#   'yes kill sure': 0.014286710372967222},
#  {'tell want good': 0.02500000000138708,
#   'know dont like': 0.02500423088162834,
#   'make fuck money': 0.025000000001362016,
#   'say talk mean': 0.025001472795002762,
#   'ill hell mr': 0.025012991143251066,
#   'im think oh': 0.5249813689725579,
#   'youre right thats': 0.025000000001614318,
#   'hes man let': 0.025000000001268015,
#   'whats need thank': 0.274996691445511,
#   'yes kill sure': 0.025003244756417548},
#  {'tell want good': 0.05000578085168579,
#   'know dont like': 0.050000000000054175,
#   'make fuck money': 0.05000000000006763,
#   'say talk mean': 0.050000000000088654,
#   'ill hell mr': 0.05000000000007726,
#   'im think oh': 0.05000000000008075,
#   'youre right thats': 0.5499942191477143,
#   'hes man let': 0.05000000000006294,
#   'whats need thank': 0.05000000000007944,
#   'yes kill sure': 0.05000000000008908},
#  {'tell want good': 0.007698861072750665,
#   'know dont like': 0.36965128993152185,
#   'make fuck money': 0.3380268263568805,
#   'say talk mean': 0.007696225441856018,
#   'ill hell mr': 0.16153014372898375,
#   'im think oh': 0.007694235038924008,
#   'youre right thats': 0.007695194988305249,
#   'hes man let': 0.0076994790897728866,
#   'whats need thank': 0.08461543665553074,
#   'yes kill sure': 0.0076923076954741685},
#  {'tell want good': 0.6999619060420772,
#   'know dont like': 0.03333879315098969,
#   'make fuck money': 0.033333333333514244,
#   'say talk mean': 0.033365967472162215,
#   'ill hell mr': 0.03333333333354007,
#   'im think oh': 0.03333333333354939,
#   'youre right thats': 0.03333333333354775,
#   'hes man let': 0.033333333333501816,
#   'whats need thank': 0.03333333333354585,
#   'yes kill sure': 0.033333333333571705},
#  {'tell want good': 0.41997840804461223,
#   'know dont like': 0.020007698418174683,
#   'make fuck money': 0.020016663773146745,
#   'say talk mean': 0.020000000000434084,
#   'ill hell mr': 0.020002185922596262,
#   'im think oh': 0.020000000000395424,
#   'youre right thats': 0.02000279019855104,
#   'hes man let': 0.21999502371437699,
#   'whats need thank': 0.020000000000389016,
#   'yes kill sure': 0.21999722992732343},
#  {'tell want good': 0.1376064206506921,
#   'know dont like': 0.45553472793225697,
#   'make fuck money': 0.01111299749918255,
#   'say talk mean': 0.011111603917681422,
#   'ill hell mr': 0.329066411066153,
#   'im think oh': 0.011112039379843695,
#   'youre right thats': 0.011111111209418668,
#   'hes man let': 0.011117629967032047,
#   'whats need thank': 0.011112781393596522,
#   'yes kill sure': 0.011114276984143107},
#  {'tell want good': 0.5510213824356115,
#   'know dont like': 0.011116532687308969,
#   'make fuck money': 0.011111512346744604,
#   'say talk mean': 0.011114233543738613,
#   'ill hell mr': 0.011111395762142998,
#   'im think oh': 0.12985355847789104,
#   'youre right thats': 0.011112475680306735,
#   'hes man let': 0.24133668684241433,
#   'whats need thank': 0.011111111111874336,
#   'yes kill sure': 0.011111111111966991},
#  {'tell want good': 0.050000000000041844,
#   'know dont like': 0.050000000000032935,
#   'make fuck money': 0.05000000000004109,
#   'say talk mean': 0.5499999999995987,
#   'ill hell mr': 0.050000000000046965,
#   'im think oh': 0.050000000000049075,
#   'youre right thats': 0.050000000000048714,
#   'hes man let': 0.05000000000003826,
#   'whats need thank': 0.05000000000004828,
#   'yes kill sure': 0.050000000000054154},
#  {'tell want good': 0.03333333333723522,
#   'know dont like': 0.03334254257062462,
#   'make fuck money': 0.03333333333716502,
#   'say talk mean': 0.36666661926531485,
#   'ill hell mr': 0.3666575048007556,
#   'im think oh': 0.03333333333790922,
#   'youre right thats': 0.033333333337877726,
#   'hes man let': 0.03333333333690136,
#   'whats need thank': 0.033333333337837195,
#   'yes kill sure': 0.03333333333837932},
#  {'tell want good': 0.36666667372790684,
#   'know dont like': 0.3666666595945417,
#   'make fuck money': 0.03333333333450931,
#   'say talk mean': 0.033333333334874884,
#   'ill hell mr': 0.033333333334676994,
#   'im think oh': 0.03333333333473736,
#   'youre right thats': 0.03333333333472701,
#   'hes man let': 0.03333333333442813,
#   'whats need thank': 0.03333333333471514,
#   'yes kill sure': 0.033333333334882774},
#  {'tell want good': 0.025000000007708786,
#   'know dont like': 0.35887562745224794,
#   'make fuck money': 0.1911229364893883,
#   'say talk mean': 0.025000000009923688,
#   'ill hell mr': 0.025001707981534546,
#   'im think oh': 0.025004776238683725,
#   'youre right thats': 0.27499495179459554,
#   'hes man let': 0.025000000007051805,
#   'whats need thank': 0.025000000008892187,
#   'yes kill sure': 0.02500000000997343},
#  {'tell want good': 0.03333333333818183,
#   'know dont like': 0.03333333333714681,
#   'make fuck money': 0.36665934185920385,
#   'say talk mean': 0.03334068671330358,
#   'ill hell mr': 0.033333333338777145,
#   'im think oh': 0.033333333339020506,
#   'youre right thats': 0.03333333333897767,
#   'hes man let': 0.3666650070415598,
#   'whats need thank': 0.033334964354222334,
#   'yes kill sure': 0.033333333339606516},
#  {'tell want good': 0.3666667308899187,
#   'know dont like': 0.03333333333571308,
#   'make fuck money': 0.033333333336302756,
#   'say talk mean': 0.36666660241743715,
#   'ill hell mr': 0.03333333333672662,
#   'im think oh': 0.033333333336879656,
#   'youre right thats': 0.033333333336855946,
#   'hes man let': 0.03333333333609843,
#   'whats need thank': 0.033333333336824464,
#   'yes kill sure': 0.033333333337243275},
#  {'tell want good': 0.014288174969265592,
#   'know dont like': 0.6610530177126762,
#   'make fuck money': 0.014285714302738296,
#   'say talk mean': 0.014285714308068635,
#   'ill hell mr': 0.014286218773216754,
#   'im think oh': 0.22465510177887352,
#   'youre right thats': 0.014285714305909782,
#   'hes man let': 0.014286547565287971,
#   'whats need thank': 0.014285714305707452,
#   'yes kill sure': 0.014288081978255877},
#  {'tell want good': 0.0333333333334749,
#   'know dont like': 0.6999999999985715,
#   'make fuck money': 0.03333333333347236,
#   'say talk mean': 0.033333333333515555,
#   'ill hell mr': 0.03333333333349223,
#   'im think oh': 0.033333333333499325,
#   'youre right thats': 0.03333333333349812,
#   'hes man let': 0.03333333333346277,
#   'whats need thank': 0.03333333333349667,
#   'yes kill sure': 0.03333333333351648},
#  {'tell want good': 0.0166666666743023,
#   'know dont like': 0.2049324899812678,
#   'make fuck money': 0.328400618133026,
#   'say talk mean': 0.016666666676491824,
#   'ill hell mr': 0.016666666675237515,
#   'im think oh': 0.3499996647568641,
#   'youre right thats': 0.016666850974356422,
#   'hes man let': 0.016666666673649647,
#   'whats need thank': 0.01666704277826254,
#   'yes kill sure': 0.01666666667654191},
#  {'tell want good': 0.010001212506227125,
#   'know dont like': 0.2156149741768418,
#   'make fuck money': 0.010000285313692719,
#   'say talk mean': 0.44010966276594543,
#   'ill hell mr': 0.16406229371025224,
#   'im think oh': 0.12020771195720342,
#   'youre right thats': 0.010000524592309783,
#   'hes man let': 0.010001214840909073,
#   'whats need thank': 0.010001860999907665,
#   'yes kill sure': 0.010000259136710779},
#  {'tell want good': 0.13750093396628546,
#   'know dont like': 0.5073637514485206,
# ...
#   'know dont like': 0.03333967949089644,
#   'make fuck money': 0.033340340203236334,
#   'say talk mean': 0.03333717104900277,
#   'ill hell mr': 0.0333333333377969,
#   'im think oh': 0.033333333337994306,
#   'youre right thats': 0.033333333337959084,
#   'hes man let': 0.3666555697001376,
#   'whats need thank': 0.033334057928208115,
#   'yes kill sure': 0.03334100740461638},
#  {'tell want good': 0.0333333333460644,
#   'know dont like': 0.03333333334335993,
#   'make fuck money': 0.033340725569350915,
#   'say talk mean': 0.03333333334974276,
#   'ill hell mr': 0.033333333347627093,
#   'im think oh': 0.03333333334827591,
#   'youre right thats': 0.03333333334815292,
#   'hes man let': 0.03333385805935659,
#   'whats need thank': 0.699992082938242,
#   'yes kill sure': 0.03333333334982746},
#  {'tell want good': 0.03333333333497619,
#   'know dont like': 0.03333333333462576,
#   'make fuck money': 0.03333754766964883,
#   'say talk mean': 0.03333333333544846,
#   'ill hell mr': 0.03333333333517644,
#   'im think oh': 0.03333333333525954,
#   'youre right thats': 0.03333333333524393,
#   'hes man let': 0.03333333333483528,
#   'whats need thank': 0.3666624081805235,
#   'yes kill sure': 0.36666671080426216},
#  {'tell want good': 0.03334216057462831,
#   'know dont like': 0.033346109490128624,
#   'make fuck money': 0.03334176895010154,
#   'say talk mean': 0.03333333333394516,
#   'ill hell mr': 0.03336317072895384,
#   'im think oh': 0.6999284449520072,
#   'youre right thats': 0.03334501196863743,
#   'hes man let': 0.03333333333376785,
#   'whats need thank': 0.0333333333338818,
#   'yes kill sure': 0.03333333333394836},
#  {'tell want good': 0.025002454323819596,
#   'know dont like': 0.025000936003090616,
#   'make fuck money': 0.3158668467544035,
#   'say talk mean': 0.025000000004513648,
#   'ill hell mr': 0.025000000003937994,
#   'im think oh': 0.02500000000411202,
#   'youre right thats': 0.025000000004084387,
#   'hes man let': 0.025001394106658723,
#   'whats need thank': 0.025002904579073493,
#   'yes kill sure': 0.484125464216306},
#  {'tell want good': 0.03333333395026024,
#   'know dont like': 0.033333333818769025,
#   'make fuck money': 0.36666343179660654,
#   'say talk mean': 0.033337707832171194,
#   'ill hell mr': 0.3666534477452784,
#   'im think oh': 0.03333333405689209,
#   'youre right thats': 0.03333333405150747,
#   'hes man let': 0.033336776248871346,
#   'whats need thank': 0.03334196636798504,
#   'yes kill sure': 0.03333333413165857},
#  {'tell want good': 0.05000000000029414,
#   'know dont like': 0.050005423348314794,
#   'make fuck money': 0.0500000000002889,
#   'say talk mean': 0.05000000000037869,
#   'ill hell mr': 0.5499945766490474,
#   'im think oh': 0.050000000000344866,
#   'youre right thats': 0.050000000000342354,
#   'hes man let': 0.050000000000268975,
#   'whats need thank': 0.050000000000339447,
#   'yes kill sure': 0.05000000000038055},
#  {'tell want good': 0.1,
#   'know dont like': 0.1,
#   'make fuck money': 0.1,
#   'say talk mean': 0.1,
#   'ill hell mr': 0.1,
#   'im think oh': 0.1,
#   'youre right thats': 0.1,
#   'hes man let': 0.1,
#   'whats need thank': 0.1,
#   'yes kill sure': 0.1},
#  {'tell want good': 0.05000000000428836,
#   'know dont like': 0.050004052958325794,
#   'make fuck money': 0.05000000000420973,
#   'say talk mean': 0.050009021139892224,
#   'ill hell mr': 0.05000000000481258,
#   'im think oh': 0.5499869258690778,
#   'youre right thats': 0.050000000004989026,
#   'hes man let': 0.05000000000391799,
#   'whats need thank': 0.050000000004942736,
#   'yes kill sure': 0.050000000005543575},
#  {'tell want good': 0.35040043936493537,
#   'know dont like': 0.010001054748463599,
#   'make fuck money': 0.010000000075051758,
#   'say talk mean': 0.010000000098394454,
#   'ill hell mr': 0.1461290967629144,
#   'im think oh': 0.010000000089635726,
#   'youre right thats': 0.010000000088966328,
#   'hes man let': 0.11000142451375118,
#   'whats need thank': 0.010002619256343916,
#   'yes kill sure': 0.3334653650015433},
#  {'tell want good': 0.05000000000057157,
#   'know dont like': 0.050000000000449754,
#   'make fuck money': 0.05000000000056089,
#   'say talk mean': 0.0500000000007356,
#   'ill hell mr': 0.05000000000064157,
#   'im think oh': 0.5499949810317445,
#   'youre right thats': 0.0500050189633757,
#   'hes man let': 0.05000000000052237,
#   'whats need thank': 0.050000000000659045,
#   'yes kill sure': 0.050000000000738926},
#  {'tell want good': 0.5499999999974223,
#   'know dont like': 0.05000000000020533,
#   'make fuck money': 0.050000000000256235,
#   'say talk mean': 0.050000000000336005,
#   'ill hell mr': 0.05000000000029296,
#   'im think oh': 0.050000000000306,
#   'youre right thats': 0.05000000000030379,
#   'hes man let': 0.05000000000023862,
#   'whats need thank': 0.05000000000030116,
#   'yes kill sure': 0.05000000000033774},
#  {'tell want good': 0.014285714287002592,
#   'know dont like': 0.01428609222744287,
#   'make fuck money': 0.014289869177753977,
#   'say talk mean': 0.1571428856930289,
#   'ill hell mr': 0.01428571428716,
#   'im think oh': 0.014285714287225863,
#   'youre right thats': 0.014285918396483773,
#   'hes man let': 0.014286657147370136,
#   'whats need thank': 0.7285643717879127,
#   'yes kill sure': 0.014287062708619349},
#  {'tell want good': 0.033333333334009584,
#   'know dont like': 0.36666667746650294,
#   'make fuck money': 0.033340014592671705,
#   'say talk mean': 0.033333333334204386,
#   'ill hell mr': 0.033333333334092705,
#   'im think oh': 0.03333333333412633,
#   'youre right thats': 0.033333333334120266,
#   'hes man let': 0.36664902552894607,
#   'whats need thank': 0.0333333333341141,
#   'yes kill sure': 0.03334428240721196},
#  {'tell want good': 0.025001073611650722,
#   'know dont like': 0.02500027497621389,
#   'make fuck money': 0.02500097023862676,
#   'say talk mean': 0.025000000004268313,
#   'ill hell mr': 0.025000000003721927,
#   'im think oh': 0.025000000003889647,
#   'youre right thats': 0.02500000000385798,
#   'hes man let': 0.025000000003031472,
#   'whats need thank': 0.7749976811504491,
#   'yes kill sure': 0.025000000004290097},
#  {'tell want good': 0.020001905451044494,
#   'know dont like': 0.02000000007189522,
#   'make fuck money': 0.02000172313901047,
#   'say talk mean': 0.020000000117743864,
#   'ill hell mr': 0.02000000010253711,
#   'im think oh': 0.2199933195839157,
#   'youre right thats': 0.24934159981133724,
#   'hes man let': 0.39066145149886994,
#   'whats need thank': 0.020000000105426127,
#   'yes kill sure': 0.02000000011821984},
#  {'tell want good': 0.033333333334319974,
#   'know dont like': 0.03333333333410981,
#   'make fuck money': 0.3666592795064187,
#   'say talk mean': 0.033333333334603206,
#   'ill hell mr': 0.033333333334440184,
#   'im think oh': 0.033333333334490164,
#   'youre right thats': 0.0333333333344823,
#   'hes man let': 0.03334069483200413,
#   'whats need thank': 0.033333333334471485,
#   'yes kill sure': 0.36666669232066},
#  {'tell want good': 0.007143780309210468,
#   'know dont like': 0.007143659279861735,
#   'make fuck money': 0.11283164148705259,
#   'say talk mean': 0.08410029648216523,
#   'ill hell mr': 0.3665237169540784,
#   'im think oh': 0.007143932793962813,
#   'youre right thats': 0.007145675540991468,
#   'hes man let': 0.39367825228636133,
#   'whats need thank': 0.00714480365527628,
#   'yes kill sure': 0.007144241211039573},
#  {'tell want good': 0.2199973622363714,
#   'know dont like': 0.020002061655946018,
#   'make fuck money': 0.4199964029806563,
#   'say talk mean': 0.020000000000597692,
#   'ill hell mr': 0.020002632492249622,
#   'im think oh': 0.02000000000054454,
#   'youre right thats': 0.22000001014673826,
#   'hes man let': 0.0200015304857593,
#   'whats need thank': 0.020000000000535773,
#   'yes kill sure': 0.020000000000600805},
#  {'tell want good': 0.00833350025648691,
#   'know dont like': 0.0916676637067507,
#   'make fuck money': 0.008335822689843559,
#   'say talk mean': 0.008333333407864619,
#   'ill hell mr': 0.008337792344205477,
#   'im think oh': 0.09166815866708113,
#   'youre right thats': 0.09166814575249156,
#   'hes man let': 0.22647348880078566,
#   'whats need thank': 0.2716732312207986,
#   'yes kill sure': 0.19350886315369173},
#  {'tell want good': 0.24997458771982614,
#   'know dont like': 0.010002764847104306,
#   'make fuck money': 0.11000094143066681,
#   'say talk mean': 0.010000000058029108,
#   'ill hell mr': 0.01000056204073802,
#   'im think oh': 0.010000595400360798,
#   'youre right thats': 0.2700275642942832,
#   'hes man let': 0.010000879994345823,
#   'whats need thank': 0.3099921041563232,
#   'yes kill sure': 0.010000000058322647},
#  {'tell want good': 0.050000000001407814,
#   'know dont like': 0.05000000000110786,
#   'make fuck money': 0.5499889577396133,
#   'say talk mean': 0.05000000000181203,
#   'ill hell mr': 0.05000000000157934,
#   'im think oh': 0.050000000001650696,
#   'youre right thats': 0.05000000000163954,
#   'hes man let': 0.05001104224774423,
#   'whats need thank': 0.05000000000162404,
#   'yes kill sure': 0.050000000001821185},
#  {'tell want good': 0.2749871938928734,
#   'know dont like': 0.275000702671959,
#   'make fuck money': 0.025000000040091445,
#   'say talk mean': 0.27500115079124415,
#   'ill hell mr': 0.025000000045913864,
#   'im think oh': 0.025000000047767378,
#   'youre right thats': 0.025000000047448716,
#   'hes man let': 0.025000000037244043,
#   'whats need thank': 0.025010952372753633,
#   'yes kill sure': 0.025000000052704377},
#  {'tell want good': 0.35342245752525303,
#   'know dont like': 0.2625010837308898,
#   'make fuck money': 0.012500288099925906,
#   'say talk mean': 0.1375007190206578,
#   'ill hell mr': 0.012500000028735674,
#   'im think oh': 0.012500264605116808,
#   'youre right thats': 0.012500000029778765,
#   'hes man let': 0.012500000023378713,
#   'whats need thank': 0.1715748948882857,
#   'yes kill sure': 0.012500292047977837},
#  {'tell want good': 0.36666670132303164,
#   'know dont like': 0.03333333333464837,
#   'make fuck money': 0.033333333334975526,
#   'say talk mean': 0.03333333333548484,
#   'ill hell mr': 0.03333333333520954,
#   'im think oh': 0.03333333333529383,
#   'youre right thats': 0.033336445051750846,
#   'hes man let': 0.03333333333486252,
#   'whats need thank': 0.36666352027924676,
#   'yes kill sure': 0.033333333335496186},
#  {'tell want good': 0.03333333333464538,
#   'know dont like': 0.03333333333436561,
#   'make fuck money': 0.03333333333462245,
#   'say talk mean': 0.03333333333502222,
#   'ill hell mr': 0.03333333333480613,
#   'im think oh': 0.033333333334872296,
#   'youre right thats': 0.03333585817481738,
#   'hes man let': 0.033333333334533734,
#   'whats need thank': 0.6999974751472836,
#   'yes kill sure': 0.033333333335031155},
#  {'tell want good': 0.2750000011874946,
#   'know dont like': 0.025000000000130595,
#   'make fuck money': 0.02500000000016295,
#   'say talk mean': 0.2749999973797549,
#   'ill hell mr': 0.0250039124555166,
#   'im think oh': 0.025000000000194575,
#   'youre right thats': 0.27499608897618805,
#   'hes man let': 0.02500000000015172,
#   'whats need thank': 0.025000000000191418,
#   'yes kill sure': 0.025000000000214663},
#  {'tell want good': 0.29999690759410425,
#   'know dont like': 0.014286977246738414,
#   'make fuck money': 0.014286047407636141,
#   'say talk mean': 0.014287831102873712,
#   'ill hell mr': 0.014286091359365052,
#   'im think oh': 0.014287340669380534,
#   'youre right thats': 0.17902705144194359,
#   'hes man let': 0.4209612595014047,
#   'whats need thank': 0.01428571432228661,
#   'yes kill sure': 0.014294779354266929},
#  {'tell want good': 0.4736735299610446,
#   'know dont like': 0.020003322079547456,
#   'make fuck money': 0.020000000000542435,
#   'say talk mean': 0.02001341615214379,
#   'ill hell mr': 0.020000000000619664,
#   'im think oh': 0.020000000000647392,
#   'youre right thats': 0.020000000000642882,
#   'hes man let': 0.020000000000504756,
#   'whats need thank': 0.3663097318035927,
#   'yes kill sure': 0.020000000000714283},
#  {'tell want good': 0.1,
#   'know dont like': 0.1,
#   'make fuck money': 0.1,
#   'say talk mean': 0.1,
#   'ill hell mr': 0.1,
#   'im think oh': 0.1,
#   'youre right thats': 0.1,
#   'hes man let': 0.1,
#   'whats need thank': 0.1,
#   'yes kill sure': 0.1},
#  {'tell want good': 0.016668377920225866,
#   'know dont like': 0.6652934750809828,
#   'make fuck money': 0.016667921959219033,
#   'say talk mean': 0.01666809041238085,
#   'ill hell mr': 0.2013574522951224,
#   'im think oh': 0.016667297868899186,
#   'youre right thats': 0.016667288927722887,
#   'hes man let': 0.016667742082561332,
#   'whats need thank': 0.016668364806293696,
#   'yes kill sure': 0.01667398864659192},
#  {'tell want good': 0.02000558072152176,
#   'know dont like': 0.020000000002718232,
#   'make fuck money': 0.22000003119948128,
#   'say talk mean': 0.02000000000444721,
#   'ill hell mr': 0.3111211437052775,
#   'im think oh': 0.3288698055917735,
#   'youre right thats': 0.02000221724735859,
#   'hes man let': 0.020001221518961974,
#   'whats need thank': 0.02000000000398624,
#   'yes kill sure': 0.020000000004473734},
#  {'tell want good': 0.01428635854955608,
#   'know dont like': 0.014289901122560239,
#   'make fuck money': 0.01429275734820209,
#   'say talk mean': 0.014285714381087286,
#   'ill hell mr': 0.3950968416435228,
#   'im think oh': 0.014286366446731678,
#   'youre right thats': 0.014286596062025198,
#   'hes man let': 0.4905975178354009,
#   'whats need thank': 0.014290276635985448,
#   'yes kill sure': 0.014287669974928372},
#  {'tell want good': 0.05000000000467401,
#   'know dont like': 0.05000000000367764,
#   'make fuck money': 0.5499999999537578,
#   'say talk mean': 0.0500000000060144,
#   'ill hell mr': 0.05000000000524435,
#   'im think oh': 0.05000000000547943,
#   'youre right thats': 0.050000000005438854,
#   'hes man let': 0.050000000004271995,
#   'whats need thank': 0.050000000005393244,
#   'yes kill sure': 0.05000000000604832},
#  {'tell want good': 0.012501628530050348,
#   'know dont like': 0.012500000006276572,
#   'make fuck money': 0.012500242646518177,
#   'say talk mean': 0.012500677413882777,
#   'ill hell mr': 0.012501917800338089,
#   'im think oh': 0.44249928911114034,
#   'youre right thats': 0.15470987521066354,
#   'hes man let': 0.3152820495072831,
#   'whats need thank': 0.012501168048560387,
#   'yes kill sure': 0.012503151725286562},
#  {'tell want good': 0.0250000000004606,
#   'know dont like': 0.0250000000003624,
#   'make fuck money': 0.02500000000045222,
#   'say talk mean': 0.025000000000592975,
#   'ill hell mr': 0.02500000000051702,
#   'im think oh': 0.5250000267702302,
#   'youre right thats': 0.025000000000536413,
#   'hes man let': 0.2749999732257208,
#   'whats need thank': 0.02500000000053149,
#   'yes kill sure': 0.025000000000595938},
#  {'tell want good': 0.011111111116875861,
#   'know dont like': 0.24622660188623482,
#   'make fuck money': 0.19990217142525854,
#   'say talk mean': 0.011112001898896683,
#   'ill hell mr': 0.011111390358197736,
#   'im think oh': 0.12222236933606098,
#   'youre right thats': 0.011111111117820162,
#   'hes man let': 0.011111111116380211,
#   'whats need thank': 0.3649810206257079,
#   'yes kill sure': 0.011111111118567265},
#  {'tell want good': 0.05000000000007474,
#   'know dont like': 0.05000000000005882,
#   'make fuck money': 0.05000000000007339,
#   'say talk mean': 0.05000000000009624,
#   'ill hell mr': 0.05000000000008391,
#   'im think oh': 0.5499999999992746,
#   'youre right thats': 0.050000000000087017,
#   'hes man let': 0.05000000000006834,
#   'whats need thank': 0.05000000000008624,
#   'yes kill sure': 0.05000000000009674},
#  {'tell want good': 0.05000000000194436,
#   'know dont like': 0.05000000000153029,
#   'make fuck money': 0.050000000001910974,
#   'say talk mean': 0.050000000002504076,
#   'ill hell mr': 0.05000000000218365,
#   'im think oh': 0.050000000002281435,
#   'youre right thats': 0.050000000002264615,
#   'hes man let': 0.050000000001778594,
#   'whats need thank': 0.5499999999810854,
#   'yes kill sure': 0.05000000000251666},
#  {'tell want good': 0.6999687142749138,
#   'know dont like': 0.03333865750310863,
#   'make fuck money': 0.03333554787039393,
#   'say talk mean': 0.033333333336424784,
#   'ill hell mr': 0.033333333336027046,
#   'im think oh': 0.03333333333614735,
#   'youre right thats': 0.03333689624301582,
#   'hes man let': 0.03333885191532741,
#   'whats need thank': 0.033333333336102555,
#   'yes kill sure': 0.03334799884853854},
#  ...]

# %%
#   Saving the list of dictionaries as a JSON file.

with open(r"../data/topic_modelling.json", "w") as f:
    json.dump(json_data, f)
